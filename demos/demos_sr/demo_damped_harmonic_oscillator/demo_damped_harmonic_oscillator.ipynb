# %% [markdown]
# # $\Phi$-SO demo

# %% [markdown]
# ## Packages import

# %%
# External packages
import torch
import numpy as np

# Pyplot
import matplotlib.pyplot as plt

# Internal code import
import physo
from physo.learn import monitoring
from physo.task  import checks

# %%
# Device
DEVICE = 'cpu'
if torch.cuda.is_available():
    DEVICE = 'cuda'
print(DEVICE)
# Out:
# cpu

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# Seed
seed = 0
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ## Test case

# %% [markdown]
# #### Data points

# %%
data_size = int(1e3)

# %%
# Data points
t  = np.random.uniform(np.pi, 10*np.pi, data_size)
X_array = np.stack((t,), axis=0)
f      = 0.784
alpha0 = 1/9.89
phi    = 0.997
y_array = np.exp(-t*alpha0)*np.cos(f*t + phi)

# %%
n_dim = X_array.shape[0]
fig, ax = plt.subplots(n_dim, 1, figsize=(10,5))
for i in range (n_dim):
    curr_ax = ax if n_dim==1 else ax[i]
    curr_ax.plot(X_array[i], y_array, 'k.',)
    curr_ax.set_xlabel("X[%i]"%(i))
    curr_ax.set_ylabel("y")
plt.show()

# %% [markdown]
# #### Sending data to device

# %%
# ------ Vectors ------
# Stack of all input variables
X = torch.tensor(X_array).to(DEVICE)
# Output of symbolic function to guess
y = torch.tensor(y_array).to(DEVICE)

# ------ Constants ------
const1 = torch.tensor(np.array( 1.   )).to(DEVICE)

# %% [markdown]
# ## Run config

# %% [markdown]
# ### Library config

# %%
# [length, mass, time]
args_make_tokens = {
                # operations
                "op_names"             : ["mul", "add", "sub", "div", "inv", "n2", "sqrt", "neg", "exp", "log", "sin", "cos"],
                "use_protected_ops"    : True,
                # input variables
                "input_var_ids"        : {"t" : 0         ,},
                "input_var_units"      : {"t" : [0, 0, 1] ,},
                "input_var_complexity" : {"t" : 1.        ,},
                # constants
                "constants"            : {"1" : const1    , },
                "constants_units"      : {"1" : [0, 0, 0] , },
                "constants_complexity" : {"1" : 1.        , },
                # free constants
                "free_constants"            : {"f"               , "alpha0"               , "phi"               , },
                "free_constants_init_val"   : {"f" : 1.          , "alpha0" : 1/10.       , "phi" : 1.          , },
                "free_constants_units"      : {"f" : [0, 0, -1]  , "alpha0" : [0, 0, -1]  , "phi" : [0, 0, 0]   , },
                "free_constants_complexity" : {"f" : 1.          , "alpha0" : 1.          , "phi" : 1.          , },
                    }

library_config = {"args_make_tokens"  : args_make_tokens,
                  "superparent_units" : [0, 0, 0],
                  "superparent_name"  : "F",
                }

# %% [markdown]
# ### Learning config

# %%
reward_config = {
                 "reward_function"     : physo.physym.reward.SquashedNRMSE, 
                 "zero_out_unphysical" : True,
                 "zero_out_duplicates" : False,
                 "keep_lowest_complexity_duplicate" : False,
                 "parallel_mode" : True,
                 "n_cpus"        : None,
                }

# %%
BATCH_SIZE = int(1e4)
MAX_LENGTH = 35
GET_OPTIMIZER = lambda model : torch.optim.Adam(
                                    model.parameters(),                
                                    lr=0.0025, #0.001, #0.0050, #0.0005, #1,  #lr=0.0025
                                                )

# %%
learning_config = {
    # Batch related
    'batch_size'       : BATCH_SIZE,
    'max_time_step'    : MAX_LENGTH,
    'n_epochs'         : int(1e9),
    # Loss related
    'gamma_decay'      : 0.7,
    'entropy_weight'   : 0.005,
    # Reward related
    'risk_factor'      : 0.05,
    'rewards_computer' : physo.physym.reward.make_RewardsComputer (**reward_config),
    # Optimizer
    'get_optimizer'    : GET_OPTIMIZER,
    'observe_units'    : True,
}

# %% [markdown]
# ### Free constant optimizer config

# %%
free_const_opti_args = {
            'loss'   : "MSE",
            'method' : 'LBFGS',
            'method_args': {
                        'n_steps' : 15,
                        'tol'     : 1e-6,
                        'lbfgs_func_args' : {
                            'max_iter'       : 4,
                            'line_search_fn' : "strong_wolfe",
                                             },
                            },
        }

# %% [markdown]
# ### Priors config

# %%
priors_config  = [
                #("UniformArityPrior", None),
                # LENGTH RELATED
                ("HardLengthPrior"  , {"min_length": 4, "max_length": MAX_LENGTH, }),
                ("SoftLengthPrior"  , {"length_loc": 8, "scale": 5, }),
                # RELATIONSHIPS RELATED
                ("NoUselessInversePrior"  , None),
                ("PhysicalUnitsPrior", {"prob_eps": np.finfo(np.float32).eps}), # PHYSICALITY
                ("NestedFunctions", {"functions":["exp",], "max_nesting" : 1}),
                ("NestedFunctions", {"functions":["log",], "max_nesting" : 1}),
                ("NestedTrigonometryPrior", {"max_nesting" : 1}),           
                #("OccurrencesPrior", {"targets" : ["1",], "max" : [3,] }),
                 ]

# %% [markdown]
# ### Cell config

# %%
cell_config = {
    "hidden_size" : 128,
    "n_layers"    : 1,
    "is_lobotomized" : False,
}

# %% [markdown]
# ### Logger

# %%
save_path_training_curves = 'demo_curves.png'
save_path_log             = 'demo.log'

run_logger     = monitoring.RunLogger(save_path = save_path_log, 
                                      do_save = True)

run_visualiser = monitoring.RunVisualiser (epoch_refresh_rate = 10,
                                           save_path = save_path_training_curves,
                                           do_show   = False,
                                           do_prints = True,
                                           do_save   = True, )

# %% [markdown]
# ### Run config

# %%
run_config = {
    "learning_config"      : learning_config,
    "reward_config"        : reward_config,
    "free_const_opti_args" : free_const_opti_args,
    "library_config"       : library_config,
    "priors_config"        : priors_config,
    "cell_config"          : cell_config,
    "run_logger"           : run_logger,
    "run_visualiser"       : run_visualiser,
}

# %% [markdown]
# ## Dummy epoch for prior tuning

# %%
checks.dummy_epoch_SR(X = X, y = y, run_config = run_config)

# %% [markdown]
# ## Run

# %%
rewards, candidates = physo.fit ([X,], [y,], run_config,
                                stop_reward = 0.9999, 
                                stop_after_n_epochs = 5)
# Out:
# =========== Epoch 00000 ===========
# -> Time 16.08 s
#
# Overall best  at R=0.599779
# -> Raw expression :
#    ⎛    sin(f⋅t⋅(-φ - 2))⎞
# log⎜1 + ─────────────────⎟
#    ⎝            φ        ⎠
#
# Best of epoch at R=0.599779
# -> Raw expression :
#    ⎛    sin(f⋅t⋅(-φ - 2))⎞
# log⎜1 + ─────────────────⎟
#    ⎝            φ        ⎠
#
#
# =========== Epoch 00001 ===========
# -> Time 42.97 s
#
# Overall best  at R=0.599779
# -> Raw expression :
#    ⎛    sin(f⋅t⋅(-φ - 2))⎞
# log⎜1 + ─────────────────⎟
#    ⎝            φ        ⎠
#
# Best of epoch at R=0.557716
# -> Raw expression :
#    ⎛   ⎛  1   ⎞⎞
#    ⎜log⎜──────⎟⎟
#    ⎜   ⎝α₀⋅2⋅t⎠⎟
# sin⎜───────────⎟
#    ⎜     0.5   ⎟
#    ⎝    φ      ⎠
#
#
# =========== Epoch 00002 ===========
# -> Time 43.46 s
#
# Overall best  at R=0.610199
# -> Raw expression :
#   ⎛                   1   ⎞
# f⋅⎜-cos(α₀⋅t - φ) + ──────⎟ - f
#   ⎝                 cos(φ)⎠
# ───────────────────────────────
#                α₀
#
# Best of epoch at R=0.610199
# -> Raw expression :
#   ⎛                   1   ⎞
# f⋅⎜-cos(α₀⋅t - φ) + ──────⎟ - f
#   ⎝                 cos(φ)⎠
# ───────────────────────────────
#                α₀
#
#
# =========== Epoch 00003 ===========
# -> Time 44.69 s
#
# Overall best  at R=0.620770
# -> Raw expression :
# ⎛  ⎛     ⎛      t   ⎞    ⎞    ⎞   1
# ⎜f⋅⎜φ⋅sin⎜φ + ──────⎟ - 1⎟ + f⎟⋅1⋅──
# ⎜  ⎜     ⎜    ⎛ f  ⎞⎟    ⎟    ⎟   α₀
# ⎜  ⎜     ⎜    ⎜────⎟⎟    ⎟    ⎟
# ⎝  ⎝     ⎝    ⎝α₀⋅f⎠⎠    ⎠    ⎠
#
# Best of epoch at R=0.620770
# -> Raw expression :
# ⎛  ⎛     ⎛      t   ⎞    ⎞    ⎞   1
# ⎜f⋅⎜φ⋅sin⎜φ + ──────⎟ - 1⎟ + f⎟⋅1⋅──
# ⎜  ⎜     ⎜    ⎛ f  ⎞⎟    ⎟    ⎟   α₀
# ⎜  ⎜     ⎜    ⎜────⎟⎟    ⎟    ⎟
# ⎝  ⎝     ⎝    ⎝α₀⋅f⎠⎠    ⎠    ⎠
#
#
# =========== Epoch 00004 ===========
# -> Time 44.83 s
#
# Overall best  at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
# Best of epoch at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
#
# =========== Epoch 00005 ===========
# -> Time 46.55 s
#
# Overall best  at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
# Best of epoch at R=0.643061
# -> Raw expression :
#          1
# ───────────────────
#       f⋅t
# ─────────────── + φ
#    ⎛       0.5⎞
#    ⎜    ⎛1⎞   ⎟
# cos⎜f⋅t⋅⎜─⎟   ⎟
#    ⎝    ⎝φ⎠   ⎠
#
#
# =========== Epoch 00006 ===========
# -> Time 46.05 s
#
# Overall best  at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
# Best of epoch at R=0.607600
# -> Raw expression :
#   ⎛        ⎛  ⎛     ⎛ 2⎞⎞⎞⎞
#   ⎜        ⎜  ⎜     ⎝φ ⎠⎟⎟⎟
#   ⎜        ⎜  ⎜    ℯ    ⎟⎟⎟
# φ⋅⎜-φ + cos⎜f⋅⎜t + ─────⎟⎟⎟
#   ⎝        ⎝  ⎝     α₀⋅φ⎠⎠⎠
#
#
# =========== Epoch 00007 ===========
# -> Time 45.22 s
#
# Overall best  at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
# Best of epoch at R=0.620770
# -> Raw expression :
#    ⎛        2   f ⎞
# sin⎜α₀⋅t + φ  + ──⎟
#    ⎝            α₀⎠
# ───────────────────
#          φ
#
#
# =========== Epoch 00008 ===========
# -> Time 46.44 s
#
# Overall best  at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
# Best of epoch at R=0.693623
# -> Raw expression :
# α₀⋅φ + α₀⋅cos(f⋅t)
# ──────────────────
#       f⋅f⋅t
#
#
# =========== Epoch 00009 ===========
# -> Time 46.65 s
#
# Overall best  at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
# Best of epoch at R=0.596810
# -> Raw expression :
#    ⎛         ⎛f⋅φ⋅t⎞  ⎞
#    ⎜      cos⎜─────⎟  ⎟
#    ⎜         ⎝  φ  ⎠  ⎟
#    ⎜ -φ + ──────────  ⎟
#    ⎜         f⋅t      ⎟
# log⎝ℯ               ⋅1⎠
#
#
# =========== Epoch 00010 ===========
# -> Time 60.69 s
#
# Overall best  at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
# Best of epoch at R=0.748521
# -> Raw expression :
#              ⎛α₀⋅t⎞
#          -sin⎜────⎟
#              ⎝ φ  ⎠
#      f - ───────────
#               t
#      ───────────────
#             f
# φ + ℯ
#
#
# =========== Epoch 00011 ===========
# -> Time 47.46 s
#
# Overall best  at R=0.793693
# -> Raw expression :
#        ⎛  ⎛                 ⎛ 2⎞⎞    ⎞
#        ⎜  ⎜                 ⎝1 ⎠⎟    ⎟
# φ + sin⎝t⋅⎝-α₀ + (-α₀ + f)⋅ℯ    ⎠ + 1⎠
# ──────────────────────────────────────
#                  α₀⋅t
#
# Best of epoch at R=0.660412
# -> Raw expression :
#       cos(f⋅t)
# ───────────────────
#   ⎛        ⎛t    ⎞⎞
# t⋅⎜-α₀ + f⋅⎜─ + 1⎟⎟
#   ⎝        ⎝t    ⎠⎠
#
#
# =========== Epoch 00012 ===========
# -> Time 45.95 s
#
# Overall best  at R=0.816523
# -> Raw expression :
# ⎛-cos((α₀⋅(t + t) + φ)⋅1) ⎞
# ⎜─────────────────────────⎟
# ⎝            α₀           ⎠
# ───────────────────────────
#              t
#
# Best of epoch at R=0.816523
# -> Raw expression :
# ⎛-cos((α₀⋅(t + t) + φ)⋅1) ⎞
# ⎜─────────────────────────⎟
# ⎝            α₀           ⎠
# ───────────────────────────
#              t
#
#
# =========== Epoch 00013 ===========
# -> Time 46.55 s
#
# Overall best  at R=0.856129
# -> Raw expression :
#    ⎛     t⋅t ⎞
# sin⎜-φ + ────⎟
#    ⎜     ⎛t ⎞⎟
#    ⎜     ⎜──⎟⎟
#    ⎝     ⎝α₀⎠⎠
# ──────────────
#      f⋅t
#
# Best of epoch at R=0.856129
# -> Raw expression :
#    ⎛     t⋅t ⎞
# sin⎜-φ + ────⎟
#    ⎜     ⎛t ⎞⎟
#    ⎜     ⎜──⎟⎟
#    ⎝     ⎝α₀⎠⎠
# ──────────────
#      f⋅t
#
#
# =========== Epoch 00014 ===========
# -> Time 46.20 s
#
# Overall best  at R=0.856129
# -> Raw expression :
#    ⎛     t⋅t ⎞
# sin⎜-φ + ────⎟
#    ⎜     ⎛t ⎞⎟
#    ⎜     ⎜──⎟⎟
#    ⎝     ⎝α₀⎠⎠
# ──────────────
#      f⋅t
#
# Best of epoch at R=0.692016
# -> Raw expression :
#     ⎛ α₀⋅t⎞
# -sin⎝ℯ    ⎠⋅-cos(f⋅t)
#
#
# =========== Epoch 00015 ===========
# -> Time 44.97 s
#
# Overall best  at R=0.856129
# -> Raw expression :
#    ⎛     t⋅t ⎞
# sin⎜-φ + ────⎟
#    ⎜     ⎛t ⎞⎟
#    ⎜     ⎜──⎟⎟
#    ⎝     ⎝α₀⎠⎠
# ──────────────
#      f⋅t
#
# Best of epoch at R=0.697435
# -> Raw expression :
# (α₀⋅t + cos(φ))⋅cos(t⋅(α₀ + f))
#
#
# =========== Epoch 00016 ===========
# -> Time 45.01 s
#
# Overall best  at R=0.856129
# -> Raw expression :
#    ⎛     t⋅t ⎞
# sin⎜-φ + ────⎟
#    ⎜     ⎛t ⎞⎟
#    ⎜     ⎜──⎟⎟
#    ⎝     ⎝α₀⎠⎠
# ──────────────
#      f⋅t
#
# Best of epoch at R=0.762931
# -> Raw expression :
#  sin(f⋅t)
# ──────────
# ⎛  -t    ⎞
# ⎜────────⎟
# ⎜      1 ⎟
# ⎜φ⋅t + ──⎟
# ⎝      α₀⎠
#
#
# =========== Epoch 00017 ===========
# -> Time 43.61 s
#
# Overall best  at R=0.856129
# -> Raw expression :
#    ⎛     t⋅t ⎞
# sin⎜-φ + ────⎟
#    ⎜     ⎛t ⎞⎟
#    ⎜     ⎜──⎟⎟
#    ⎝     ⎝α₀⎠⎠
# ──────────────
#      f⋅t
#
# Best of epoch at R=0.697435
# -> Raw expression :
#   ⎛           ⎛α₀⎞⎞
# φ⋅⎜-α₀⋅t + cos⎜──⎟⎟⋅cos(f⋅t)
#   ⎝           ⎝f ⎠⎠
#
#
# =========== Epoch 00018 ===========
# -> Time 42.52 s
#
# Overall best  at R=0.856129
# -> Raw expression :
#    ⎛   ⎛        t⋅log(φ)⎞    ⎞
# sin⎜α₀⋅⎜t + t - ────────⎟ - φ⎟
#    ⎜   ⎜          ⎛t⎞   ⎟    ⎟
#    ⎜   ⎜          ⎜─⎟   ⎟    ⎟
#    ⎝   ⎝          ⎝t⎠   ⎠    ⎠
# ──────────────────────────────
#              f⋅t
#
# Best of epoch at R=0.856129
# -> Raw expression :
#    ⎛   ⎛        t⋅log(φ)⎞    ⎞
# sin⎜α₀⋅⎜t + t - ────────⎟ - φ⎟
#    ⎜   ⎜          ⎛t⎞   ⎟    ⎟
#    ⎜   ⎜          ⎜─⎟   ⎟    ⎟
#    ⎝   ⎝          ⎝t⎠   ⎠    ⎠
# ──────────────────────────────
#              f⋅t
#
#
# =========== Epoch 00019 ===========
# -> Time 41.72 s
#
# Overall best  at R=0.856129
# -> Raw expression :
#    ⎛   ⎛        t⋅log(φ)⎞    ⎞
# sin⎜α₀⋅⎜t + t - ────────⎟ - φ⎟
#    ⎜   ⎜          ⎛t⎞   ⎟    ⎟
#    ⎜   ⎜          ⎜─⎟   ⎟    ⎟
#    ⎝   ⎝          ⎝t⎠   ⎠    ⎠
# ──────────────────────────────
#              f⋅t
#
# Best of epoch at R=0.850024
# -> Raw expression :
#         1
# ──────────────────
# ⎛      f⋅t       ⎞
# ⎜────────────────⎟
# ⎝cos(α₀⋅φ⋅-t + φ)⎠
#
#
# =========== Epoch 00020 ===========
# -> Time 55.46 s
#
# Overall best  at R=0.856129
# -> Raw expression :
#    ⎛   ⎛        t⋅log(φ)⎞    ⎞
# sin⎜α₀⋅⎜t + t - ────────⎟ - φ⎟
#    ⎜   ⎜          ⎛t⎞   ⎟    ⎟
#    ⎜   ⎜          ⎜─⎟   ⎟    ⎟
#    ⎝   ⎝          ⎝t⎠   ⎠    ⎠
# ──────────────────────────────
#              f⋅t
#
# Best of epoch at R=0.767920
# -> Raw expression :
#     -t
# ───────────⋅sin(f⋅t)
#    α₀⋅t - φ
# t⋅ℯ
#
#
# =========== Epoch 00021 ===========
# -> Time 39.16 s
#
# Overall best  at R=0.856129
# -> Raw expression :
# cos(α₀⋅(-2⋅t + t) - φ)
# ──────────────────────
#          f⋅t
#
# Best of epoch at R=0.856129
# -> Raw expression :
# cos(α₀⋅(-2⋅t + t) - φ)
# ──────────────────────
#          f⋅t
#
#
# =========== Epoch 00022 ===========
# -> Time 38.71 s
#
# Overall best  at R=0.856129
# -> Raw expression :
# cos(α₀⋅(-2⋅t + t) - φ)
# ──────────────────────
#          f⋅t
#
# Best of epoch at R=0.850205
# -> Raw expression :
#    ⎛   ⎛     1⎞⎞
# cos⎜-t⋅⎜-f - ─⎟⎟
#    ⎝   ⎝     t⎠⎠
# ────────────────
#   α₀⋅t⋅sin(φ)
#
#
# =========== Epoch 00023 ===========
# -> Time 38.22 s
#
# Overall best  at R=0.856129
# -> Raw expression :
# cos(α₀⋅(-2⋅t + t) - φ)
# ──────────────────────
#          f⋅t
#
# Best of epoch at R=0.856129
# -> Raw expression :
# cos(α₀⋅-2⋅t + f⋅t + φ)
# ──────────────────────
#          α₀⋅t
#
#
# =========== Epoch 00024 ===========
# -> Time 38.43 s
#
# Overall best  at R=0.856129
# -> Raw expression :
# cos(α₀⋅(-2⋅t + t) - φ)
# ──────────────────────
#          f⋅t
#
# Best of epoch at R=0.766369
# -> Raw expression :
# t⋅sin(-α₀⋅t)
# ────────────
#       f⋅t
#   t⋅-ℯ
#
#
# =========== Epoch 00025 ===========
# -> Time 36.11 s
#
# Overall best  at R=0.856129
# -> Raw expression :
# cos(α₀⋅(-2⋅t + t) - φ)
# ──────────────────────
#          f⋅t
#
# Best of epoch at R=0.758084
# -> Raw expression :
#      sin(α₀⋅t - f⋅t + φ)
# -φ + ───────────────────
#              f⋅t
#
#
# =========== Epoch 00026 ===========
# -> Time 34.32 s
#
# Overall best  at R=0.856129
# -> Raw expression :
# cos(α₀⋅(-2⋅t + t) - φ)
# ──────────────────────
#          f⋅t
#
# Best of epoch at R=0.856129
# -> Raw expression :
# - -cos(α₀⋅-t - φ)
# ──────────────────
#        f⋅t
#
#
# =========== Epoch 00027 ===========
# -> Time 34.05 s
#
# Overall best  at R=0.856129
# -> Raw expression :
# cos(α₀⋅(-2⋅t + t) - φ)
# ──────────────────────
#          f⋅t
#
# Best of epoch at R=0.856129
# -> Raw expression :
# cos(-φ + φ + φ + φ + α₀⋅t - φ)
# ──────────────────────────────
#              f⋅t
#
#
# =========== Epoch 00028 ===========
# -> Time 32.41 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#  - -f⋅-t
# ℯ       ⋅sin(-α₀⋅t - φ)
#
# Best of epoch at R=1.000000
# -> Raw expression :
#  - -f⋅-t
# ℯ       ⋅sin(-α₀⋅t - φ)
#
#
# =========== Epoch 00029 ===========
# -> Time 32.02 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#  - -f⋅-t
# ℯ       ⋅sin(-α₀⋅t - φ)
#
# Best of epoch at R=0.856129
# -> Raw expression :
# sin(φ + -f⋅t + 2⋅φ)
# ───────────────────
#         α₀⋅t
#
#
# =========== Epoch 00030 ===========
# -> Time 46.27 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#  - -f⋅-t
# ℯ       ⋅sin(-α₀⋅t - φ)
#
# Best of epoch at R=0.856129
# -> Raw expression :
# cos(φ + t⋅(-α₀ + f + f))
# ────────────────────────
#           f⋅t
#
#
# =========== Epoch 00031 ===========
# -> Time 31.54 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#  - -f⋅-t
# ℯ       ⋅sin(-α₀⋅t - φ)
#
# Best of epoch at R=0.856129
# -> Raw expression :
# cos(φ + φ + t⋅(-α₀ + α₀ + α₀ - f))
# ──────────────────────────────────
#                f⋅t
#
#
# =========== Epoch 00032 ===========
# -> Time 30.73 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#  - -f⋅-t
# ℯ       ⋅sin(-α₀⋅t - φ)
#
# Best of epoch at R=0.864887
# -> Raw expression :
# ⎛    ⎛            t   ⎞ ⎞
# ⎜-cos⎜f⋅t + φ + ──────⎟ ⎟
# ⎜    ⎝          α₀⋅t⋅t⎠ ⎟
# ⎜───────────────────────⎟
# ⎝           α₀          ⎠
# ─────────────────────────
#             t
#
#
# =========== Epoch 00033 ===========
# -> Time 31.86 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#  - -f⋅-t
# ℯ       ⋅sin(-α₀⋅t - φ)
#
# Best of epoch at R=0.856129
# -> Raw expression :
#    ⎛    -α₀ - f⋅f⋅-2⋅t⎞
# cos⎜φ + ──────────────⎟
#    ⎝          f       ⎠
# ───────────────────────
#           α₀⋅t

# %% [markdown]
# ## Results

# %% [markdown]
# ### Run plot

# %%
run_visualiser.make_visualisation()
run_visualiser.save_visualisation()
run_visualiser.save_data()

# %% [markdown]
# ### Pareto Front

# %%
def plot_pareto_front(run_logger,
                      do_simplify                   = True,
                      show_superparent_at_beginning = True,
                      eq_text_size                  = 18,
                      delta_xlim                    = [0, 5 ],
                      delta_ylim                    = [-0.1, 0.005],
                      frac_delta_equ                = [0.01, -0.01],
                      figsize                       = (20, 10),
                     ):

    pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

    pareto_front_r2 = physo.physym.reward.SquashedNRMSE_to_R2(pareto_front_r)
    # Fig params
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    # enables new_dummy_symbol = "\square"
    plt.rc('text.latex', preamble=r'\usepackage{amssymb} \usepackage{xcolor}')

    # Fig
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(pareto_front_complexities, pareto_front_r2, 'r-')
    ax.plot(pareto_front_complexities, pareto_front_r2, 'ro')

    # Limits
    xmin = pareto_front_complexities.min() + delta_xlim[0]
    xmax = pareto_front_complexities.max() + delta_xlim[1]
    ymin = pareto_front_r2.min() + delta_ylim[0]
    ymax = pareto_front_r2.max() + delta_ylim[1]
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    ax.invert_yaxis()

    # Axes labels
    ax.set_xlabel("Expression complexity")
    ax.set_ylabel("$R^2$")


    for i_prog in range (len(pareto_front_programs)):
        prog = pareto_front_programs[i_prog]

        text_pos  = [pareto_front_complexities[i_prog] + frac_delta_equ[0]*(xmax-xmin), 
                     pareto_front_r2[i_prog]         + frac_delta_equ[1]*(ymax-ymin)]
        # Getting latex expr
        latex_str = prog.get_infix_latex(do_simplify = do_simplify)
        # Adding "superparent =" before program to make it pretty
        if show_superparent_at_beginning:
            latex_str = prog.library.superparent.name + ' =' + latex_str


        ax.annotate(text = f'${latex_str}$',
                    xy   = (text_pos[0], text_pos[1]), 
                    size = eq_text_size,
                    ha   = "left",
                    va   = "bottom",
                   )
    return fig

# %%
plot_pareto_front(run_logger)

# %% [markdown]
# ### Complexity - accuracy optimums

# %%
pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)
    free_consts = prog.free_consts.class_values[0].detach().cpu().numpy()
    for i in range (len(free_consts)):
        print("%s = %f"%(prog.library.free_const_names[i], free_consts[i]))
# Out:
# alpha0 = 0.100000
# f = 1.000000
# phi = -0.013214
# alpha0 = -0.617787
# f = 1.000000
# phi = 1.000000
# alpha0 = -1.791064
# f = 1.000000
# phi = -270.144108
# alpha0 = 0.742897
# f = 1.000000
# phi = 4.412941
# alpha0 = 0.417496
# f = 0.873221
# phi = 1.000000
# alpha0 = 0.776382
# f = 0.328797
# phi = 5.185064
# alpha0 = 0.776384
# f = 0.328797
# phi = 3.614273
# alpha0 = 0.447585
# f = 0.776385
# phi = -2.668905
# alpha0 = -0.776386
# f = 0.328799
# phi = 5.185076
# alpha0 = 0.784000
# f = 0.101112
# phi = -0.573796
