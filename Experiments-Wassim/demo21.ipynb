# %% [markdown]
# # $\Phi$-SO demo

# %% [markdown]
# ## Packages import

# %%
# conda env
# !echo $CONDA_PREFIX
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/PhySO

# %%
# External packages
import torch
import numpy as np

# Pyplot
# %matplotlib inline
import matplotlib.pyplot as plt

# Internal code import
import physo
from physo.learn import monitoring
from physo.task  import benchmark

# %%
# Device
DEVICE = 'cpu'
if torch.cuda.is_available():
    DEVICE = 'cuda'
print(DEVICE)
# Out:
# cpu

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# ## Test case

# %%
data_size = 50

# %%
# Data points
data_lowbound, data_upbound = -10, 10
z  = np.random.uniform(data_lowbound, data_upbound, data_size)
vz = np.random.uniform(data_lowbound, data_upbound, data_size)
x0_array = z
x1_array = vz
X_array = np.stack((x0_array, x1_array), axis=0)
m = 1.5
g = 9.8
y_array = m*g*z + m*vz**2 #+ 0.5*m*vz**2

# One of many symbolic solutions:
target_program_str = ["add", "mul", "mul", "m", "g", "z", "mul", "m", "n2", "v_z"]
print(len(target_program_str))
# Out:
# 10

# %%
n_dim = X_array.shape[0]
fig, ax = plt.subplots(n_dim, 1, figsize=(10,5))
for i in range (n_dim):
    curr_ax = ax if n_dim==1 else ax[i]
    curr_ax.plot(X_array[i], y_array, 'k.',)
    curr_ax.set_xlabel("X[%i]"%(i))
    curr_ax.set_ylabel("y")
plt.show()

# %%
# ------ Vectors ------
# Stack of all input variables
X = torch.tensor(X_array).to(DEVICE)
# Output of symbolic function to guess
y = torch.tensor(y_array).to(DEVICE)

# ------ Constants ------
const1 = torch.tensor(np.array(1.)).to(DEVICE)
m = torch.tensor(np.array(m)).to(DEVICE)
g = torch.tensor(np.array(g)).to(DEVICE)

# %% [markdown]
# ## Run config

# %% [markdown]
# ### Library config

# %%
args_make_tokens = {
                # operations
                "op_names"             : ["mul", "add", "sub", "div", "inv", "n2", "sqrt", "exp", "log", "sin", "cos"],
                "use_protected_ops"    : True,
                # input variables
                "input_var_ids"        : {"z" : 0         , "v_z" : 1         , },
                "input_var_units"      : {"z" : [1, 0, 0] , "v_z" : [1, -1, 0], },
                "input_var_complexity" : {"z" : 1.        , "v_z" : 1.        , },
                # constants
                "constants"            : {"1" : const1    , },
                "constants_units"      : {"1" : [0, 0, 0] , },
                "constants_complexity" : {"1" : 1.        , },
                # free constants
                "free_constants"            : {"m"              , "g"              ,},
                "free_constants_init_val"   : {"m" : 1.         , "g" : 1.         ,},
                "free_constants_units"      : {"m" : [0, 0, 1]  , "g" : [1, -2, 0] ,},
                "free_constants_complexity" : {"m" : 1.         , "g" : 1.         ,},
                    }

library_config = {"args_make_tokens"  : args_make_tokens,
                  "superparent_units" : [2, -2, 1],
                  "superparent_name"  : "E",
                }

# %% [markdown]
# ### Free constant optimizer config

# %%
free_const_opti_args = {
            'loss'   : "MSE",
            'method' : 'LBFGS',
            'method_args': {
                        'n_steps' : 30,
                        'tol'     : 1e-8,
                        'lbfgs_func_args' : {
                            'max_iter'       : 4,
                            'line_search_fn' : "strong_wolfe",
                                             },
                            },
        }

# %% [markdown]
# ### Learning config

# %%
MAX_TRIAL_EXPRESSIONS = 2*1e6
BATCH_SIZE = int(1e3)
MAX_LENGTH = 35
GET_OPTIMIZER = lambda model : torch.optim.Adam(
                                    model.parameters(),                
                                    lr=0.0025, #0.001, #0.0050, #0.0005, #1,  #lr=0.0025
                                                )

# %%
reward_config = {
                 "reward_function"     : physo.physym.reward.SquashedNRMSE, # PHYSICALITY
                 "zero_out_unphysical" : True,
                 "zero_out_duplicates" : True,
                 "keep_lowest_complexity_duplicate" : True,
                }

# %%
learning_config = {
    # Batch related
    'batch_size'       : BATCH_SIZE,
    'max_time_step'    : MAX_LENGTH,
    'n_epochs'         : int(1e9), #int(MAX_TRIAL_EXPRESSIONS/BATCH_SIZE),
    # Loss related
    'gamma_decay'      : 0.7,
    'entropy_weight'   : 0.005,
    # Reward related
    'risk_factor'      : 0.05,
    'rewards_computer' : physo.physym.reward.make_RewardsComputer (**reward_config),
    # Optimizer
    'get_optimizer'    : GET_OPTIMIZER,
}

# %% [markdown]
# ### Priors config

# %%
priors_config  = [
                #("UniformArityPrior", None),
                # LENGTH RELATED
                ("HardLengthPrior"  , {"min_length": 4, "max_length": MAX_LENGTH, }),
                ("SoftLengthPrior"  , {"length_loc": 6, "scale": 5, }),
                # RELATIONSHIPS RELATED
                ("NoUselessInversePrior"  , None),
                ("PhysicalUnitsPrior", {"prob_eps": np.finfo(np.float32).eps}), # PHYSICALITY
                #("NestedFunctions", {"functions":["exp",], "max_nesting" : 1}),
                #("NestedFunctions", {"functions":["log",], "max_nesting" : 1}),
                ("NestedTrigonometryPrior", {"max_nesting" : 1}),
                ("OccurrencesPrior", {"targets" : ["1",], "max" : [3,] }),
                 ]

# %% [markdown]
# ### Cell config

# %%
cell_config = {
    "hidden_size" : 128,
    "n_layers"    : 1,
}

# %% [markdown]
# ### Logger

# %%
save_path_training_curves = 'demo_curves.png'
save_path_log             = 'demo.log'

run_logger     = monitoring.RunLogger(save_path = save_path_log, 
                                      do_save = True)

run_visualiser = monitoring.RunVisualiser (epoch_refresh_rate = 10,
                                           save_path = save_path_training_curves,
                                           do_show   = False,
                                           do_prints = True,
                                           do_save   = True, )

# %% [markdown]
# ### Run config

# %%
run_config = {
    "learning_config"      : learning_config,
    "reward_config"        : reward_config,
    "free_const_opti_args" : free_const_opti_args,
    "library_config"       : library_config,
    "priors_config"        : priors_config,
    "cell_config"          : cell_config,
    "run_logger"           : run_logger,
    "run_visualiser"       : run_visualiser,
}

# %% [markdown]
# ## Dummy epoch for prior tuning

# %%
benchmark.dummy_epoch(X, y, run_config)

# %% [markdown]
# ## Sanity checks

# %%
target_program = benchmark.sanity_check(X, y, run_config, target_program_str=target_program_str)
# Out:
# Data
# {'mul': 0, 'add': 1, 'sub': 2, 'div': 3, 'inv': 4, 'n2': 5, 'sqrt': 6, 'exp': 7, 'log': 8, 'sin': 9, 'cos': 10, '1': 11, 'g': 12, 'm': 13, 'z': 14, 'v_z': 15}
# -------------------------- Library -------------------------
# [mul add sub div inv n2 sqrt exp log sin cos 1 g m z v_z E dummy -]
# --------------------------- Prior --------------------------
# PriorCollection:
# - HardLengthPrior (min_length = 4, max_length = 35)
# - SoftLengthPrior (length_loc = 6, scale = 5)
# - NoUselessInversePrior (['inv', 'log', 'exp', 'n2', 'sqrt'] can not be child of ['inv', 'exp', 'log', 'sqrt', 'n2'])
# - PhysicalUnitsPrior
# - NestedTrigonometryPrior (tokens = ['sin' 'cos'], nesting forbidden)
# - OccurrencesPrior (tokens ['1'] can be used [3] times max)
# -------------------------- Dataset -------------------------
# X        : torch.Size([2, 50])
# y_target : torch.Size([50])
# -------------------------- Programs ------------------------
# [['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ...
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']]
#
# -------------------------- Cell ------------------------
# Cell(
#   (input_dense): Linear(in_features=81, out_features=128, bias=True)
#   (stacked_cells): ModuleList(
#     (0): LSTMCell(128, 128)
#   )
#   (output_dense): Linear(in_features=128, out_features=16, bias=True)
# )
# n_params= 144657
# -------------------------- Ideal reward ------------------------
# ---- Target ----
# Tokens in prefix notation:
# [add, mul, mul, m, g, z, mul, m, n2, v_z]
# Raw expression ascii:
#              2
# g⋅m⋅z + m⋅v_z
# Raw expression:
# Simplified expression:
# Ideal reward : 0.9999998296117928

# %% [markdown]
# ## Run

# %%
rewards, candidates = physo.fit(X, y, run_config)
# Out:
# =========== Epoch 00000 ===========
# -> Time 2.62 s
#
# Overall best  at R=0.483693
# -> Raw expression :
#          m
# ────────────────────
# ⎛          2       ⎞
# ⎜⎛   1    ⎞        ⎟
# ⎜⎜────────⎟ ⋅sin(1)⎟
# ⎜⎜⎛ v_z  ⎞⎟        ⎟
# ⎜⎜⎜──────⎟⎟        ⎟
# ⎜⎝⎝log(1)⎠⎠        ⎟
# ⎜──────────────────⎟
# ⎝        1         ⎠
#
# Best of epoch at R=0.483693
# -> Raw expression :
#          m
# ────────────────────
# ⎛          2       ⎞
# ⎜⎛   1    ⎞        ⎟
# ⎜⎜────────⎟ ⋅sin(1)⎟
# ⎜⎜⎛ v_z  ⎞⎟        ⎟
# ⎜⎜⎜──────⎟⎟        ⎟
# ⎜⎝⎝log(1)⎠⎠        ⎟
# ⎜──────────────────⎟
# ⎝        1         ⎠
#
#
# =========== Epoch 00001 ===========
# -> Time 2.18 s
#
# Overall best  at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
# Best of epoch at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
#
# =========== Epoch 00002 ===========
# -> Time 1.29 s
#
# Overall best  at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
# Best of epoch at R=0.610519
# -> Raw expression :
# g⋅z
# ────
# ⎛m ⎞
# ⎜──⎟
# ⎜ 2⎟
# ⎝m ⎠
#
#
# =========== Epoch 00003 ===========
# -> Time 1.68 s
#
# Overall best  at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
# Best of epoch at R=0.610519
# -> Raw expression :
# g⋅z
# ───
# ⎛1⎞
# ⎜─⎟
# ⎝m⎠
#
#
# =========== Epoch 00004 ===========
# -> Time 1.79 s
#
# Overall best  at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
# Best of epoch at R=0.610519
# -> Raw expression :
#       ⎛       ⎛   ⎛  1  ⎞⎞⎞
# g⋅m⋅z⋅⎜1 - log⎜cos⎜─────⎟⎟⎟
#       ⎝       ⎝   ⎝1 - 1⎠⎠⎠
#
#
# =========== Epoch 00005 ===========
# -> Time 1.53 s
#
# Overall best  at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
# Best of epoch at R=0.610519
# -> Raw expression :
#     ⎛          ⎛    0.5⎞    ⎞
#     ⎜          ⎜⎛ 1⎞   ⎟    ⎟
# m⋅z⋅⎝-g + g⋅sin⎝⎝ℯ ⎠   ⎠ + g⎠
#
#
# =========== Epoch 00006 ===========
# -> Time 1.44 s
#
# Overall best  at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
# Best of epoch at R=0.610519
# -> Raw expression :
# g⋅m⋅z
#
#
# =========== Epoch 00007 ===========
# -> Time 1.79 s
#
# Overall best  at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
# Best of epoch at R=0.610519
# -> Raw expression :
#   g⋅m⋅z
# ─────────
#  ⎛ 0.5⎞
#  ⎝1   ⎠
# ℯ      ⋅1
#
#
# =========== Epoch 00008 ===========
# -> Time 1.52 s
#
# Overall best  at R=0.610519
# -> Raw expression :
#        ⎛               2⎞
#        ⎜⎛   1      ⎛1⎞⎞ ⎟
#        ⎜⎜- ℯ  + cos⎜─⎟⎟ ⎟
#        ⎝⎝          ⎝1⎠⎠ ⎠
# g⋅m⋅z⋅ℯ
#
# Best of epoch at R=0.610519
# -> Raw expression :
# g⋅m⋅z
#
#
# =========== Epoch 00009 ===========
# -> Time 1.63 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#     ⎛ 1⎞
#  sin⎝ℯ ⎠                  2
# ℯ       ⋅z⋅m⋅1⋅g⋅1 - m⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#     ⎛ 1⎞
#  sin⎝ℯ ⎠                  2
# ℯ       ⋅z⋅m⋅1⋅g⋅1 - m⋅v_z
#
#
# =========== Epoch 00010 ===========
# -> Time 3.34 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#               m
# -g⋅m⋅z + ────────────
#          ⎛       2  ⎞
#          ⎜  ⎛ 1 ⎞   ⎟
#          ⎜  ⎜───⎟   ⎟
#          ⎜  ⎝v_z⎠   ⎟
#          ⎜──────────⎟
#          ⎜ ⎛    0.5⎞⎟
#          ⎜ ⎜⎛ 1⎞   ⎟⎟
#          ⎜ ⎝⎝ℯ ⎠   ⎠⎟
#          ⎝ℯ         ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#               m
# -g⋅m⋅z + ────────────
#          ⎛       2  ⎞
#          ⎜  ⎛ 1 ⎞   ⎟
#          ⎜  ⎜───⎟   ⎟
#          ⎜  ⎝v_z⎠   ⎟
#          ⎜──────────⎟
#          ⎜ ⎛    0.5⎞⎟
#          ⎜ ⎜⎛ 1⎞   ⎟⎟
#          ⎜ ⎝⎝ℯ ⎠   ⎠⎟
#          ⎝ℯ         ⎠
#
#
# =========== Epoch 00011 ===========
# -> Time 1.81 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#               m
# -g⋅m⋅z + ────────────
#          ⎛       2  ⎞
#          ⎜  ⎛ 1 ⎞   ⎟
#          ⎜  ⎜───⎟   ⎟
#          ⎜  ⎝v_z⎠   ⎟
#          ⎜──────────⎟
#          ⎜ ⎛    0.5⎞⎟
#          ⎜ ⎜⎛ 1⎞   ⎟⎟
#          ⎜ ⎝⎝ℯ ⎠   ⎠⎟
#          ⎝ℯ         ⎠
#
# Best of epoch at R=0.610519
# -> Raw expression :
# m⋅1⋅sin(1)⋅g⋅z
#
#
# =========== Epoch 00012 ===========
# -> Time 1.94 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#               m
# -g⋅m⋅z + ────────────
#          ⎛       2  ⎞
#          ⎜  ⎛ 1 ⎞   ⎟
#          ⎜  ⎜───⎟   ⎟
#          ⎜  ⎝v_z⎠   ⎟
#          ⎜──────────⎟
#          ⎜ ⎛    0.5⎞⎟
#          ⎜ ⎜⎛ 1⎞   ⎟⎟
#          ⎜ ⎝⎝ℯ ⎠   ⎠⎟
#          ⎝ℯ         ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#           1
# ──────────────────────
# ⎛          ⎛1⎞       ⎞
# ⎜       cos⎜─⎟       ⎟
# ⎜          ⎝1⎠       ⎟
# ⎜────────────────────⎟
# ⎝-g⋅m⋅z + v_z⋅1⋅m⋅v_z⎠
#
#
# =========== Epoch 00013 ===========
# -> Time 2.17 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#               m
# -g⋅m⋅z + ────────────
#          ⎛       2  ⎞
#          ⎜  ⎛ 1 ⎞   ⎟
#          ⎜  ⎜───⎟   ⎟
#          ⎜  ⎝v_z⎠   ⎟
#          ⎜──────────⎟
#          ⎜ ⎛    0.5⎞⎟
#          ⎜ ⎜⎛ 1⎞   ⎟⎟
#          ⎜ ⎝⎝ℯ ⎠   ⎠⎟
#          ⎝ℯ         ⎠
#
# Best of epoch at R=0.610519
# -> Raw expression :
# g⋅m⋅z
#
#
# =========== Epoch 00014 ===========
# -> Time 1.98 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#               m
# -g⋅m⋅z + ────────────
#          ⎛       2  ⎞
#          ⎜  ⎛ 1 ⎞   ⎟
#          ⎜  ⎜───⎟   ⎟
#          ⎜  ⎝v_z⎠   ⎟
#          ⎜──────────⎟
#          ⎜ ⎛    0.5⎞⎟
#          ⎜ ⎜⎛ 1⎞   ⎟⎟
#          ⎜ ⎝⎝ℯ ⎠   ⎠⎟
#          ⎝ℯ         ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#     ⎛                2⎞
# 1⋅m⋅⎝g⋅z⋅sin(1) + v_z ⎠
#
#
# =========== Epoch 00015 ===========
# -> Time 1.67 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#               m
# -g⋅m⋅z + ────────────
#          ⎛       2  ⎞
#          ⎜  ⎛ 1 ⎞   ⎟
#          ⎜  ⎜───⎟   ⎟
#          ⎜  ⎝v_z⎠   ⎟
#          ⎜──────────⎟
#          ⎜ ⎛    0.5⎞⎟
#          ⎜ ⎜⎛ 1⎞   ⎟⎟
#          ⎜ ⎝⎝ℯ ⎠   ⎠⎟
#          ⎝ℯ         ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#              1
# g⋅v_z⋅1⋅z⋅m⋅─── - m⋅v_z⋅v_z
#             v_z
#
#
# =========== Epoch 00016 ===========
# -> Time 1.64 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#               m
# -g⋅m⋅z + ────────────
#          ⎛       2  ⎞
#          ⎜  ⎛ 1 ⎞   ⎟
#          ⎜  ⎜───⎟   ⎟
#          ⎜  ⎝v_z⎠   ⎟
#          ⎜──────────⎟
#          ⎜ ⎛    0.5⎞⎟
#          ⎜ ⎜⎛ 1⎞   ⎟⎟
#          ⎜ ⎝⎝ℯ ⎠   ⎠⎟
#          ⎝ℯ         ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                   2  cos(1)
# -g⋅m⋅z + m⋅(1⋅v_z) ⋅ℯ
#
#
# =========== Epoch 00017 ===========
# -> Time 1.74 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#              1
# ────────────────────────────
#                   1
# cos(1)⋅1⋅───────────────────
#          1⋅g⋅z⋅m - m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#              1
# ────────────────────────────
#                   1
# cos(1)⋅1⋅───────────────────
#          1⋅g⋅z⋅m - m⋅v_z⋅v_z
#
#
# =========== Epoch 00018 ===========
# -> Time 1.63 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
#
# =========== Epoch 00019 ===========
# -> Time 1.63 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#      1
# 1⋅m⋅ℯ ⋅(g⋅z - v_z⋅v_z)
#
#
# =========== Epoch 00020 ===========
# -> Time 3.14 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                     1
# -m⋅v_z⋅v_z + 1⋅m⋅───────
#                  ⎛  1  ⎞
#                  ⎜─────⎟
#                  ⎝1⋅g⋅z⎠
#
#
# =========== Epoch 00021 ===========
# -> Time 1.93 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
# sin(1)⋅1⋅m⋅(g⋅z⋅sin(1) - v_z⋅v_z)
#
#
# =========== Epoch 00022 ===========
# -> Time 2.29 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   ⎛              ⎛ 1⎞          ⎞
#   ⎜              ⎜ ─⎟          ⎟
#   ⎜              ⎜ 1⎟          ⎟
# m⋅⎝-g⋅z + g⋅z⋅sin⎝ℯ ⎠ + v_z⋅v_z⎠
#
#
# =========== Epoch 00023 ===========
# -> Time 1.96 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   ⎛        1          ⎞
# m⋅⎜1⋅z⋅z⋅g⋅─ - v_z⋅v_z⎟
#   ⎝        z          ⎠
#
#
# =========== Epoch 00024 ===========
# -> Time 2.24 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                       ⎛ 1⎞
# -g⋅m⋅z + m⋅v_z⋅v_z⋅sin⎝ℯ ⎠⋅cos(1)
#
#
# =========== Epoch 00025 ===========
# -> Time 2.03 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
# g⋅m⋅z⋅sin(1) + 1⋅v_z⋅m⋅v_z
#
#
# =========== Epoch 00026 ===========
# -> Time 1.72 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                      ⎛   1  ⎞
#                      ⎜ m⋅─⋅1⎟
#                      ⎜   m  ⎟
# g⋅m⋅z + m⋅v_z⋅v_z⋅cos⎝ℯ     ⎠
#
#
# =========== Epoch 00027 ===========
# -> Time 1.68 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#              1
# 1⋅────────────────────────
#   ⎛        cos(1)        ⎞
#   ⎜──────────────────────⎟
#   ⎝1⋅(-g⋅m⋅z + m⋅v_z⋅v_z)⎠
#
#
# =========== Epoch 00028 ===========
# -> Time 1.87 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#          ⎛ 1⎞
#          ⎝ℯ ⎠
# g⋅m⋅z - ℯ    ⋅1⋅v_z⋅m⋅v_z
#
#
# =========== Epoch 00029 ===========
# -> Time 1.97 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                    sin(1)
# g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ      ⋅cos(1⋅1)
#
#
# =========== Epoch 00030 ===========
# -> Time 3.42 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#      ⎛ ⎛ 1⎞⎞
#      ⎜ ⎝ℯ ⎠⎟
# - sin⎝ℯ    ⎠⋅z⋅1⋅g⋅m + m⋅v_z⋅v_z
#
#
# =========== Epoch 00031 ===========
# -> Time 2.27 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
# m⋅(g⋅z - v_z⋅v_z)⋅sin(1⋅1)
#
#
# =========== Epoch 00032 ===========
# -> Time 2.64 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                      ⎛ ⎛ ⎛ 1⎞⎞⎞
#                      ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                      ⎜ ⎝ℯ    ⎠⎟
# g⋅m⋅z + m⋅v_z⋅v_z⋅cos⎝ℯ       ⎠
#
#
# =========== Epoch 00033 ===========
# -> Time 2.42 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                1
# g⋅m⋅z - ───────────────
#         ⎛    cos(1)   ⎞
#         ⎜─────────────⎟
#         ⎝1⋅v_z⋅1⋅v_z⋅m⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                 ⎛ ⎛ 1⎞⎞
#                 ⎜ ⎝ℯ ⎠⎟
# g⋅m⋅z⋅cos(1)⋅cos⎝ℯ    ⎠ + m⋅v_z⋅v_z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 rewards, candidates = physo.fit(X, y, run_config)
#
# File ~/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/task/fit.py:62, in fit(X, y, run_config, stop_reward)
#      58 cell      = cell_reseter ()
#      59 optimizer = run_config["learning_config"]["get_optimizer"](cell)
# ---> 62 hall_of_fame_R, hall_of_fame = learn.learner (
#      63                                                 model               = cell,
#      64                                                 optimizer           = optimizer,
#      65                                                 n_epochs            = run_config["learning_config"]["n_epochs"],
#      66                                                 batch_reseter       = batch_reseter,
#      67                                                 risk_factor         = run_config["learning_config"]["risk_factor"],
#      68                                                 gamma_decay         = run_config["learning_config"]["gamma_decay"],
#      69                                                 entropy_weight      = run_config["learning_config"]["entropy_weight"],
#      70                                                 verbose             = False,
#      71                                                 stop_reward         = stop_reward,
#      72                                                 stop_after_n_epochs = 50,
#      73                                                 run_logger          = run_config["run_logger"],
#      74                                                 run_visualiser      = run_config["run_visualiser"],
#      75                                                )
#      77 return hall_of_fame_R, hall_of_fame
#
# File ~/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/learn/learn.py:115, in learner(model, optimizer, n_epochs, batch_reseter, risk_factor, gamma_decay, entropy_weight, verbose, stop_reward, stop_after_n_epochs, run_logger, run_visualiser)
#     110 outlogit = output                                         # (batch_size, output_size)
#     112 # ------------ PRIOR ------------
#     113
#     114 # (embedding output)
# --> 115 prior_array = batch.prior().astype(np.float32)         # (batch_size, output_size)
#     117 # 0 protection so there is always something to sample
#     118 epsilon = 0 #1e-14 #1e0*np.finfo(np.float32).eps
#
# File ~/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/prior.py:848, in PriorCollection.__call__(self)
#     846 res = self.init_prob
#     847 for prior in self.priors:
# --> 848     res = np.multiply(res, prior())
#     849 return res
#
# File ~/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/prior.py:710, in PhysicalUnitsPrior.__call__(self)
#     707 units_requirement_padded = np.moveaxis(np.tile(units_requirement, reps=(self.lib.n_choices, 1, 1))              # (batch_size, n_choices, UNITS_VECTOR_SIZE)
#     708                                        , source=0, destination=1)
#     709 # mask : for each token in batch, is choosing token in library legal units-wise
# --> 710 mask_prob_units_legality = (np.abs(units_requirement_padded - self.lib_units_padded) < self.tol).prod(axis=-1)  # (batch_size, n_choices)
#     712 # ------- RESULT -------
#     713 # Token in library should be allowed if there are no units constraints on any side (library, current dummies)
#     714 # OR if the units are consistent OR if the program is unphysical.
#     715 # Ie. all tokens in the library are allowed if there are no constraints on any sides or if the program is
#     716 # unphysical anyway.
#     717 mask_prob = np.logical_or.reduce((                                                                              # (batch_size, n_choices)
#     718     (~ mask_prob_is_constraining_info),
#     719     (~ is_physical_padded),
#     720     mask_prob_units_legality,
#     721                                   )).astype(float)
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x17ab30310> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/pyplot.py:138, in install_repl_displayhook.<locals>.post_execute()
#     136 def post_execute():
#     137     if matplotlib.is_interactive():
# --> 138         draw_all()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py:137, in Gcf.draw_all(cls, force)
#     135 for manager in cls.get_all_fig_managers():
#     136     if force or manager.canvas.figure.stale:
# --> 137         manager.canvas.draw_idle()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/backend_bases.py:2060, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2058 if not self._is_idle_drawing:
#    2059     with self._idle_draw_cntx():
# -> 2060         self.draw(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/collections.py:2175, in QuadMesh.draw(self, renderer)
#    2172         ys = self.convert_yunits(self._offsets[:, 1])
#    2173         offsets = np.column_stack([xs, ys])
# -> 2175 self.update_scalarmappable()
#    2177 if not transform.is_affine:
#    2178     coordinates = self._coordinates.reshape((-1, 2))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/collections.py:906, in Collection.update_scalarmappable(self)
#     904         # pcolormesh, scatter, maybe others flatten their _A
#     905         self._alpha = self._alpha.reshape(self._A.shape)
# --> 906     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     908 if self._face_is_mapped:
#     909     self._facecolors = self._mapped_colors
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/cm.py:456, in ScalarMappable.to_rgba(self, x, alpha, bytes, norm)
#     454 if norm:
#     455     x = self.norm(x)
# --> 456 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     457 return rgba
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/matplotlib/colors.py:628, in Colormap.__call__(self, X, alpha, bytes)
#     626         xa[xa == self.N] = self.N - 1
#     627         # Avoid converting large positive values to negative integers.
# --> 628         np.clip(xa, -1, self.N, out=xa)
#     629         xa = xa.astype(int)
#     630 # Set the over-range indices before the under-range;
#     631 # otherwise the under-range values get converted to over-range.
#
# File <__array_function__ internals>:200, in clip(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2180, in clip(a, a_min, a_max, out, **kwargs)
#    2111 @array_function_dispatch(_clip_dispatcher)
#    2112 def clip(a, a_min, a_max, out=None, **kwargs):
#    2113     """
#    2114     Clip (limit) the values in an array.
#    2115
#    (...)
#    2178
#    2179     """
# -> 2180     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/numpy/core/_methods.py:161, in _clip(a, min, max, out, casting, **kwargs)
#     158     return _clip_dep_invoke_with_casting(
#     159         um.maximum, a, min, out=out, casting=casting, **kwargs)
#     160 else:
# --> 161     return _clip_dep_invoke_with_casting(
#     162         um.clip, a, min, max, out=out, casting=casting, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PhySO/lib/python3.8/site-packages/numpy/core/_methods.py:115, in _clip_dep_invoke_with_casting(ufunc, out, casting, *args, **kwargs)
#     113 # try to deal with broken casting rules
#     114 try:
# --> 115     return ufunc(*args, out=out, **kwargs)
#     116 except _exceptions._UFuncOutputCastingError as e:
#     117     # Numpy 1.17.0, 2019-02-24
#     118     warnings.warn(
#     119         "Converting the output of clip from {!r} to {!r} is deprecated. "
#     120         "Pass `casting=\"unsafe\"` explicitly to silence this warning, or "
#    (...)
#     123         stacklevel=2
#     124     )
#
# KeyboardInterrupt:

# %% [markdown]
# ## Results

# %% [markdown]
# ### Run plot

# %%
run_visualiser.make_visualisation()

# %% [markdown]
# ### Pareto Front

# %%
def plot_pareto_front(run_logger,
                      do_simplify                   = True,
                      show_superparent_at_beginning = True,
                      eq_text_size                  = 12,
                      delta_xlim                    = [0, 5 ],
                      delta_ylim                    = [0, 15],
                      frac_delta_equ                = [0.03, 0.03],
                      figsize                       = (20, 10),
                     ):

    pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

    pareto_front_rmse = np.log(pareto_front_rmse)
    # Fig params
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    # enables new_dummy_symbol = "\square"
    plt.rc('text.latex', preamble=r'\usepackage{amssymb} \usepackage{xcolor}')
    plt.rc('font', size=32)

    # Fig
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'r-')
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'ro')

    # Limits
    xmin = pareto_front_complexities.min() + delta_xlim[0]
    xmax = pareto_front_complexities.max() + delta_xlim[1]
    ymin = pareto_front_rmse.min() + delta_ylim[0]
    ymax = pareto_front_rmse.max() + delta_ylim[1]
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    # Axes labels
    ax.set_xlabel("Expression complexity")
    ax.set_ylabel("log(RMSE)")


    for i_prog in range (len(pareto_front_programs)):
        prog = pareto_front_programs[i_prog]

        text_pos  = [pareto_front_complexities[i_prog] + frac_delta_equ[0]*(xmax-xmin), 
                     pareto_front_rmse[i_prog]         + frac_delta_equ[1]*(ymax-ymin)]
        # Getting latex expr
        latex_str = prog.get_infix_latex(do_simplify = do_simplify)
        # Adding "superparent =" before program to make it pretty
        if show_superparent_at_beginning:
            latex_str = prog.library.superparent.name + ' =' + latex_str


        ax.text(text_pos[0], text_pos[1], f'${latex_str}$', size = eq_text_size)

# %%
plot_pareto_front(run_logger)

# %%
pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)

# %% [markdown]
# ### Symbolic equivalence

# %%
best_prog_sympy   = candidates[-1] .get_infix_sympy(do_simplify=True)
target_prog_sympy = target_program .get_infix_sympy(do_simplify=True)

# %%
target_prog_sympy

# %%
best_prog_sympy

# %%
target_prog_sympy == best_prog_sympy

# %%
hall_of_fame = run_logger.hall_of_fame

# %%
for i in range(len(hall_of_fame)):
    print(hall_of_fame[i].get_infix_sympy(do_simplify=False))

# %%
eq = hall_of_fame[i].get_infix_sympy(do_simplify=True)

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)
    print("g", prog.free_const_values[0])
    print("m", prog.free_const_values[1])
