# %% [markdown]
# # $\Phi$-SO demo

# %% [markdown]
# ## Packages import

# %%
# conda env
try:
    get_ipython().system('echo $CONDA_PREFIX')
except:
    pass
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/PhySO

# %%
try:
    # %matplotlib inline
    #get_ipython().run_line_magic('matplotlib', 'inline')
except:
    pass

# %%
# External packages
import torch
import numpy as np

# Pyplot
import matplotlib.pyplot as plt

# Internal code import
import physo
from physo.learn import monitoring
from physo.task  import benchmark

# %%
# Device
DEVICE = 'cpu'
if torch.cuda.is_available():
    DEVICE = 'cuda'
print(DEVICE)
# Out:
# cpu

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# ## Test case

# %%
data_size = 50

# %%
# Data points
data_lowbound, data_upbound = -10, 10
z  = np.random.uniform(data_lowbound, data_upbound, data_size)
vz = np.random.uniform(data_lowbound, data_upbound, data_size)
x0_array = z
x1_array = vz
X_array = np.stack((x0_array, x1_array), axis=0)
m = 1.5
g = 9.8
y_array = m*g*z + m*vz**2 #+ 0.5*m*vz**2

# One of many symbolic solutions:
target_program_str = ["add", "mul", "mul", "m", "g", "z", "mul", "m", "n2", "v_z"]
print(len(target_program_str))
# Out:
# 10

# %%
n_dim = X_array.shape[0]
fig, ax = plt.subplots(n_dim, 1, figsize=(10,5))
for i in range (n_dim):
    curr_ax = ax if n_dim==1 else ax[i]
    curr_ax.plot(X_array[i], y_array, 'k.',)
    curr_ax.set_xlabel("X[%i]"%(i))
    curr_ax.set_ylabel("y")
plt.show()

# %%
# ------ Vectors ------
# Stack of all input variables
X = torch.tensor(X_array).to(DEVICE)
# Output of symbolic function to guess
y = torch.tensor(y_array).to(DEVICE)

# ------ Constants ------
const1 = torch.tensor(np.array(1.)).to(DEVICE)
m = torch.tensor(np.array(m)).to(DEVICE)
g = torch.tensor(np.array(g)).to(DEVICE)

# %% [markdown]
# ## Run config

# %% [markdown]
# ### Library config

# %%
args_make_tokens = {
                # operations
                "op_names"             : ["mul", "add", "sub", "div", "inv", "n2", "sqrt", "exp", "log", "sin", "cos"],
                "use_protected_ops"    : True,
                # input variables
                "input_var_ids"        : {"z" : 0         , "v_z" : 1         , },
                "input_var_units"      : {"z" : [1, 0, 0] , "v_z" : [1, -1, 0], },
                "input_var_complexity" : {"z" : 1.        , "v_z" : 1.        , },
                # constants
                "constants"            : {"1" : const1    , },
                "constants_units"      : {"1" : [0, 0, 0] , },
                "constants_complexity" : {"1" : 1.        , },
                # free constants
                "free_constants"            : {"m"              , "g"              ,},
                "free_constants_init_val"   : {"m" : 1.         , "g" : 1.         ,},
                "free_constants_units"      : {"m" : [0, 0, 1]  , "g" : [1, -2, 0] ,},
                "free_constants_complexity" : {"m" : 1.         , "g" : 1.         ,},
                    }

library_config = {"args_make_tokens"  : args_make_tokens,
                  "superparent_units" : [2, -2, 1],
                  "superparent_name"  : "E",
                }

# %% [markdown]
# ### Free constant optimizer config

# %%
free_const_opti_args = {
            'loss'   : "MSE",
            'method' : 'LBFGS',
            'method_args': {
                        'n_steps' : 30,
                        'tol'     : 1e-8,
                        'lbfgs_func_args' : {
                            'max_iter'       : 4,
                            'line_search_fn' : "strong_wolfe",
                                             },
                            },
        }

# %% [markdown]
# ### Learning config

# %%
MAX_TRIAL_EXPRESSIONS = 2*1e6
BATCH_SIZE = int(1e3)
MAX_LENGTH = 35
GET_OPTIMIZER = lambda model : torch.optim.Adam(
                                    model.parameters(),                
                                    lr=0.0025, #0.001, #0.0050, #0.0005, #1,  #lr=0.0025
                                                )

# %%
reward_config = {
                 "reward_function"     : physo.physym.reward.SquashedNRMSE, # PHYSICALITY
                 "zero_out_unphysical" : True,
                 "zero_out_duplicates" : True,
                 "keep_lowest_complexity_duplicate" : True,
                }

# %%
learning_config = {
    # Batch related
    'batch_size'       : BATCH_SIZE,
    'max_time_step'    : MAX_LENGTH,
    'n_epochs'         : int(1e9), #int(MAX_TRIAL_EXPRESSIONS/BATCH_SIZE),
    # Loss related
    'gamma_decay'      : 0.7,
    'entropy_weight'   : 0.005,
    # Reward related
    'risk_factor'      : 0.05,
    'rewards_computer' : physo.physym.reward.make_RewardsComputer (**reward_config),
    # Optimizer
    'get_optimizer'    : GET_OPTIMIZER,
}

# %% [markdown]
# ### Priors config

# %%
priors_config  = [
                #("UniformArityPrior", None),
                # LENGTH RELATED
                ("HardLengthPrior"  , {"min_length": 4, "max_length": MAX_LENGTH, }),
                ("SoftLengthPrior"  , {"length_loc": 6, "scale": 5, }),
                # RELATIONSHIPS RELATED
                ("NoUselessInversePrior"  , None),
                ("PhysicalUnitsPrior", {"prob_eps": np.finfo(np.float32).eps}), # PHYSICALITY
                #("NestedFunctions", {"functions":["exp",], "max_nesting" : 1}),
                #("NestedFunctions", {"functions":["log",], "max_nesting" : 1}),
                ("NestedTrigonometryPrior", {"max_nesting" : 1}),
                ("OccurrencesPrior", {"targets" : ["1",], "max" : [3,] }),
                 ]

# %% [markdown]
# ### Cell config

# %%
cell_config = {
    "hidden_size" : 128,
    "n_layers"    : 1,
}

# %% [markdown]
# ### Logger

# %%
save_path_training_curves = 'demo_curves.png'
save_path_log             = 'demo.log'

run_logger     = monitoring.RunLogger(save_path = save_path_log, 
                                      do_save = True)

run_visualiser = monitoring.RunVisualiser (epoch_refresh_rate = 10,
                                           save_path = save_path_training_curves,
                                           do_show   = False,
                                           do_prints = True,
                                           do_save   = True, )

# %% [markdown]
# ### Run config

# %%
run_config = {
    "learning_config"      : learning_config,
    "reward_config"        : reward_config,
    "free_const_opti_args" : free_const_opti_args,
    "library_config"       : library_config,
    "priors_config"        : priors_config,
    "cell_config"          : cell_config,
    "run_logger"           : run_logger,
    "run_visualiser"       : run_visualiser,
}

# %% [markdown]
# ## Dummy epoch for prior tuning

# %%
benchmark.dummy_epoch(X, y, run_config)

# %% [markdown]
# ## Sanity checks

# %%
target_program = benchmark.sanity_check(X, y, run_config, target_program_str=target_program_str)
# Out:
# Data
# {'mul': 0, 'add': 1, 'sub': 2, 'div': 3, 'inv': 4, 'n2': 5, 'sqrt': 6, 'exp': 7, 'log': 8, 'sin': 9, 'cos': 10, '1': 11, 'g': 12, 'm': 13, 'z': 14, 'v_z': 15}
# -------------------------- Library -------------------------
# [mul add sub div inv n2 sqrt exp log sin cos 1 g m z v_z E dummy -]
# --------------------------- Prior --------------------------
# PriorCollection:
# - HardLengthPrior (min_length = 4, max_length = 35)
# - SoftLengthPrior (length_loc = 6, scale = 5)
# - NoUselessInversePrior (['inv', 'log', 'exp', 'n2', 'sqrt'] can not be child of ['inv', 'exp', 'log', 'sqrt', 'n2'])
# - PhysicalUnitsPrior
# - NestedTrigonometryPrior (tokens = ['sin' 'cos'], nesting forbidden)
# - OccurrencesPrior (tokens ['1'] can be used [3] times max)
# -------------------------- Dataset -------------------------
# X        : torch.Size([2, 50])
# y_target : torch.Size([50])
# -------------------------- Programs ------------------------
# [['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ...
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']]
#
# -------------------------- Cell ------------------------
# Cell(
#   (input_dense): Linear(in_features=81, out_features=128, bias=True)
#   (stacked_cells): ModuleList(
#     (0): LSTMCell(128, 128)
#   )
#   (output_dense): Linear(in_features=128, out_features=16, bias=True)
# )
# n_params= 144657
# -------------------------- Ideal reward ------------------------
# ---- Target ----
# Tokens in prefix notation:
# [add, mul, mul, m, g, z, mul, m, n2, v_z]
# Raw expression ascii:
#              2
# g⋅m⋅z + m⋅v_z
# Raw expression:
# Simplified expression:
# Ideal reward : 0.999999880036708

# %% [markdown]
# ## Run

# %%
rewards, candidates = physo.fit(X, y, run_config)
# Out:
# =========== Epoch 00000 ===========
# -> Time 1.59 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
#
# =========== Epoch 00001 ===========
# -> Time 2.29 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# -> Raw expression :
#       g
# ──────────────
#             1
# 1⋅1⋅cos(1)⋅───
#            m⋅z
#
#
# =========== Epoch 00002 ===========
# -> Time 1.82 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# -> Raw expression :
#       ⎛      1          z⎞
# g⋅m⋅z⋅⎜────────────── + ─⎟
#       ⎜   0.5           z⎟
#       ⎝log   (log(1))    ⎠
#
#
# =========== Epoch 00003 ===========
# -> Time 1.95 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# -> Raw expression :
#          z
# ────────────────────
# ⎛   ⎛   ⎛z⋅log(1)⎞⎞⎞
# ⎜cos⎜log⎜────────⎟⎟⎟
# ⎜   ⎝   ⎝   z    ⎠⎠⎟
# ⎜──────────────────⎟
# ⎝       g⋅m        ⎠
#
#
# =========== Epoch 00004 ===========
# -> Time 1.66 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# -> Raw expression :
#              g⋅z
# ──────────────────────────────
#           2
# ⎛   1    ⎞     ⎛     ⎛1⎞    1⎞
# ⎜────────⎟ ⋅sin⎜- log⎜─⎟ + ℯ ⎟
# ⎜     0.5⎟     ⎝     ⎝1⎠     ⎠
# ⎜  ⎛1⎞   ⎟
# ⎜m⋅⎜─⎟   ⎟
# ⎝  ⎝m⎠   ⎠
#
#
# =========== Epoch 00005 ===========
# -> Time 1.52 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# Unable to print status.
# =========== Epoch 00006 ===========
# -> Time 1.09 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
#
# =========== Epoch 00007 ===========
# -> Time 1.44 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.535174
# -> Raw expression :
#      2 ⎛                   ⎛ 1  ⎞⎞
# m⋅v_z ⋅⎜log(cos(1⋅1)) + cos⎜────⎟⎟
#        ⎜                   ⎜ 0.5⎟⎟
#        ⎝                   ⎝1   ⎠⎠
#
#
# =========== Epoch 00008 ===========
# -> Time 1.45 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# -> Raw expression :
#                      1
#        cos(log(1))⋅1⋅─
#                      1
# g⋅m⋅z⋅ℯ
#
#
# =========== Epoch 00009 ===========
# -> Time 1.54 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# Unable to print status.
# =========== Epoch 00010 ===========
# -> Time 3.90 s
#
# Overall best  at R=0.598152
# -> Raw expression :
# g⋅m⋅z
#
# Best of epoch at R=0.598152
# -> Raw expression :
#                  ⎛   ⎛           2⎞⎞
#                  ⎜   ⎜⎛   2     ⎞ ⎟⎟
# g⋅m⋅z + g⋅m⋅z⋅cos⎝log⎝⎝log (1)⋅1⎠ ⎠⎠
#
#
# =========== Epoch 00011 ===========
# -> Time 2.85 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#   1 ⎛       1         2⎞
# 1⋅─⋅⎜1⋅g⋅m⋅─── + m⋅v_z ⎟
#   1 ⎜      ⎛1⎞         ⎟
#     ⎜      ⎜─⎟         ⎟
#     ⎝      ⎝z⎠         ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   1 ⎛       1         2⎞
# 1⋅─⋅⎜1⋅g⋅m⋅─── + m⋅v_z ⎟
#   1 ⎜      ⎛1⎞         ⎟
#     ⎜      ⎜─⎟         ⎟
#     ⎝      ⎝z⎠         ⎠
#
#
# =========== Epoch 00012 ===========
# -> Time 3.02 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#   1 ⎛       1         2⎞
# 1⋅─⋅⎜1⋅g⋅m⋅─── + m⋅v_z ⎟
#   1 ⎜      ⎛1⎞         ⎟
#     ⎜      ⎜─⎟         ⎟
#     ⎝      ⎝z⎠         ⎠
#
# Best of epoch at R=0.598152
# -> Raw expression :
#  1
# ℯ ⋅z⋅m⋅1⋅g⋅1
#
#
# =========== Epoch 00013 ===========
# -> Time 2.22 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#   1 ⎛       1         2⎞
# 1⋅─⋅⎜1⋅g⋅m⋅─── + m⋅v_z ⎟
#   1 ⎜      ⎛1⎞         ⎟
#     ⎜      ⎜─⎟         ⎟
#     ⎝      ⎝z⎠         ⎠
#
# Best of epoch at R=0.598152
# -> Raw expression :
#          1
#        1⋅──
#           1
#          ℯ
# g⋅m⋅z⋅ℯ    ⋅cos(1)
#
#
# =========== Epoch 00014 ===========
# -> Time 1.69 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                     1
# -m⋅v_z⋅v_z + m⋅1⋅────────
#                  ⎛sin(1)⎞
#                  ⎜──────⎟
#                  ⎝1⋅z⋅g ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                     1
# -m⋅v_z⋅v_z + m⋅1⋅────────
#                  ⎛sin(1)⎞
#                  ⎜──────⎟
#                  ⎝1⋅z⋅g ⎠
#
#
# =========== Epoch 00015 ===========
# -> Time 2.57 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#      1
# 1⋅g⋅ℯ ⋅m⋅z + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#      1
# 1⋅g⋅ℯ ⋅m⋅z + m⋅v_z⋅v_z
#
#
# =========== Epoch 00016 ===========
# -> Time 2.41 s
#
# Overall best  at R=1.000000
# -> Raw expression :
# -1⋅m⋅g⋅z + sin(1)⋅v_z⋅m⋅1⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
# -1⋅m⋅g⋅z + sin(1)⋅v_z⋅m⋅1⋅v_z
#
#
# =========== Epoch 00017 ===========
# -> Time 2.97 s
#
# Overall best  at R=1.000000
# -> Raw expression :
# -1⋅m⋅g⋅z + sin(1)⋅v_z⋅m⋅1⋅v_z
#
# Best of epoch at R=0.598152
# -> Raw expression :
#        1
# g⋅m⋅z⋅ℯ
#
#
# =========== Epoch 00018 ===========
# -> Time 2.76 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#     ⎛               1  cos(1)⎞
# 1⋅m⋅⎝g⋅z + v_z⋅v_z⋅ℯ ⋅ℯ      ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#     ⎛               1  cos(1)⎞
# 1⋅m⋅⎝g⋅z + v_z⋅v_z⋅ℯ ⋅ℯ      ⎠
#
#
# =========== Epoch 00019 ===========
# -> Time 3.72 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#     ⎛               1  cos(1)⎞
# 1⋅m⋅⎝g⋅z + v_z⋅v_z⋅ℯ ⋅ℯ      ⎠
#
# Best of epoch at R=0.598152
# -> Raw expression :
#        cos(1)
# g⋅m⋅z⋅ℯ      ⋅cos(1)
#
#
# =========== Epoch 00020 ===========
# -> Time 3.78 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#     ⎛               1  cos(1)⎞
# 1⋅m⋅⎝g⋅z + v_z⋅v_z⋅ℯ ⋅ℯ      ⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#            1
# 1⋅g⋅m⋅z + ℯ ⋅1⋅m⋅v_z⋅v_z
#
#
# =========== Epoch 00021 ===========
# -> Time 2.47 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#           1
# -g⋅m⋅z + ℯ ⋅1⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#           1
# -g⋅m⋅z + ℯ ⋅1⋅1⋅v_z⋅v_z⋅m
#
#
# =========== Epoch 00022 ===========
# -> Time 2.37 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
#
# =========== Epoch 00023 ===========
# -> Time 2.24 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#      ⎛    1⎞
#      ⎜ 1⋅ℯ ⎟
# 1⋅cos⎝ℯ    ⎠⋅(-g⋅m⋅z + m⋅v_z⋅v_z)
#
#
# =========== Epoch 00024 ===========
# -> Time 2.14 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
# g⋅m⋅z⋅cos(1)⋅cos(1) + m⋅v_z⋅v_z
#
#
# =========== Epoch 00025 ===========
# -> Time 2.14 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                     ⎛ 1⎞      2
# g⋅m⋅z + sin(1)⋅1⋅sin⎝ℯ ⎠⋅m⋅v_z
#
#
# =========== Epoch 00026 ===========
# -> Time 2.35 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#           1
# sin(1)⋅───────⋅m⋅1⋅g⋅z - m⋅v_z⋅v_z
#         sin(1)
#        ℯ
#
#
# =========== Epoch 00027 ===========
# -> Time 2.99 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   ⎛  1          2⎞  1
# m⋅⎜1⋅─⋅z⋅g + v_z ⎟⋅ℯ
#   ⎝  1           ⎠
#
#
# =========== Epoch 00028 ===========
# -> Time 2.82 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   ⎛                 1⎞
# m⋅⎝1⋅z⋅g + v_z⋅v_z⋅ℯ ⎠
# ──────────────────────
#         cos(1)
#
#
# =========== Epoch 00029 ===========
# -> Time 2.81 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
# (g⋅m⋅z⋅cos(1) - 1⋅v_z⋅m⋅v_z)⋅sin(1)
#
#
# =========== Epoch 00030 ===========
# -> Time 4.66 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#      ⎛ 2⎞
# m⋅sin⎝1 ⎠⋅1⋅(-g⋅z + v_z⋅v_z)
#
#
# =========== Epoch 00031 ===========
# -> Time 3.04 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#    ⎛ 1 - 1⎞
# cos⎝ℯ     ⎠⋅1⋅m⋅g⋅z - m⋅v_z⋅v_z
#
#
# =========== Epoch 00032 ===========
# -> Time 3.57 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#            ⎛ 1⎞          2
# g⋅m⋅z + cos⎝ℯ ⎠⋅1⋅m⋅1⋅v_z
#
#
# =========== Epoch 00033 ===========
# -> Time 6.72 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ 1⎞⎞
#   ⎛              2⎞    ⎜ ⎝ℯ ⎠⎟
# m⋅⎝-g⋅z + 1⋅1⋅v_z ⎠⋅cos⎝ℯ    ⎠
#
#
# =========== Epoch 00034 ===========
# -> Time 7.44 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                       1
# m⋅(-g⋅z + 1⋅v_z⋅v_z)⋅ℯ
#
#
# =========== Epoch 00035 ===========
# -> Time 6.10 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                            ⎛ 1⎞
#                    -1 + cos⎝ℯ ⎠
# m⋅(g⋅z + v_z⋅v_z)⋅ℯ            ⋅sin(1)
#
#
# =========== Epoch 00036 ===========
# -> Time 10.44 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   ⎛                 m         ⎞
# 1⋅⎜g⋅m⋅z + ───────────────────⎟
#   ⎜                          2⎟
#   ⎜        ⎛   ⎛ ⎛ 1⎞⎞      ⎞ ⎟
#   ⎜        ⎜   ⎜ ⎝ℯ ⎠⎟    1 ⎟ ⎟
#   ⎜        ⎜sin⎝ℯ    ⎠⋅1⋅───⎟ ⎟
#   ⎝        ⎝             v_z⎠ ⎠
#
#
# =========== Epoch 00037 ===========
# -> Time 3.13 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#       ⎛ 1⎞
#    sin⎝ℯ ⎠
# 1⋅ℯ       ⋅log(sin(1))⋅m⋅(-g⋅z + v_z⋅v_z)
#
#
# =========== Epoch 00038 ===========
# -> Time 7.11 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                       ⎛  1  ⎞
#                       ⎜ ℯ ⋅1⎟
# m⋅(-g⋅z + v_z⋅v_z)⋅cos⎝ℯ    ⎠
#
#
# =========== Epoch 00039 ===========
# -> Time 8.35 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                           ⎛ 1⎞
#                        sin⎝ℯ ⎠
# m⋅(g⋅z + 1⋅1⋅v_z⋅v_z)⋅ℯ
#
#
# =========== Epoch 00040 ===========
# -> Time 4.64 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                    1 + 1
# m⋅(g⋅z - v_z⋅v_z)⋅ℯ     ⋅sin(1)
#
#
# =========== Epoch 00041 ===========
# -> Time 2.21 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#            ⎛      1⎞
#            ⎜ 1 + ℯ ⎟
# g⋅m⋅z + sin⎝ℯ      ⎠⋅1⋅v_z⋅v_z⋅m
#
# Best of epoch at R=1.000000
# -> Raw expression :
# (g⋅m⋅z - m⋅v_z⋅v_z)⋅sin(1)⋅cos(1)⋅cos(1)
#
#
# =========== Epoch 00042 ===========
# -> Time 1.97 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
#
# =========== Epoch 00043 ===========
# -> Time 2.29 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
# Best of epoch at R=1.000000
# -> Raw expression :
# m⋅(g⋅z + v_z⋅v_z)⋅sin(1)⋅sin(1)⋅cos(1)
#
#
# =========== Epoch 00044 ===========
# -> Time 1.82 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   ⎛       ⎛ sin(1)⎞             ⎞
#   ⎜       ⎝ℯ      ⎠  1          ⎟
# m⋅⎝g⋅z + ℯ         ⋅ℯ ⋅1⋅v_z⋅v_z⎠
#
#
# =========== Epoch 00045 ===========
# -> Time 1.92 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
# Best of epoch at R=1.000000
# -> Raw expression :
# (g⋅m⋅z + m⋅v_z⋅v_z)⋅sin(1)⋅sin(1)⋅cos(1)
#
#
# =========== Epoch 00046 ===========
# -> Time 1.84 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
# Best of epoch at R=1.000000
# -> Raw expression :
# m⋅1⋅(v_z⋅v_z + z⋅(g + g))
#
#
# =========== Epoch 00047 ===========
# -> Time 1.98 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   ⎛                                 2⎞
#   ⎜                ⎛ sin(1)        ⎞ ⎟
# m⋅⎝g⋅z + v_z⋅v_z + ⎝ℯ      ⋅1⋅1⋅v_z⎠ ⎠
#
#
# =========== Epoch 00048 ===========
# -> Time 1.76 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                          1
# (m⋅z⋅1⋅g + 1⋅m⋅v_z⋅v_z)⋅ℯ
#
#
# =========== Epoch 00049 ===========
# -> Time 1.61 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#                        ⎛ ⎛ ⎛ 1⎞⎞⎞
#                        ⎜ ⎜ ⎝ℯ ⎠⎟⎟
#                        ⎜ ⎝ℯ    ⎠⎟
#                     sin⎝ℯ       ⎠
# -g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ
#
# Best of epoch at R=1.000000
# -> Raw expression :
#         ⎛ 1⎞
#      sin⎝ℯ ⎠
# 1⋅m⋅ℯ       ⋅g⋅z + m⋅v_z⋅v_z
#
#
# =========== Epoch 00050 ===========
# -> Time 2.88 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
#
# =========== Epoch 00051 ===========
# -> Time 2.12 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#             1
# -1⋅g⋅m⋅z + ℯ ⋅v_z⋅1⋅v_z⋅m
#
#
# =========== Epoch 00052 ===========
# -> Time 2.83 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#         ⎛ 1⎞
#      sin⎝ℯ ⎠
# 1⋅z⋅ℯ       ⋅1⋅g⋅m + m⋅v_z⋅v_z
#
#
# =========== Epoch 00053 ===========
# -> Time 1.74 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
# (m + m)⋅(1⋅v_z⋅v_z + 1⋅(-1⋅z⋅g + v_z⋅v_z))
#
#
# =========== Epoch 00054 ===========
# -> Time 2.24 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                         ⎛ sin(1)⎞
#                         ⎝ℯ      ⎠
# (-g⋅1⋅m⋅z + m⋅v_z⋅v_z)⋅ℯ
#
#
# =========== Epoch 00055 ===========
# -> Time 2.47 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#   ⎛                 1       ⎞
# m⋅⎝1⋅z⋅g + v_z⋅v_z⋅ℯ ⋅cos(1)⎠
#
#
# =========== Epoch 00056 ===========
# -> Time 1.61 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#    sin(1)
# 1⋅ℯ      ⋅m⋅(g⋅z + v_z⋅v_z)
#
#
# =========== Epoch 00057 ===========
# -> Time 1.52 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#       ⎛ 1⎞
#    cos⎝ℯ ⎠
# 1⋅ℯ       ⋅(-g⋅m⋅z + v_z⋅1⋅m⋅v_z)
#
#
# =========== Epoch 00058 ===========
# -> Time 1.64 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                    sin(1)
# g⋅m⋅z + m⋅v_z⋅v_z⋅ℯ      ⋅sin(1⋅1)
#
#
# =========== Epoch 00059 ===========
# -> Time 1.60 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#                      1
# 1⋅m⋅z⋅g + m⋅v_z⋅v_z⋅ℯ ⋅cos(1)
#
#
# =========== Epoch 00060 ===========
# -> Time 3.03 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
#            sin(1)
# g⋅m⋅z + m⋅ℯ      ⋅1⋅sin(1)⋅v_z⋅v_z
#
#
# =========== Epoch 00061 ===========
# -> Time 1.66 s
#
# Overall best  at R=1.000000
# -> Raw expression :
#       ⎛   ⎛      1⎞    ⎞
# g⋅m⋅z⋅⎝sin⎝-1 + ℯ ⎠ + 1⎠ + m⋅v_z⋅v_z
#
# Best of epoch at R=1.000000
# -> Raw expression :
# (g⋅m⋅z⋅sin(1) - 1⋅v_z⋅m⋅v_z)⋅sin(1)

# %% [markdown]
# ## Results

# %% [markdown]
# ### Run plot

# %%
run_visualiser.make_visualisation()

# %% [markdown]
# ### Pareto Front

# %%
def plot_pareto_front(run_logger,
                      do_simplify                   = True,
                      show_superparent_at_beginning = True,
                      eq_text_size                  = 12,
                      delta_xlim                    = [0, 5 ],
                      delta_ylim                    = [0, 15],
                      frac_delta_equ                = [0.03, 0.03],
                      figsize                       = (20, 10),
                     ):

    pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

    pareto_front_rmse = np.log(pareto_front_rmse)
    # Fig params
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    # enables new_dummy_symbol = "\square"
    plt.rc('text.latex', preamble=r'\usepackage{amssymb} \usepackage{xcolor}')
    plt.rc('font', size=32)

    # Fig
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'r-')
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'ro')

    # Limits
    xmin = pareto_front_complexities.min() + delta_xlim[0]
    xmax = pareto_front_complexities.max() + delta_xlim[1]
    ymin = pareto_front_rmse.min() + delta_ylim[0]
    ymax = pareto_front_rmse.max() + delta_ylim[1]
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    # Axes labels
    ax.set_xlabel("Expression complexity")
    ax.set_ylabel("log(RMSE)")


    for i_prog in range (len(pareto_front_programs)):
        prog = pareto_front_programs[i_prog]

        text_pos  = [pareto_front_complexities[i_prog] + frac_delta_equ[0]*(xmax-xmin), 
                     pareto_front_rmse[i_prog]         + frac_delta_equ[1]*(ymax-ymin)]
        # Getting latex expr
        latex_str = prog.get_infix_latex(do_simplify = do_simplify)
        # Adding "superparent =" before program to make it pretty
        if show_superparent_at_beginning:
            latex_str = prog.library.superparent.name + ' =' + latex_str


        ax.text(text_pos[0], text_pos[1], f'${latex_str}$', size = eq_text_size)

# %%
plot_pareto_front(run_logger)

# %%
pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)

# %% [markdown]
# ### Symbolic equivalence

# %%
best_prog_sympy   = candidates[-1] .get_infix_sympy(do_simplify=True)
target_prog_sympy = target_program .get_infix_sympy(do_simplify=True)

# %%
target_prog_sympy
# Out:
# m*(g*z + v_z**2)

# %%
best_prog_sympy
# Out:
# m*(g*z*(1 - sin(1 - E)) + v_z**2)

# %%
target_prog_sympy == best_prog_sympy
# Out:
# False

# %%
hall_of_fame = run_logger.hall_of_fame

# %%
for i in range(len(hall_of_fame)):
    print(hall_of_fame[i].get_infix_sympy(do_simplify=False))
# Out:
# g*m*z
# 1*(1*g*m/1/z + m*v_z**2)/1
# -m*v_z*v_z + m*1/(sin(1)/((1*z*g)))
# 1*g*exp(1)*m*z + m*v_z*v_z
# -g*m*z + sin(1)*v_z*m*1*v_z
# 1*m*(g*z + v_z*v_z*exp(1)*exp(cos(1)))
# -g*m*z + exp(1)*1*1*v_z*v_z*m
# g*m*z + sin(exp(1 + exp(1)))*1*v_z*v_z*m
# -g*m*z + m*v_z*v_z*exp(sin(exp(exp(exp(1)))))
# g*m*z*(sin(-1*1 + exp(1)) + 1) + m*v_z*v_z

# %%
eq = hall_of_fame[i].get_infix_sympy(do_simplify=True)

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)
    print("g", prog.free_const_values[0])
    print("m", prog.free_const_values[1])
# Out:
# g tensor(3.8567, dtype=torch.float64)
# m tensor(3.8567, dtype=torch.float64)
# g tensor(9.8000, dtype=torch.float64)
# m tensor(1.5000, dtype=torch.float64)
# g tensor(4.9000, dtype=torch.float64)
# m tensor(1.5000, dtype=torch.float64)
# g tensor(14.3932, dtype=torch.float64)
# m tensor(1.0213, dtype=torch.float64)
# g tensor(4.9267, dtype=torch.float64)
# m tensor(1.5000, dtype=torch.float64)
