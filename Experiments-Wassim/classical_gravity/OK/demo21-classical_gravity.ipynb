# %% [markdown]
# # $\Phi$-SO demo

# %% [markdown]
# ## Packages import

# %%
# conda env
try:
    get_ipython().system('echo $CONDA_PREFIX')
except:
    pass
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/PhySO

# %%
try:
    # %matplotlib inline
    #get_ipython().run_line_magic('matplotlib', 'inline')
except:
    pass

# %%
# External packages
import torch
import numpy as np

# Pyplot
import matplotlib.pyplot as plt

# Internal code import
import physo
from physo.learn import monitoring
from physo.task  import benchmark

# %%
# Device
DEVICE = 'cpu'
if torch.cuda.is_available():
    DEVICE = 'cuda'
print(DEVICE)
# Out:
# cpu

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# ## Test case

# %%
data_size = int(1e3)

# %%
# Data points
m1  = np.random.uniform(0, 1, data_size)
m2  = np.random.uniform(0, 1, data_size)
r   = np.random.uniform(1, 4, data_size)
X_array = np.stack((m1, m2, r), axis=0)
G   = 1.184
y_array = m1*m2*G/r**2

# One of many symbolic solutions:
target_program_str = ["div", "mul", "mul", "m1", "m2", "G", "n2", "r",]
print(len(target_program_str))
# Out:
# 8

# %%
n_dim = X_array.shape[0]
fig, ax = plt.subplots(n_dim, 1, figsize=(10,5))
for i in range (n_dim):
    curr_ax = ax if n_dim==1 else ax[i]
    curr_ax.plot(X_array[i], y_array, 'k.',)
    curr_ax.set_xlabel("X[%i]"%(i))
    curr_ax.set_ylabel("y")
plt.show()

# %%
# ------ Vectors ------
# Stack of all input variables
X = torch.tensor(X_array).to(DEVICE)
# Output of symbolic function to guess
y = torch.tensor(y_array).to(DEVICE)

# ------ Constants ------
const1 = torch.tensor(np.array( 1.   )).to(DEVICE)
G      = torch.tensor(np.array( G    )).to(DEVICE)

# %% [markdown]
# ## Run config

# %% [markdown]
# ### Library config

# %%
# [length, mass, time]
args_make_tokens = {
                # operations
                "op_names"             : ["mul", "add", "sub", "div", "inv", "n2", "sqrt", "exp", "log", "sin", "cos"],
                "use_protected_ops"    : True,
                # input variables
                "input_var_ids"        : {"m1" : 0         , "m2" : 1         , "r" : 2         , },
                "input_var_units"      : {"m1" : [0, 1, 0] , "m2" : [0, 1, 0] , "r" : [1, 0, 0] , },
                "input_var_complexity" : {"m1" : 1.        , "m2" : 1.        , "r" : 1.        , },
                # constants
                "constants"            : {"1" : const1    ,},
                "constants_units"      : {"1" : [0, 0, 0] ,},
                "constants_complexity" : {"1" : 1.        ,},
                # free constants
                "free_constants"            : {"G"               ,},
                "free_constants_init_val"   : {"G" : 1.          ,},
                "free_constants_units"      : {"G" : [3, -1, -2] ,},
                "free_constants_complexity" : {"G" : 1.          ,},
                    }

library_config = {"args_make_tokens"  : args_make_tokens,
                  "superparent_units" : [1, 1, -2],
                  "superparent_name"  : "F",
                }

# %% [markdown]
# ### Learning config

# %%
reward_config = {
                 "reward_function"     : physo.physym.reward.SquashedNRMSE, 
                 "zero_out_unphysical" : True, # PHYSICALITY
                 "zero_out_duplicates" : False,
                 "keep_lowest_complexity_duplicate" : False,
                }

# %%
MAX_TRIAL_EXPRESSIONS = 2*1e6
BATCH_SIZE = int(1e4)
MAX_LENGTH = 35
GET_OPTIMIZER = lambda model : torch.optim.Adam(
                                    model.parameters(),                
                                    lr=0.0025, #0.001, #0.0050, #0.0005, #1,  #lr=0.0025
                                                )

# %%
learning_config = {
    # Batch related
    'batch_size'       : BATCH_SIZE,
    'max_time_step'    : MAX_LENGTH,
    'n_epochs'         : int(1e9), #int(MAX_TRIAL_EXPRESSIONS/BATCH_SIZE),
    # Loss related
    'gamma_decay'      : 0.7,
    'entropy_weight'   : 0.005,
    # Reward related
    'risk_factor'      : 0.05,
    'rewards_computer' : physo.physym.reward.make_RewardsComputer (**reward_config),
    # Optimizer
    'get_optimizer'    : GET_OPTIMIZER,
    'observe_units'    : True,
}

# %% [markdown]
# ### Free constant optimizer config

# %%
free_const_opti_args = {
            'loss'   : "MSE",
            'method' : 'LBFGS',
            'method_args': {
                        'n_steps' : 30,
                        'tol'     : 1e-8,
                        'lbfgs_func_args' : {
                            'max_iter'       : 4,
                            'line_search_fn' : "strong_wolfe",
                                             },
                            },
        }

# %% [markdown]
# ### Priors config

# %%
priors_config  = [
                #("UniformArityPrior", None),
                # LENGTH RELATED
                ("HardLengthPrior"  , {"min_length": 4, "max_length": MAX_LENGTH, }),
                ("SoftLengthPrior"  , {"length_loc": 8, "scale": 5, }),
                # RELATIONSHIPS RELATED
                ("NoUselessInversePrior"  , None),
                ("PhysicalUnitsPrior", {"prob_eps": np.finfo(np.float32).eps}), # PHYSICALITY
                #("NestedFunctions", {"functions":["exp",], "max_nesting" : 1}),
                #("NestedFunctions", {"functions":["log",], "max_nesting" : 1}),
                #("NestedTrigonometryPrior", {"max_nesting" : 1}),           
                #("OccurrencesPrior", {"targets" : ["1",], "max" : [3,] }),
                 ]

# %% [markdown]
# ### Cell config

# %%
cell_config = {
    "hidden_size" : 128,
    "n_layers"    : 1,
    "is_lobotomized" : False,
}

# %% [markdown]
# ### Logger

# %%
save_path_training_curves = 'classical_gravity_curves.png'
save_path_log             = 'classical_gravity.log'

run_logger     = monitoring.RunLogger(save_path = save_path_log, 
                                      do_save = True)

run_visualiser = monitoring.RunVisualiser (epoch_refresh_rate = 10,
                                           save_path = save_path_training_curves,
                                           do_show   = False,
                                           do_prints = True,
                                           do_save   = True, )

# %% [markdown]
# ### Run config

# %%
run_config = {
    "learning_config"      : learning_config,
    "reward_config"        : reward_config,
    "free_const_opti_args" : free_const_opti_args,
    "library_config"       : library_config,
    "priors_config"        : priors_config,
    "cell_config"          : cell_config,
    "run_logger"           : run_logger,
    "run_visualiser"       : run_visualiser,
}

# %% [markdown]
# ## Dummy epoch for prior tuning

# %%
benchmark.dummy_epoch(X, y, run_config)

# %% [markdown]
# ## Sanity checks

# %%
target_program = benchmark.sanity_check(X, y, run_config, 
                                        target_program_str = target_program_str,
                                        expected_ideal_reward = 1.,
                                       )
# Out:
# Data
# {'mul': 0, 'add': 1, 'sub': 2, 'div': 3, 'inv': 4, 'n2': 5, 'sqrt': 6, 'exp': 7, 'log': 8, 'sin': 9, 'cos': 10, '1': 11, 'G': 12, 'm1': 13, 'm2': 14, 'r': 15}
# -------------------------- Library -------------------------
# [mul add sub div inv n2 sqrt exp log sin cos 1 G m1 m2 r F dummy -]
# --------------------------- Prior --------------------------
# PriorCollection:
# - HardLengthPrior (min_length = 4, max_length = 35)
# - SoftLengthPrior (length_loc = 8, scale = 5)
# - NoUselessInversePrior (['inv', 'log', 'exp', 'n2', 'sqrt'] can not be child of ['inv', 'exp', 'log', 'sqrt', 'n2'])
# - PhysicalUnitsPrior
# -------------------------- Dataset -------------------------
# X        : torch.Size([3, 1000])
# y_target : torch.Size([1000])
# -------------------------- Programs ------------------------
# [['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ...
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']]
#
# -------------------------- Learning config ------------------------
# {'batch_size': 10000, 'max_time_step': 35, 'n_epochs': 1000000000, 'gamma_decay': 0.7, 'entropy_weight': 0.005, 'risk_factor': 0.05, 'rewards_computer': <function make_RewardsComputer.<locals>.<lambda> at 0x163739a60>, 'get_optimizer': <function <lambda> at 0x163739670>, 'observe_units': True}
# -------------------------- Cell ------------------------
# Cell(
#   (input_dense): Linear(in_features=81, out_features=128, bias=True)
#   (stacked_cells): ModuleList(
#     (0): LSTMCell(128, 128)
#   )
#   (output_dense): Linear(in_features=128, out_features=16, bias=True)
# )
# n_params= 144657
# config:
# {'hidden_size': 128, 'n_layers': 1, 'is_lobotomized': False}
# -------------------------- Reward config ------------------------
# {'reward_function': <function SquashedNRMSE at 0x127c33ee0>, 'zero_out_unphysical': True, 'zero_out_duplicates': False, 'keep_lowest_complexity_duplicate': False}
# -------------------------- Ideal reward ------------------------
# ---- Target ----
# Tokens in prefix notation:
# [div, mul, mul, m1, m2, G, n2, r]
# Raw expression ascii:
# G⋅m₁⋅m₂
# ───────
#     2
#    r
# Raw expression:
# Simplified expression:
# free const opti time = 1.722667 ms
# Ideal reward : 0.9999999999999998

# %% [markdown]
# ## Run

# %%
rewards, candidates = physo.fit (X, y, run_config,
                                stop_reward = 1., 
                                stop_after_n_epochs = 30)
# Out:
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/learn/monitoring.py:519: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   self.fig.savefig(self.save_path)
# =========== Epoch 00000 ===========
# -> Time 8.82 s
#
# Overall best  at R=0.595216
# -> Raw expression :
#         G⋅m₂⋅m₂
# ────────────────────────
#  2                     2
# r  + r⋅r + (-r - r + r)
#
# Best of epoch at R=0.595216
# -> Raw expression :
#         G⋅m₂⋅m₂
# ────────────────────────
#  2                     2
# r  + r⋅r + (-r - r + r)
#
#
# =========== Epoch 00001 ===========
# -> Time 9.79 s
#
# Overall best  at R=0.595216
# -> Raw expression :
#         G⋅m₂⋅m₂
# ────────────────────────
#  2                     2
# r  + r⋅r + (-r - r + r)
#
# Best of epoch at R=0.595216
# -> Raw expression :
#                               2
# ⎛  2    ⎛   0.5         ⎛1 ⎞⎞⎞
# ⎜m₂ ⋅log⎜cos   (1) + sin⎜──⎟⎟⎟
# ⎜       ⎜               ⎜ 2⎟⎟⎟
# ⎜       ⎝               ⎝1 ⎠⎠⎟
# ⎜────────────────────────────⎟
# ⎜           ⎛m₂⋅r⎞           ⎟
# ⎜           ⎜────⎟           ⎟
# ⎜           ⎜ 0.5⎟           ⎟
# ⎝           ⎝G   ⎠           ⎠
#
#
# =========== Epoch 00002 ===========
# -> Time 10.02 s
#
# Overall best  at R=1.000000
# -> Raw expression :
# m₁⋅m₂⋅r
# ───────
#  0.5
# 1     2
# ────⋅r
# ⎛G⎞
# ⎜─⎟
# ⎝r⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
# m₁⋅m₂⋅r
# ───────
#  0.5
# 1     2
# ────⋅r
# ⎛G⎞
# ⎜─⎟
# ⎝r⎠
#
#
# =========== Epoch 00003 ===========
# -> Time 9.75 s
#
# Overall best  at R=1.000000
# -> Raw expression :
# m₁⋅m₂⋅r
# ───────
#  0.5
# 1     2
# ────⋅r
# ⎛G⎞
# ⎜─⎟
# ⎝r⎠
#
# Best of epoch at R=0.523984
# -> Raw expression :
#       m₂⋅m₂
# ─────────────────
#  1    2
# ────⋅r ⋅(m₁ + m₂)
# G⋅m₁
#
#
# =========== Epoch 00004 ===========
# -> Time 9.75 s
#
# Overall best  at R=1.000000
# -> Raw expression :
# m₁⋅m₂⋅r
# ───────
#  0.5
# 1     2
# ────⋅r
# ⎛G⎞
# ⎜─⎟
# ⎝r⎠
#
# Best of epoch at R=0.595216
# -> Raw expression :
#                    2
# ⎛        m₂       ⎞
# ⎜─────────────────⎟
# ⎜⎛       r       ⎞⎟
# ⎜⎜───────────────⎟⎟
# ⎜⎜            0.5⎟⎟
# ⎜⎜⎛      ⎛ 1⎞⎞   ⎟⎟
# ⎜⎜⎜   1  ⎝ℯ ⎠⎟   ⎟⎟
# ⎝⎝⎝G⋅ℯ ⋅ℯ    ⎠   ⎠⎠
#
#
# =========== Epoch 00005 ===========
# -> Time 9.19 s
#
# Overall best  at R=1.000000
# -> Raw expression :
# m₁⋅m₂⋅r
# ───────
#  0.5
# 1     2
# ────⋅r
# ⎛G⎞
# ⎜─⎟
# ⎝r⎠
#
# Best of epoch at R=1.000000
# -> Raw expression :
#         m₁⋅m₂
# ──────────────────────
#    r
# 1⋅───⋅log(sin(sin(1)))
#   ⎛G⎞
#   ⎜─⎟
#   ⎝r⎠

# %% [markdown]
# ## Results

# %% [markdown]
# ### Run plot

# %%
run_visualiser.make_visualisation()
run_visualiser.save_visualisation()
run_visualiser.save_data()

# %% [markdown]
# ### Pareto Front

# %%
def plot_pareto_front(run_logger,
                      do_simplify                   = True,
                      show_superparent_at_beginning = True,
                      eq_text_size                  = 12,
                      delta_xlim                    = [0, 5 ],
                      delta_ylim                    = [0, 15],
                      frac_delta_equ                = [0.03, 0.03],
                      figsize                       = (20, 10),
                     ):

    pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

    pareto_front_rmse = pareto_front_rmse
    # Fig params
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    # enables new_dummy_symbol = "\square"
    plt.rc('text.latex', preamble=r'\usepackage{amssymb} \usepackage{xcolor}')
    plt.rc('font', size=32)

    # Fig
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'r-')
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'ro')

    # Limits
    xmin = pareto_front_complexities.min() + delta_xlim[0]
    xmax = pareto_front_complexities.max() + delta_xlim[1]
    ymin = pareto_front_rmse.min() + delta_ylim[0]
    ymax = pareto_front_rmse.max() + delta_ylim[1]
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    # Axes labels
    ax.set_xlabel("Expression complexity")
    ax.set_ylabel("RMSE")


    for i_prog in range (len(pareto_front_programs)):
        prog = pareto_front_programs[i_prog]

        text_pos  = [pareto_front_complexities[i_prog] + frac_delta_equ[0]*(xmax-xmin), 
                     pareto_front_rmse[i_prog]         + frac_delta_equ[1]*(ymax-ymin)]
        # Getting latex expr
        latex_str = prog.get_infix_latex(do_simplify = do_simplify)
        # Adding "superparent =" before program to make it pretty
        if show_superparent_at_beginning:
            latex_str = prog.library.superparent.name + ' =' + latex_str


        ax.text(text_pos[0], text_pos[1], f'${latex_str}$', size = eq_text_size)

# %%
plot_pareto_front(run_logger)

# %%
run_logger.get_pareto_front()

# %%
pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)

# %% [markdown]
# ### Symbolic equivalence

# %%
best_prog_sympy   = candidates[-1] .get_infix_sympy(do_simplify=True)
target_prog_sympy = target_program .get_infix_sympy(do_simplify=True)

# %%
target_prog_sympy

# %%
best_prog_sympy

# %%
target_prog_sympy == best_prog_sympy

# %%
hall_of_fame = run_logger.hall_of_fame

# %%
for i in range(len(hall_of_fame)):
    print(hall_of_fame[i].get_infix_sympy(do_simplify=False))

# %%
eq = hall_of_fame[i].get_infix_sympy(do_simplify=True)

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)
    print("g", prog.free_const_values[0])
    print("m", prog.free_const_values[1])
