# %% [markdown]
# # $\Phi$-SO demo

# %% [markdown]
# ## Packages import

# %%
# conda env
try:
    get_ipython().system('echo $CONDA_PREFIX')
except:
    pass
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/PhySO

# %%
try:
    # %matplotlib inline
    #get_ipython().run_line_magic('matplotlib', 'inline')
except:
    pass

# %%
# External packages
import torch
import numpy as np
import pandas as pd
import time
# Pyplot
import matplotlib.pyplot as plt

# Internal code import
import physo
from physo.learn import monitoring
from physo.task  import benchmark

# %%
# Device
DEVICE = 'cpu'
if torch.cuda.is_available():
    DEVICE = 'cuda'
print(DEVICE)
# Out:
# cpu

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# ## Test case

# %% [markdown]
# #### Target function and wrapper

# %%
# Target function
H0    = 73.3 #km/s/Mpc
Omega = 0.315
c = 3e5 # km/s

f_LCDM = lambda x: (H0**2)*(Omega*(x)**3 + 1 - Omega) # (H0**2)*Omega*x**3 + (H0**2)*(1 - Omega) # = c0*x**3 + c1

target_program_str = ["mul", "n2", "H0", "sub", "add", "mul", "Omega", "mul", "x", "n2", "x", "1", "Omega"]
print(len(target_program_str))

# %%
def my_torch_1D_integrate(f, a, b, N=100):
    space        = torch.linspace(a, b, N)
    int_on_space = f(space)
    res = torch.trapezoid(y=int_on_space, x=space,) 
    return res

# %%
def wrapper_func (func, X):
    z = X[0]
    H_func = lambda z: torch.sqrt(func(z+1))  # in Mpc
    integrand = lambda zp: 1/H_func(zp)
    integral  = torch.stack([my_torch_1D_integrate(integrand, 0, z_i, N=100) for z_i in z])
    dL = (1+z)*c*integral # in Mpc
    mu_z = 5*torch.log10(dL/1e-5) # 10 pc = 1e-5 Mpc
    return mu_z

# %% [markdown]
# #### Observational data

# %%
df = pd.read_csv("Scolnic_2018.txt", sep=" ", index_col=False)
df = df.sort_values(by="zcmb")

# %%
z_array  = df["zcmb"].to_numpy()
mu_array = df["mb"] + 19.253 # https://iopscience.iop.org/article/10.3847/2041-8213/ac5c5b

X_array = np.stack((z_array,), axis=0)
y_array = mu_array

# %%
n_dim = X_array.shape[0]
fig, ax = plt.subplots(n_dim, 1, figsize=(10,5))
for i in range (n_dim):
    curr_ax = ax if n_dim==1 else ax[i]
    curr_ax.plot(X_array[i], y_array, 'k.',)
    curr_ax.set_xlabel("X[%i]"%(i))
    curr_ax.set_ylabel("y")
plt.show()

# %%
# ------ Vectors ------
# Stack of all input variables
X = torch.tensor(X_array).to(DEVICE)
# Output of symbolic function to guess
y = torch.tensor(y_array).to(DEVICE)

# %%
plt.plot(X[0], y, "k.", label="Scolnic_2018")
plt.plot(X[0], wrapper_func(f_LCDM, X), "r-", label="LCDM")

# %% [markdown]
# #### Synthetic data

# %%
z_array  = np.linspace(0.01, 2.5, 1000)
X_array = np.stack((z_array,), axis=0)

# %%
# ------ Vectors ------
# Stack of all input variables
X = torch.tensor(X_array).to(DEVICE)
# Output of symbolic function to guess
y = wrapper_func(f_LCDM, X).to(DEVICE)

# %%
plt.plot(X[0], y, "k.", label="Synthetic LCDM")
plt.plot(X[0], wrapper_func(f_LCDM, X), "r-", label="LCDM")

# %% [markdown]
# #### Constants

# %%
# ------ Constants ------
const1 = torch.tensor(np.array(1.)).to(DEVICE)

# %% [markdown]
# ## Run config

# %% [markdown]
# ### Library config

# %%
args_make_tokens = {
                # operations
                "op_names"             : ["mul", "add", "sub", "div", "inv", "n2", "sqrt",], # "exp", "log", "sin", "cos"],
                "use_protected_ops"    : True,
                # input variables
                "input_var_ids"        : {"x" : 0         ,},
                "input_var_units"      : {"x" : [0, 0, 0] ,},
                "input_var_complexity" : {"x" : 1.        ,},
                # constants
                "constants"            : {"1" : const1    , },
                "constants_units"      : {"1" : [0, 0, 0] , },
                "constants_complexity" : {"1" : 1.        , },
                # free constants
                "free_constants"            : {"H0"              , "Omega"              ,},
                "free_constants_init_val"   : {"H0" : 1.         , "Omega" : 1.         ,},
                "free_constants_units"      : {"H0" : [0, -1, 0] , "Omega" : [0, 0, 0]  ,},
                "free_constants_complexity" : {"H0" : 1.         , "Omega" : 1.         ,},
                    }

library_config = {"args_make_tokens"  : args_make_tokens,
                  "superparent_units" : [0, -1, 0],
                  "superparent_name"  : "sqrtH",
                }

# %% [markdown]
# ### Free constant optimizer config

# %%
free_const_opti_args = {
            'loss'   : "MSE",
            'method' : 'LBFGS',
            'method_args': {
                        'n_steps' : 30,
                        'tol'     : 1e-6,
                        'lbfgs_func_args' : {
                            'max_iter'       : 4,
                            'line_search_fn' : "strong_wolfe",
                                             },
                            },
        }

# %% [markdown]
# ### Learning config

# %%
MAX_TRIAL_EXPRESSIONS = 2*1e6
BATCH_SIZE = int(1e3)
MAX_LENGTH = 35
GET_OPTIMIZER = lambda model : torch.optim.Adam(
                                    model.parameters(),                
                                    lr=0.0025, #0.001, #0.0050, #0.0005, #1,  #lr=0.0025
                                                )

# %%
reward_config = {
                 "reward_function"     : physo.physym.reward.SquashedNRMSE, # PHYSICALITY
                 "zero_out_unphysical" : True,
                 "zero_out_duplicates" : False,
                 "keep_lowest_complexity_duplicate" : False,
                }

# %%
learning_config = {
    # Batch related
    'batch_size'       : BATCH_SIZE,
    'max_time_step'    : MAX_LENGTH,
    'n_epochs'         : int(1e9), #int(MAX_TRIAL_EXPRESSIONS/BATCH_SIZE),
    # Loss related
    'gamma_decay'      : 0.7,
    'entropy_weight'   : 0.005,
    # Reward related
    'risk_factor'      : 0.05,
    'rewards_computer' : physo.physym.reward.make_RewardsComputer (**reward_config),
    # Optimizer
    'get_optimizer'    : GET_OPTIMIZER,
}

# %% [markdown]
# ### Priors config

# %%
priors_config  = [
                #("UniformArityPrior", None),
                # LENGTH RELATED
                ("HardLengthPrior"  , {"min_length": 4, "max_length": MAX_LENGTH, }),
                ("SoftLengthPrior"  , {"length_loc": 6, "scale": 5, }),
                # RELATIONSHIPS RELATED
                ("NoUselessInversePrior"  , None),
                ("PhysicalUnitsPrior", {"prob_eps": np.finfo(np.float32).eps}), # PHYSICALITY
                #("NestedFunctions", {"functions":["exp",], "max_nesting" : 1}),
                #("NestedFunctions", {"functions":["log",], "max_nesting" : 1}),
                #("NestedTrigonometryPrior", {"max_nesting" : 1}),
                ("OccurrencesPrior", {"targets" : ["1",], "max" : [4,] }),
                 ]

# %% [markdown]
# ### Cell config

# %%
cell_config = {
    "hidden_size" : 128,
    "n_layers"    : 1,
}

# %% [markdown]
# ### Logger

# %%
save_path_training_curves = 'demo_curves.png'
save_path_log             = 'demo.log'

run_logger     = monitoring.RunLogger(save_path = save_path_log, 
                                      do_save = True)

run_visualiser = monitoring.RunVisualiser (epoch_refresh_rate = 1,
                                           save_path = save_path_training_curves,
                                           do_show   = False,
                                           do_prints = True,
                                           do_save   = True, )

# %% [markdown]
# ### Run config

# %%
run_config = {
    "learning_config"      : learning_config,
    "reward_config"        : reward_config,
    "free_const_opti_args" : free_const_opti_args,
    "library_config"       : library_config,
    "priors_config"        : priors_config,
    "cell_config"          : cell_config,
    "run_logger"           : run_logger,
    "run_visualiser"       : run_visualiser,
}

# %% [markdown]
# ## Dummy epoch for prior tuning

# %%
benchmark.dummy_epoch(X, y, run_config)

# %% [markdown]
# ## Sanity checks

# %%
target_program = benchmark.sanity_check(X, y, run_config, target_program_str=target_program_str, expected_ideal_reward=1.)
# Out:
# Data
# {'mul': 0, 'add': 1, 'sub': 2, 'div': 3, 'inv': 4, 'n2': 5, 'sqrt': 6, '1': 7, 'H0': 8, 'Omega': 9, 'x': 10}
# -------------------------- Library -------------------------
# [mul add sub div inv n2 sqrt 1 H0 Omega x sqrtH dummy -]
# --------------------------- Prior --------------------------
# PriorCollection:
# - HardLengthPrior (min_length = 4, max_length = 35)
# - SoftLengthPrior (length_loc = 6, scale = 5)
# - NoUselessInversePrior (['inv', 'n2', 'sqrt'] can not be child of ['inv', 'sqrt', 'n2'])
# - PhysicalUnitsPrior
# - OccurrencesPrior (tokens ['1'] can be used [4] times max)
# -------------------------- Dataset -------------------------
# X        : torch.Size([1, 1000])
# y_target : torch.Size([1000])
# -------------------------- Programs ------------------------
# [['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ...
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']
#  ['dummy' '-' '-' ... '-' '-' '-']]
#
# -------------------------- Cell ------------------------
# Cell(
#   (input_dense): Linear(in_features=66, out_features=128, bias=True)
#   (stacked_cells): ModuleList(
#     (0): LSTMCell(128, 128)
#   )
#   (output_dense): Linear(in_features=128, out_features=11, bias=True)
# )
# n_params= 142092
# -------------------------- Ideal reward ------------------------
# ---- Target ----
# Tokens in prefix notation:
# [mul, n2, H0, sub, add, mul, Omega, mul, x, n2, x, 1, Omega]
# Raw expression ascii:
#   2 ⎛     2        ⎞
# H₀ ⋅⎝Ω⋅x⋅x  - Ω + 1⎠
# Raw expression:
# Simplified expression:
# Ideal reward : 0.5842251166481252
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 target_program = benchmark.sanity_check(X, y, run_config, target_program_str=target_program_str)
#
# File ~/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/task/benchmark.py:167, in sanity_check(X, y, run_config, target_program_str, expected_ideal_reward)
#     164 print("Ideal reward :", ideal_reward)
#     166 eps = 1e-5
# --> 167 assert (expected_ideal_reward - ideal_reward) <= 2*eps, 'Ideal reward should be >= %f +/- %f '% (expected_ideal_reward, eps)
#     169 return target_program
#
# AssertionError: Ideal reward should be >= 1.000000 +/- 0.000010

# %% [markdown]
# ## Run

# %%
rewards, candidates = physo.fit(X, y, candidate_wrapper = None, run_config)
# Out:
# =========== Epoch 00000 ===========
# -> Time 4.58 s
#
# Overall best  at R=0.840658
# -> Raw expression :
#                            2
#    ⎛               0.5    ⎞
#    ⎜⎛          0.5⎞       ⎟
#    ⎜⎜⎛     0.5⎞   ⎟       ⎟
# H₀⋅⎝⎝⎝Ω + x   ⎠   ⎠    + 1⎠
#
# Best of epoch at R=0.840658
# -> Raw expression :
#                            2
#    ⎛               0.5    ⎞
#    ⎜⎛          0.5⎞       ⎟
#    ⎜⎜⎛     0.5⎞   ⎟       ⎟
# H₀⋅⎝⎝⎝Ω + x   ⎠   ⎠    + 1⎠
#
#
# =========== Epoch 00001 ===========
# -> Time 10.48 s
#
# Overall best  at R=0.840658
# -> Raw expression :
#                            2
#    ⎛               0.5    ⎞
#    ⎜⎛          0.5⎞       ⎟
#    ⎜⎜⎛     0.5⎞   ⎟       ⎟
# H₀⋅⎝⎝⎝Ω + x   ⎠   ⎠    + 1⎠
#
# Best of epoch at R=0.814875
# -> Raw expression :
#                0.5
# ⎛      0.5    ⎞
# ⎝-Ω + x    + 1⎠
# ──────────────────
#        ⎛1 ⎞
#        ⎜──⎟
#        ⎝H₀⎠
#
#
# =========== Epoch 00002 ===========
# -> Time 11.47 s
#
# Overall best  at R=0.840658
# -> Raw expression :
#                            2
#    ⎛               0.5    ⎞
#    ⎜⎛          0.5⎞       ⎟
#    ⎜⎜⎛     0.5⎞   ⎟       ⎟
# H₀⋅⎝⎝⎝Ω + x   ⎠   ⎠    + 1⎠
#
# Best of epoch at R=0.791197
# -> Raw expression :
#         0.5
#      ⎛Ω⎞
# H₀ + ⎜─⎟   ⋅(H₀ + H₀)⋅(Ω + x)
#      ⎝x⎠
#
#
# =========== Epoch 00003 ===========
# -> Time 10.05 s
#
# Overall best  at R=0.846309
# -> Raw expression :
#                 1 - Ω
# H₀ + H₀ + H₀ + ───────
#                ⎛x + 1⎞
#                ⎜─────⎟
#                ⎝  H₀ ⎠
#
# Best of epoch at R=0.846309
# -> Raw expression :
#                 1 - Ω
# H₀ + H₀ + H₀ + ───────
#                ⎛x + 1⎞
#                ⎜─────⎟
#                ⎝  H₀ ⎠
#
#
# =========== Epoch 00004 ===========
# -> Time 10.04 s
#
# Overall best  at R=0.887985
# -> Raw expression :
#    ⎛            0.5    ⎞
#    ⎜⎛       0.5⎞       ⎟
#    ⎜⎜⎛ Ω⋅x ⎞   ⎟       ⎟
# H₀⋅⎜⎜⎜─────⎟   ⎟    + 1⎟
#    ⎜⎜⎜⎛ Ω ⎞⎟   ⎟       ⎟
#    ⎜⎜⎜⎜───⎟⎟   ⎟       ⎟
#    ⎝⎝⎝⎝1⋅Ω⎠⎠   ⎠       ⎠
#
# Best of epoch at R=0.887985
# -> Raw expression :
#    ⎛            0.5    ⎞
#    ⎜⎛       0.5⎞       ⎟
#    ⎜⎜⎛ Ω⋅x ⎞   ⎟       ⎟
# H₀⋅⎜⎜⎜─────⎟   ⎟    + 1⎟
#    ⎜⎜⎜⎛ Ω ⎞⎟   ⎟       ⎟
#    ⎜⎜⎜⎜───⎟⎟   ⎟       ⎟
#    ⎝⎝⎝⎝1⋅Ω⎠⎠   ⎠       ⎠
#
#
# =========== Epoch 00005 ===========
# -> Time 11.56 s
#
# Overall best  at R=0.887985
# -> Raw expression :
#    ⎛            0.5    ⎞
#    ⎜⎛       0.5⎞       ⎟
#    ⎜⎜⎛ Ω⋅x ⎞   ⎟       ⎟
# H₀⋅⎜⎜⎜─────⎟   ⎟    + 1⎟
#    ⎜⎜⎜⎛ Ω ⎞⎟   ⎟       ⎟
#    ⎜⎜⎜⎜───⎟⎟   ⎟       ⎟
#    ⎝⎝⎝⎝1⋅Ω⎠⎠   ⎠       ⎠
#
# Best of epoch at R=0.887985
# -> Raw expression :
#             1
# H₀ + ───────────────
#      ⎛          0.5⎞
#      ⎜⎛   1    ⎞   ⎟
#      ⎜⎜────────⎟   ⎟
#      ⎜⎜     0.5⎟   ⎟
#      ⎜⎜⎛Ω⋅x⎞   ⎟   ⎟
#      ⎜⎜⎜───⎟   ⎟   ⎟
#      ⎜⎝⎝ 1 ⎠   ⎠   ⎟
#      ⎜─────────────⎟
#      ⎝      H₀     ⎠
#
#
# =========== Epoch 00006 ===========
# -> Time 11.40 s
#
# Overall best  at R=0.887985
# -> Raw expression :
#    ⎛            0.5    ⎞
#    ⎜⎛       0.5⎞       ⎟
#    ⎜⎜⎛ Ω⋅x ⎞   ⎟       ⎟
# H₀⋅⎜⎜⎜─────⎟   ⎟    + 1⎟
#    ⎜⎜⎜⎛ Ω ⎞⎟   ⎟       ⎟
#    ⎜⎜⎜⎜───⎟⎟   ⎟       ⎟
#    ⎝⎝⎝⎝1⋅Ω⎠⎠   ⎠       ⎠
#
# Best of epoch at R=0.790029
# -> Raw expression :
#                  2
#    ⎛         0.5⎞
#    ⎜    ⎛ x ⎞   ⎟
# H₀⋅⎜Ω + ⎜───⎟   ⎟  + H₀
#    ⎜    ⎜⎛1⎞⎟   ⎟
#    ⎜    ⎜⎜─⎟⎟   ⎟
#    ⎝    ⎝⎝1⎠⎠   ⎠
#
#
# =========== Epoch 00007 ===========
# -> Time 13.69 s
#
# Overall best  at R=0.887985
# -> Raw expression :
#    ⎛            0.5    ⎞
#    ⎜⎛       0.5⎞       ⎟
#    ⎜⎜⎛ Ω⋅x ⎞   ⎟       ⎟
# H₀⋅⎜⎜⎜─────⎟   ⎟    + 1⎟
#    ⎜⎜⎜⎛ Ω ⎞⎟   ⎟       ⎟
#    ⎜⎜⎜⎜───⎟⎟   ⎟       ⎟
#    ⎝⎝⎝⎝1⋅Ω⎠⎠   ⎠       ⎠
#
# Best of epoch at R=0.802300
# -> Raw expression :
#    ⎛                       0.5⎞
#    ⎜     ⎛             0.5⎞   ⎟
# H₀⋅⎝-Ω + ⎝(x⋅(Ω⋅x + Ω))   ⎠   ⎠
#
#
# =========== Epoch 00008 ===========
# -> Time 13.26 s
#
# Overall best  at R=0.887985
# -> Raw expression :
#    ⎛            0.5    ⎞
#    ⎜⎛       0.5⎞       ⎟
#    ⎜⎜⎛ Ω⋅x ⎞   ⎟       ⎟
# H₀⋅⎜⎜⎜─────⎟   ⎟    + 1⎟
#    ⎜⎜⎜⎛ Ω ⎞⎟   ⎟       ⎟
#    ⎜⎜⎜⎜───⎟⎟   ⎟       ⎟
#    ⎝⎝⎝⎝1⋅Ω⎠⎠   ⎠       ⎠
#
# Best of epoch at R=0.797888
# -> Raw expression :
#    ⎛                 0.5⎞
#    ⎜    ⎛  1        ⎞   ⎟
# H₀⋅⎜Ω + ⎜─────⋅Ω⋅x⋅1⎟   ⎟
#    ⎝    ⎝Ω + Ω      ⎠   ⎠
#
#
# =========== Epoch 00009 ===========
# -> Time 13.01 s
#
# Overall best  at R=0.887985
# -> Raw expression :
#    ⎛            0.5    ⎞
#    ⎜⎛       0.5⎞       ⎟
#    ⎜⎜⎛ Ω⋅x ⎞   ⎟       ⎟
# H₀⋅⎜⎜⎜─────⎟   ⎟    + 1⎟
#    ⎜⎜⎜⎛ Ω ⎞⎟   ⎟       ⎟
#    ⎜⎜⎜⎜───⎟⎟   ⎟       ⎟
#    ⎝⎝⎝⎝1⋅Ω⎠⎠   ⎠       ⎠
#
# Best of epoch at R=0.787661
# -> Raw expression :
#   ⎛                 0.5⎞
#   ⎜    ⎛       1  1⎞   ⎟
# 1⋅⎜Ω + ⎜x + 1⋅───⋅─⎟   ⎟⋅H₀
#   ⎝    ⎝      1⋅Ω Ω⎠   ⎠
#
#
# =========== Epoch 00010 ===========
# -> Time 14.07 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
#
# =========== Epoch 00011 ===========
# -> Time 16.49 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.862251
# -> Raw expression :
#              x
# H₀ + ─────────────────
#      ⎛Ω⋅(Ω⋅Ω + Ω) + x⎞
#      ⎜───────────────⎟
#      ⎝      H₀⋅Ω     ⎠
#
#
# =========== Epoch 00012 ===========
# -> Time 15.62 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.887985
# -> Raw expression :
#    ⎛              0.5⎞
#    ⎜    ⎛     0.5⎞   ⎟
#    ⎜    ⎜⎛ x ⎞   ⎟   ⎟
# H₀⋅⎜Ω + ⎜⎜───⎟   ⎟   ⎟ + H₀ + H₀
#    ⎝    ⎝⎝Ω⋅Ω⎠   ⎠   ⎠
#
#
# =========== Epoch 00013 ===========
# -> Time 14.70 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.868896
# -> Raw expression :
#      ⎛         1     ⎞
# H₀⋅x⋅⎜Ω + ───────────⎟ + H₀ + H₀
#      ⎜            Ω⋅x⎟
#      ⎜    Ω + x + ───⎟
#      ⎝             Ω ⎠
#
#
# =========== Epoch 00014 ===========
# -> Time 14.52 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.879085
# -> Raw expression :
#             1
# H₀ + ────────────────
#      ⎛           0.5⎞
#      ⎜    (Ω⋅Ω⋅x)   ⎟
#      ⎜Ω + ──────────⎟
#      ⎜        Ω     ⎟
#      ⎜──────────────⎟
#      ⎝      H₀      ⎠
#
#
# =========== Epoch 00015 ===========
# -> Time 15.35 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.887985
# -> Raw expression :
#    ⎛                     0.5⎞
#    ⎜    ⎛       0.5     ⎞   ⎟
#    ⎜    ⎜      x        ⎟   ⎟
# H₀⋅⎜Ω + ⎜───────────────⎟   ⎟
#    ⎜    ⎜⎛Ω⋅(Ω + Ω + Ω)⎞⎟   ⎟
#    ⎜    ⎜⎜─────────────⎟⎟   ⎟
#    ⎝    ⎝⎝      Ω      ⎠⎠   ⎠
#
#
# =========== Epoch 00016 ===========
# -> Time 17.18 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.900463
# -> Raw expression :
#   H₀⋅Ω⋅x⋅x
# ─────────── + H₀
# 1⋅x⋅(Ω + x)
#
#
# =========== Epoch 00017 ===========
# -> Time 18.55 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.871274
# -> Raw expression :
#    ⎛     Ω⋅Ω⋅Ω⋅x ⎞
# H₀⋅⎜Ω + ─────────⎟ + H₀
#    ⎝    Ω⋅(Ω + x)⎠
#
#
# =========== Epoch 00018 ===========
# -> Time 15.91 s
#
# Overall best  at R=0.903966
# -> Raw expression :
#         H₀⋅x
# ─────────────────── + H₀
# ⎛x⋅(Ω + x + x + 1)⎞
# ⎜─────────────────⎟
# ⎝        Ω        ⎠
# ────────────────────────
#            Ω
#
# Best of epoch at R=0.887985
# -> Raw expression :
#                      0.5
#          ⎛       0.5⎞
# H₀⋅Ω⋅Ω⋅Ω⋅⎝(Ω⋅Ω⋅x)   ⎠
# ──────────────────────── + H₀
#            Ω
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 277 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 283 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 322 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 333 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 349 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# =========== Epoch 00019 ===========
# -> Time 17.16 s
#
# Overall best  at R=0.970543
# -> Raw expression :
#                      0.5
#    ⎛             0.5⎞
#    ⎜⎛        0.5⎞   ⎟
#    ⎜⎜⎛   0.5⎞   ⎟   ⎟
#    ⎜⎜⎜⎛x⎞   ⎟   ⎟   ⎟
#    ⎜⎜⎜⎜─⎟   ⎟   ⎟   ⎟
#    ⎜⎝⎝⎝Ω⎠   ⎠   ⎠   ⎟
# H₀⋅⎜────────────────⎟
#    ⎝      Ω⋅Ω       ⎠
#
# Best of epoch at R=0.970543
# -> Raw expression :
#                      0.5
#    ⎛             0.5⎞
#    ⎜⎛        0.5⎞   ⎟
#    ⎜⎜⎛   0.5⎞   ⎟   ⎟
#    ⎜⎜⎜⎛x⎞   ⎟   ⎟   ⎟
#    ⎜⎜⎜⎜─⎟   ⎟   ⎟   ⎟
#    ⎜⎝⎝⎝Ω⎠   ⎠   ⎠   ⎟
# H₀⋅⎜────────────────⎟
#    ⎝      Ω⋅Ω       ⎠
#
#
# =========== Epoch 00020 ===========
# -> Time 18.08 s
#
# Overall best  at R=0.970543
# -> Raw expression :
#                      0.5
#    ⎛             0.5⎞
#    ⎜⎛        0.5⎞   ⎟
#    ⎜⎜⎛   0.5⎞   ⎟   ⎟
#    ⎜⎜⎜⎛x⎞   ⎟   ⎟   ⎟
#    ⎜⎜⎜⎜─⎟   ⎟   ⎟   ⎟
#    ⎜⎝⎝⎝Ω⎠   ⎠   ⎠   ⎟
# H₀⋅⎜────────────────⎟
#    ⎝      Ω⋅Ω       ⎠
#
# Best of epoch at R=0.952304
# -> Raw expression :
#                            0.5
#           ⎛            0.5⎞
#           ⎜⎛       0.5⎞   ⎟
#      H₀⋅Ω⋅⎝⎝(Ω⋅Ω⋅x)   ⎠   ⎠
# H₀ + ─────────────────────────
#                  Ω
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 382 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 414 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 423 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# =========== Epoch 00021 ===========
# -> Time 17.73 s
#
# Overall best  at R=0.970543
# -> Raw expression :
#                      0.5
#    ⎛             0.5⎞
#    ⎜⎛        0.5⎞   ⎟
#    ⎜⎜⎛   0.5⎞   ⎟   ⎟
#    ⎜⎜⎜⎛x⎞   ⎟   ⎟   ⎟
#    ⎜⎜⎜⎜─⎟   ⎟   ⎟   ⎟
#    ⎜⎝⎝⎝Ω⎠   ⎠   ⎠   ⎟
# H₀⋅⎜────────────────⎟
#    ⎝      Ω⋅Ω       ⎠
#
# Best of epoch at R=0.970543
# -> Raw expression :
#                             0.5
# ⎛                       0.5⎞
# ⎜⎛                  0.5⎞   ⎟
# ⎜⎜⎛             0.5⎞   ⎟   ⎟         1
# ⎝⎝⎝(Ω⋅x⋅(Ω + Ω))   ⎠   ⎠   ⎠   ⋅Ω⋅1⋅────
#                                     ⎛Ω ⎞
#                                     ⎜──⎟
#                                     ⎝H₀⎠
#
#
# =========== Epoch 00022 ===========
# -> Time 16.89 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00023 ===========
# -> Time 17.69 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.985314
# -> Raw expression :
#                          0.5
#    ⎛                 0.5⎞
#    ⎜⎛            0.5⎞   ⎟
#    ⎜⎜⎛       0.5⎞   ⎟   ⎟
#    ⎜⎝⎝(x + x)   ⎠   ⎠   ⎟
# H₀⋅⎜────────────────────⎟    + H₀
#    ⎝        1⋅Ω         ⎠
#
#
# =========== Epoch 00024 ===========
# -> Time 17.16 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.989550
# -> Raw expression :
#    ⎛                           0.5⎞
#    ⎜           ⎛           0.5⎞   ⎟
#    ⎜           ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜           ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
#    ⎜     0.5   ⎜⎝⎝x   ⎠   ⎠   ⎟   ⎟
#    ⎜    Ω    + ⎜──────────────⎟   ⎟
#    ⎜           ⎝      Ω       ⎠   ⎟
# H₀⋅⎜Ω + ──────────────────────────⎟
#    ⎝                1             ⎠
#
#
# =========== Epoch 00025 ===========
# -> Time 16.72 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.932068
# -> Raw expression :
#                            0.5
# ⎛                      0.5⎞
# ⎜    ⎛             0.5⎞   ⎟
# ⎜    ⎜ 0.5   ⎛ 0.5⎞   ⎟   ⎟
# ⎝x + ⎝Ω   ⋅Ω⋅⎝x   ⎠   ⎠   ⎠   ⋅1⋅H₀
#
#
# =========== Epoch 00026 ===========
# -> Time 16.18 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.970966
# -> Raw expression :
#    ⎛                               0.5⎞
#    ⎜    ⎛                      0.5⎞   ⎟
#    ⎜    ⎜⎛                 0.5⎞   ⎟   ⎟
#    ⎜    ⎜⎜⎛        0.5    ⎞   ⎟   ⎟   ⎟
#    ⎜    ⎜⎜⎜⎛ 0.5  ⎞       ⎟   ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝x   ⋅x⎠   ⋅1⋅Ω⎠   ⎠   ⎠   ⎠
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 552 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 571 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 601 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 611 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 679 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 694 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 713 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 720 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# /Users/wtenachi/Documents/ASTRO_research/projects/AI_physicist/my_AI_physicist/PhySO/PhySO/physo/physym/reward.py:117: UserWarning: Unable to optimize.py free constants of prog 730 -> r = 0
#   warnings.warn("Unable to optimize.py free constants of prog %i -> r = 0"%(i))
# =========== Epoch 00027 ===========
# -> Time 18.39 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.988697
# -> Raw expression :
#                                           0.5
#    ⎛                                  0.5⎞
#    ⎜    ⎛                         0.5⎞   ⎟
#    ⎜    ⎜⎛              0.5      ⎞   ⎟   ⎟
#    ⎜    ⎜⎜⎛         0.5⎞      1  ⎟   ⎟   ⎟
# H₀⋅⎜Ω + ⎜⎜⎝(x⋅Ω⋅1⋅x)   ⎠   ⋅1⋅─⋅Ω⎟   ⎟   ⎟
#    ⎝    ⎝⎝                    Ω  ⎠   ⎠   ⎠
#
#
# =========== Epoch 00028 ===========
# -> Time 17.90 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.969732
# -> Raw expression :
#    ⎛                                  0.5⎞
#    ⎜        ⎛                 0.5    ⎞   ⎟
#    ⎜        ⎜⎛            0.5⎞       ⎟   ⎟
#    ⎜        ⎜⎜⎛     0.5  ⎞   ⎟       ⎟   ⎟
#    ⎜        ⎜⎜⎜⎛Ω⋅x⎞     ⎟   ⎟       ⎟   ⎟
# H₀⋅⎜Ω + Ω + ⎜⎜⎜⎜───⎟   ⋅1⎟   ⎟    + 1⎟   ⎟ + H₀
#    ⎝        ⎝⎝⎝⎝ Ω ⎠     ⎠   ⎠       ⎠   ⎠
#
#
# =========== Epoch 00029 ===========
# -> Time 17.31 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.988697
# -> Raw expression :
#                              0.5
#    ⎛                     0.5⎞
#    ⎜    ⎛      0.5      ⎞   ⎟
#    ⎜    ⎜⎛ 0.5⎞    1    ⎟   ⎟
#    ⎜Ω + ⎜⎝x   ⎠   ⋅─⋅1⋅1⎟   ⎟
#    ⎜    ⎝          1    ⎠   ⎟
# H₀⋅⎜────────────────────────⎟
#    ⎝           1            ⎠
#
#
# =========== Epoch 00030 ===========
# -> Time 19.42 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.986567
# -> Raw expression :
#                            0.5
#    ⎛                   0.5⎞
#    ⎜⎛            0.5  ⎞   ⎟
#    ⎜⎜      ⎛ 0.5⎞     ⎟   ⎟
#    ⎜⎜      ⎜x   ⎟     ⎟   ⎟
# H₀⋅⎜⎜Ω + 1⋅⎜────⎟   ⋅1⎟   ⎟
#    ⎝⎝      ⎝ Ω  ⎠     ⎠   ⎠
# ──────────────────────────────
#               1
#
#
# =========== Epoch 00031 ===========
# -> Time 15.38 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜              ⎛           0.5⎞   ⎟
#    ⎜        0.5   ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜  ⎛ 0.5⎞      ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅⎝Ω   ⎠    + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
# Best of epoch at R=0.988697
# -> Raw expression :
#                                0.5
#    ⎛                   0.5    ⎞
#    ⎜  ⎛            0.5⎞       ⎟
#    ⎜  ⎜  ⎛     0.5⎞   ⎟       ⎟
#    ⎜  ⎜Ω⋅⎝(Ω⋅x)   ⎠   ⎟       ⎟
# H₀⋅⎜Ω⋅⎜───────────────⎟    + 1⎟
#    ⎝  ⎝       1       ⎠       ⎠
#
#
# =========== Epoch 00032 ===========
# -> Time 17.54 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
#
# =========== Epoch 00033 ===========
# -> Time 14.59 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#                                 0.5
#           ⎛                 0.5⎞
#           ⎜⎛          0.5  ⎞   ⎟
#           ⎜⎜⎛     0.5⎞     ⎟   ⎟
#           ⎜⎝⎝(1⋅x)   ⎠   ⋅1⎠   ⎟
# H₀⋅Ω + H₀⋅⎜────────────────────⎟
#           ⎝         Ω          ⎠
#
#
# =========== Epoch 00034 ===========
# -> Time 15.85 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.988697
# -> Raw expression :
#                                       0.5
#    ⎛                              0.5⎞
#    ⎜    ⎛                     0.5⎞   ⎟
#    ⎜    ⎜⎛                0.5⎞   ⎟   ⎟
#    ⎜    ⎜⎜⎛       0.5    ⎞   ⎟   ⎟   ⎟
#    ⎜    ⎜⎜⎜⎛Ω    ⎞       ⎟   ⎟   ⎟   ⎟
# H₀⋅⎜Ω + ⎜⎜⎜⎜─ + 1⎟   ⋅1⋅x⎟   ⎟   ⎟   ⎟
#    ⎝    ⎝⎝⎝⎝1    ⎠       ⎠   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00035 ===========
# -> Time 17.02 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.975231
# -> Raw expression :
#                                            0.5
#    ⎛                                   0.5⎞
#    ⎜⎛                              0.5⎞   ⎟
#    ⎜⎜⎛                       0.5  ⎞   ⎟   ⎟
# H₀⋅⎝⎝⎝(Ω + Ω + x + x + 1 + 1)   ⋅1⎠   ⎠   ⎠
#
#
# =========== Epoch 00036 ===========
# -> Time 18.26 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.988717
# -> Raw expression :
#    ⎛                            0.5    ⎞
#    ⎜    ⎛               0.5    ⎞       ⎟
#    ⎜    ⎜⎛          0.5⎞       ⎟       ⎟
#    ⎜    ⎜⎜⎛     0.5⎞   ⎟       ⎟       ⎟
# H₀⋅⎝Ω⋅Ω⋅⎝⎝⎝(Ω⋅x)   ⎠   ⎠   ⋅1⋅Ω⎠    + 1⎠
#
#
# =========== Epoch 00037 ===========
# -> Time 17.86 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.975231
# -> Raw expression :
#                                      0.5
#    ⎛                             0.5⎞
#    ⎜⎛                        0.5⎞   ⎟
#    ⎜⎜⎛                   0.5⎞   ⎟   ⎟
# H₀⋅⎝⎝⎝(Ω + (Ω + x⋅1⋅1)⋅1)   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00038 ===========
# -> Time 18.74 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.986567
# -> Raw expression :
#                                 0.5
#    ⎛                        0.5⎞
#    ⎜⎛               0.5    ⎞   ⎟
#    ⎜⎜  ⎛        0.5⎞       ⎟   ⎟
#    ⎜⎜  ⎜ 0.5   x   ⎟       ⎟   ⎟
# H₀⋅⎜⎜Ω⋅⎜x    + ────⎟    + 1⎟   ⎟
#    ⎝⎝  ⎝       Ω⋅1 ⎠       ⎠   ⎠
#
#
# =========== Epoch 00039 ===========
# -> Time 20.34 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.967418
# -> Raw expression :
#                                   0.5
#    ⎛                        0.5  ⎞
#    ⎜⎛                   0.5⎞     ⎟
# H₀⋅⎝⎝((Ω + x + 1 + 1)⋅1)   ⎠   ⋅1⎠    + H₀
#
#
# =========== Epoch 00040 ===========
# -> Time 17.68 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.977519
# -> Raw expression :
#                                         0.5
#    ⎛                                0.5⎞
#    ⎜⎛                       0.5    ⎞   ⎟
#    ⎜⎜⎛                  0.5⎞       ⎟   ⎟
#    ⎜⎜⎜⎛             0.5⎞   ⎟       ⎟   ⎟
# H₀⋅⎝⎝⎝⎝Ω⋅x⋅(Ω + 1⋅1)   ⎠   ⎠    + 1⎠   ⎠
#
#
# =========== Epoch 00041 ===========
# -> Time 19.69 s
#
# Overall best  at R=0.989688
# -> Raw expression :
#    ⎛                        0.5⎞
#    ⎜    ⎛               0.5⎞   ⎟
#    ⎜    ⎜  ⎛      0.5  ⎞   ⎟   ⎟
#    ⎜    ⎜  ⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝1⋅⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠ + H₀
#
# Best of epoch at R=0.982417
# -> Raw expression :
#                                   0.5
#    ⎛                          0.5⎞
#    ⎜⎛                     0.5⎞   ⎟
#    ⎜⎜⎛                0.5⎞   ⎟   ⎟
#    ⎜⎜⎜⎛           0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝⎝⎝⎝x + (x⋅1⋅Ω)   ⎠   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00042 ===========
# -> Time 21.23 s
#
# Overall best  at R=0.993321
# -> Raw expression :
#    ⎛                                        0.5    ⎞
#    ⎜    ⎛⎛                    0.5       ⎞  ⎞       ⎟
#    ⎜    ⎜⎜⎛               0.5⎞          ⎟  ⎟       ⎟
#    ⎜    ⎜⎜⎜⎛          0.5⎞   ⎟          ⎟  ⎟       ⎟
#    ⎜    ⎜⎜⎜⎜⎛     0.5⎞   ⎟   ⎟       0.5⎟  ⎟       ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝⎝(x⋅1)   ⎠   ⎠   ⎠    + 1   ⎠⋅1⎠    + 1⎠
#
# Best of epoch at R=0.993321
# -> Raw expression :
#    ⎛                                        0.5    ⎞
#    ⎜    ⎛⎛                    0.5       ⎞  ⎞       ⎟
#    ⎜    ⎜⎜⎛               0.5⎞          ⎟  ⎟       ⎟
#    ⎜    ⎜⎜⎜⎛          0.5⎞   ⎟          ⎟  ⎟       ⎟
#    ⎜    ⎜⎜⎜⎜⎛     0.5⎞   ⎟   ⎟       0.5⎟  ⎟       ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝⎝(x⋅1)   ⎠   ⎠   ⎠    + 1   ⎠⋅1⎠    + 1⎠
#
#
# =========== Epoch 00043 ===========
# -> Time 21.65 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
#
# =========== Epoch 00044 ===========
# -> Time 20.63 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989682
# -> Raw expression :
# ⎛                                     0.5⎞
# ⎜    ⎛                            0.5⎞   ⎟
# ⎜    ⎜⎛                       0.5⎞   ⎟   ⎟
# ⎜    ⎜⎜      0.5 ⎛        0.5⎞   ⎟   ⎟   ⎟
# ⎜    ⎜⎜⎛ 0.5⎞    ⎜⎛ 0.5  ⎞   ⎟   ⎟   ⎟   ⎟
# ⎝Ω + ⎝⎝⎝x   ⎠   ⋅⎝⎝Ω   ⋅Ω⎠   ⎠   ⎠   ⎠   ⎠⋅1⋅H₀
#
#
# =========== Epoch 00045 ===========
# -> Time 24.47 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.975237
# -> Raw expression :
#                                           0.5
#    ⎛                                  0.5⎞
#    ⎜⎛⎛                         0.5⎞  ⎞   ⎟
#    ⎜⎜⎜    ⎛                0.5⎞   ⎟  ⎟   ⎟
#    ⎜⎜⎜    ⎜      ⎛ 0.5    ⎞   ⎟   ⎟  ⎟   ⎟
# H₀⋅⎝⎝⎝Ω + ⎝Ω⋅Ω + ⎝Ω    + x⎠   ⎠   ⎠⋅1⎠   ⎠
#
#
# =========== Epoch 00046 ===========
# -> Time 23.79 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.977050
# -> Raw expression :
#                                              0.5
#    ⎛                             0.5        ⎞
#    ⎜    ⎛                    0.5⎞           ⎟
#    ⎜    ⎜⎛               0.5⎞   ⎟           ⎟
# H₀⋅⎝Ω + ⎝⎝(Ω + x + 1 + 1)   ⎠   ⎠    + 1 + 1⎠
#
#
# =========== Epoch 00047 ===========
# -> Time 24.91 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.987604
# -> Raw expression :
#                                         0.5
#    ⎛                                0.5⎞
#    ⎜    ⎛                     0.5  ⎞   ⎟
#    ⎜    ⎜⎛                0.5⎞     ⎟   ⎟
#    ⎜    ⎜⎜⎛           0.5⎞   ⎟     ⎟   ⎟
#    ⎜    ⎜⎜⎜⎛  ⎛    x⎞⎞   ⎟   ⎟     ⎟   ⎟
# H₀⋅⎜Ω + ⎜⎜⎜⎜x⋅⎜Ω + ─⎟⎟   ⎟   ⎟   ⋅1⎟   ⎟
#    ⎝    ⎝⎝⎝⎝  ⎝    Ω⎠⎠   ⎠   ⎠     ⎠   ⎠
# ───────────────────────────────────────────
#                      1
#
#
# =========== Epoch 00048 ===========
# -> Time 27.97 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.985345
# -> Raw expression :
#    ⎛                                  0.5    ⎞
#    ⎜             ⎛                0.5⎞       ⎟
#    ⎜             ⎜⎛           0.5⎞   ⎟       ⎟
#    ⎜             ⎜⎜⎛      0.5⎞   ⎟   ⎟       ⎟
#    ⎜         0.5 ⎜⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟       ⎟
# H₀⋅⎝Ω + Ω + 1   ⋅⎝⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠    + 1⎠
#
#
# =========== Epoch 00049 ===========
# -> Time 30.80 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.975037
# -> Raw expression :
#                                          0.5
#    ⎛⎛                             0.5⎞  ⎞
#    ⎜⎜    ⎛                    0.5⎞   ⎟  ⎟
#    ⎜⎜    ⎜⎛               0.5⎞   ⎟   ⎟  ⎟
# H₀⋅⎝⎝Ω + ⎝⎝(Ω⋅x⋅x + Ω + x)   ⎠   ⎠   ⎠⋅1⎠
#
#
# =========== Epoch 00050 ===========
# -> Time 25.29 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.993321
# -> Raw expression :
#    ⎛                                 0.5⎞
#    ⎜    ⎛                    0.5    ⎞   ⎟
#    ⎜    ⎜⎛               0.5⎞       ⎟   ⎟
#    ⎜    ⎜⎜⎛          0.5⎞   ⎟       ⎟   ⎟
#    ⎜    ⎜⎜⎜⎛ 0.5    ⎞   ⎟   ⎟       ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝x   ⋅1⋅1⎠   ⎠   ⎠    + 1⎠   ⎠
#
#
# =========== Epoch 00051 ===========
# -> Time 26.26 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.984836
# -> Raw expression :
#                                      0.5
#    ⎛                             0.5⎞
#    ⎜⎛                    0.5    ⎞   ⎟
#    ⎜⎜⎛             0.5  ⎞       ⎟   ⎟
# H₀⋅⎝⎝⎝(Ω⋅x⋅(Ω + x))   ⋅1⎠    + 1⎠   ⎠
#
#
# =========== Epoch 00052 ===========
# -> Time 26.27 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.988556
# -> Raw expression :
#    ⎛            ⎛                                0.5⎞  ⎞
#    ⎜            ⎜    ⎛                       0.5⎞   ⎟  ⎟
#    ⎜            ⎜    ⎜    ⎛              0.5⎞   ⎟   ⎟  ⎟
#    ⎜            ⎜    ⎜    ⎜        ⎛ 0.5⎞   ⎟   ⎟   ⎟  ⎟
# H₀⋅⎝Ω + Ω + Ω + ⎝Ω + ⎝Ω + ⎝Ω + Ω + ⎝x   ⎠   ⎠   ⎠   ⎠⋅1⎠
#
#
# =========== Epoch 00053 ===========
# -> Time 26.90 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.977006
# -> Raw expression :
# ⎛                                      0.5  ⎞
# ⎜    ⎛                             0.5⎞     ⎟
# ⎜    ⎜⎛                        0.5⎞   ⎟     ⎟
# ⎜    ⎜⎜⎛                   0.5⎞   ⎟   ⎟     ⎟
# ⎝Ω + ⎝⎝⎝(Ω + (Ω + x + x)⋅1)   ⎠   ⎠   ⎠   ⋅1⎠⋅1⋅H₀
#
#
# =========== Epoch 00054 ===========
# -> Time 27.66 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.987305
# -> Raw expression :
#                   0.5
# ⎛             0.5⎞
# ⎜⎛        0.5⎞   ⎟
# ⎜⎜⎛ 0.5  ⎞   ⎟   ⎟
# ⎝⎝⎝x   ⋅1⎠   ⎠   ⎠   ⋅Ω⋅Ω⋅1⋅H₀ + H₀
#
#
# =========== Epoch 00055 ===========
# -> Time 27.51 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.982110
# -> Raw expression :
#                                       0.5
# ⎛                               0.5  ⎞
# ⎜    ⎛                      0.5⎞     ⎟
# ⎜    ⎜    ⎛             0.5⎞   ⎟     ⎟
# ⎝Ω + ⎝Ω + ⎝(Ω⋅(Ω + x⋅1))   ⎠   ⎠   ⋅1⎠   ⋅1⋅H₀
#
#
# =========== Epoch 00056 ===========
# -> Time 29.56 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989175
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜    ⎛                     0.5⎞   ⎟
#    ⎜    ⎜          ⎛      0.5⎞   ⎟   ⎟
#    ⎜    ⎜          ⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝Ω⋅Ω + Ω + ⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00057 ===========
# -> Time 30.35 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.988104
# -> Raw expression :
#    ⎛                                  0.5⎞
#    ⎜    ⎛                         0.5⎞   ⎟
#    ⎜    ⎜⎛                0.5    ⎞   ⎟   ⎟
#    ⎜    ⎜⎜    ⎛       0.5⎞       ⎟   ⎟   ⎟
#    ⎜    ⎜⎝Ω + ⎝(x + x)   ⎠    + 1⎠   ⎟   ⎟
# H₀⋅⎜Ω + ⎜────────────────────────────⎟   ⎟ + H₀
#    ⎝    ⎝             1              ⎠   ⎠
#
#
# =========== Epoch 00058 ===========
# -> Time 27.63 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.986567
# -> Raw expression :
#                                      0.5
#    ⎛                           0.5  ⎞
#    ⎜⎛                      0.5⎞     ⎟
#    ⎜⎜    ⎛             0.5⎞   ⎟     ⎟
# H₀⋅⎝⎝Ω + ⎝(Ω⋅x⋅1⋅Ω + x)   ⎠   ⎠   ⋅1⎠
#
#
# =========== Epoch 00059 ===========
# -> Time 26.69 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.985099
# -> Raw expression :
#    ⎛                                   0.5⎞
#    ⎜    ⎛                          0.5⎞   ⎟
#    ⎜    ⎜⎛                     0.5⎞   ⎟   ⎟
#    ⎜    ⎜⎜⎛    ⎛ 0.5    0.5⎞  ⎞   ⎟   ⎟   ⎟
#    ⎜    ⎜⎜⎜Ω + ⎝x    + x   ⎠⋅1⎟   ⎟   ⎟   ⎟
# H₀⋅⎜Ω + ⎜⎜⎜───────────────────⎟   ⎟   ⎟   ⎟
#    ⎝    ⎝⎝⎝         Ω         ⎠   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00060 ===========
# -> Time 27.30 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.986982
# -> Raw expression :
# ⎛                                0.5⎞
# ⎜            ⎛               0.5⎞   ⎟
# ⎜            ⎜⎛          0.5⎞   ⎟   ⎟
# ⎜            ⎜⎜⎛     0.5⎞   ⎟   ⎟   ⎟
# ⎝Ω + Ω + Ω + ⎝⎝⎝Ω + x   ⎠   ⎠   ⎠   ⎠⋅1⋅H₀
#
#
# =========== Epoch 00061 ===========
# -> Time 30.48 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.984250
# -> Raw expression :
# ⎛                     0.5    ⎞
# ⎜  ⎛        0.5      ⎞       ⎟
# ⎜  ⎜       x         ⎟       ⎟
# ⎜Ω⋅⎜─────────────────⎟    + 1⎟⋅1⋅H₀
# ⎜  ⎜              0.5⎟       ⎟
# ⎜  ⎜  ⎛       0.5⎞   ⎟       ⎟
# ⎝  ⎝Ω⋅⎝(Ω + x)   ⎠   ⎠       ⎠
#
#
# =========== Epoch 00062 ===========
# -> Time 28.20 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.970543
# -> Raw expression :
#                            0.5
#    ⎛             0.5      ⎞
#    ⎜⎛        0.5⎞         ⎟
#    ⎜⎜  ⎛ 0.5⎞   ⎟         ⎟
# H₀⋅⎝⎝Ω⋅⎝x   ⎠   ⎠   ⋅1⋅1⋅Ω⎠
#
#
# =========== Epoch 00063 ===========
# -> Time 24.26 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.988697
# -> Raw expression :
#                                       0.5
#    ⎛                          0.5    ⎞
#    ⎜    ⎛                 0.5⎞       ⎟
#    ⎜    ⎜⎛ 0.5 ⎛ 0.5    ⎞⎞   ⎟       ⎟
# H₀⋅⎝Ω + ⎝⎝x   ⋅⎝Ω    + 1⎠⎠   ⎠    + 1⎠
#
#
# =========== Epoch 00064 ===========
# -> Time 27.51 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛⎛                            0.5⎞      ⎞
#    ⎜⎜            ⎛           0.5⎞   ⎟      ⎟
#    ⎜⎜            ⎜⎛      0.5⎞   ⎟   ⎟      ⎟
#    ⎜⎜            ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟      ⎟
# H₀⋅⎝⎝Ω + Ω + Ω + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠⋅1 + 1⎠ + H₀
#
#
# =========== Epoch 00065 ===========
# -> Time 33.94 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.993101
# -> Raw expression :
# ⎛                                    0.5⎞
# ⎜    ⎛                           0.5⎞   ⎟
# ⎜    ⎜⎛                      0.5⎞   ⎟   ⎟
# ⎜    ⎜⎜⎛                 0.5⎞   ⎟   ⎟   ⎟
# ⎜    ⎜⎜⎜⎛            0.5⎞   ⎟   ⎟   ⎟   ⎟
# ⎜    ⎜⎜⎜⎜⎛     0.5  ⎞   ⎟   ⎟   ⎟   ⎟   ⎟
# ⎝Ω + ⎝⎝⎝⎝⎝Ω⋅Ω⋅x   ⋅x⎠   ⎠   ⎠   ⎠   ⎠   ⎠⋅1⋅H₀
#
#
# =========== Epoch 00066 ===========
# -> Time 27.68 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.986567
# -> Raw expression :
#                                 0.5
# ⎛                           0.5⎞
# ⎜⎛                    0.5  ⎞   ⎟
# ⎜⎜        ⎛     0.5  ⎞     ⎟   ⎟
# ⎝⎝Ω + Ω + ⎝(x⋅1)   ⋅1⎠   ⋅1⎠   ⎠   ⋅1⋅H₀
#
#
# =========== Epoch 00067 ===========
# -> Time 27.59 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.983200
# -> Raw expression :
#                                     0.5
#    ⎛                            0.5⎞
#    ⎜    ⎛                   0.5⎞   ⎟
#    ⎜    ⎜⎛     0.5  0.5   1⎞   ⎟   ⎟
# H₀⋅⎜Ω + ⎜⎜1 + x   ⋅1   ⋅1⋅─⎟   ⎟   ⎟
#    ⎝    ⎝⎝                Ω⎠   ⎠   ⎠
#
#
# =========== Epoch 00068 ===========
# -> Time 31.33 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.977239
# -> Raw expression :
#    ⎛                                       0.5⎞
#    ⎜    ⎛                          0.5    ⎞   ⎟
#    ⎜    ⎜⎛⎛                 0.5⎞  ⎞       ⎟   ⎟
#    ⎜    ⎜⎜⎜    ⎛        0.5⎞   ⎟  ⎟       ⎟   ⎟
#    ⎜    ⎜⎜⎜    ⎜⎛ 0.5  ⎞   ⎟   ⎟  ⎟       ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝⎝Ω + ⎝⎝x   ⋅x⎠   ⎠   ⎠⋅1⎠    + 1⎠   ⎠
#
#
# =========== Epoch 00069 ===========
# -> Time 28.60 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
# ⎛                      0.5⎞
# ⎜    ⎛             0.5⎞   ⎟
# ⎜    ⎜⎛      0.5  ⎞   ⎟   ⎟
# ⎜    ⎜⎜⎛ 0.5⎞     ⎟   ⎟   ⎟
# ⎝Ω + ⎝⎝⎝x   ⎠   ⋅1⎠   ⎠   ⎠⋅(1 + 1)⋅1⋅H₀ + H₀
#
#
# =========== Epoch 00070 ===========
# -> Time 26.38 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.988697
# -> Raw expression :
#                             0.5
#   ⎛                     0.5⎞
#   ⎜    ⎛            0.5⎞   ⎟
#   ⎜    ⎜⎛     0.5  ⎞   ⎟   ⎟
# 1⋅⎝Ω + ⎝⎝(Ω⋅x)   ⋅1⎠   ⎠   ⎠   ⋅1⋅1⋅H₀
#
#
# =========== Epoch 00071 ===========
# -> Time 29.26 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                              0.5          ⎞
#    ⎜            ⎛             0.5⎞             ⎟
#    ⎜            ⎜⎛        0.5⎞   ⎟             ⎟
#    ⎜            ⎜⎜⎛ 0.5  ⎞   ⎟   ⎟             ⎟
# H₀⋅⎝Ω + Ω + Ω + ⎝⎝⎝x   ⋅1⎠   ⎠   ⎠   ⋅1 + 1 + 1⎠
#
#
# =========== Epoch 00072 ===========
# -> Time 29.42 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛  ⎛                    0.5⎞          ⎞
#    ⎜  ⎜    ⎛           0.5⎞   ⎟          ⎟
#    ⎜  ⎜    ⎜⎛      0.5⎞   ⎟   ⎟          ⎟
#    ⎜  ⎜    ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟          ⎟
# H₀⋅⎝1⋅⎝Ω + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠⋅1 + 1 + 1⎠
#
#
# =========== Epoch 00073 ===========
# -> Time 22.15 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.984507
# -> Raw expression :
#                           0.5
# ⎛                     0.5⎞
# ⎜⎛⎛        0.5    ⎞  ⎞   ⎟
# ⎜⎜⎜⎛   0.5⎞       ⎟  ⎟   ⎟
# ⎝⎝⎝⎝Ω⋅x   ⎠    + 1⎠⋅1⎠   ⎠   ⋅1⋅1⋅H₀
#
#
# =========== Epoch 00074 ===========
# -> Time 25.75 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                                0.5⎞
#    ⎜    ⎛                     0.5  ⎞   ⎟
#    ⎜    ⎜⎛                0.5⎞     ⎟   ⎟
#    ⎜    ⎜⎜⎛         0.5  ⎞   ⎟     ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝⎝(x⋅1⋅1⋅Ω)   ⋅1⎠   ⎠   ⋅1⎠   ⎠
#
#
# =========== Epoch 00075 ===========
# -> Time 29.25 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                         0.5    ⎞
#    ⎜    ⎛                0.5⎞       ⎟
#    ⎜    ⎜⎛           0.5⎞   ⎟       ⎟
#    ⎜    ⎜⎜⎛ 0.5  0.5⎞   ⎟   ⎟    1  ⎟
# H₀⋅⎜1 + ⎝⎝⎝Ω   ⋅x   ⎠   ⎠   ⎠   ⋅─⋅1⎟ + H₀
#    ⎝                             Ω  ⎠
#
#
# =========== Epoch 00076 ===========
# -> Time 31.63 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
# ⎛                             0.5⎞
# ⎜    ⎛                    0.5⎞   ⎟
# ⎜    ⎜⎛               0.5⎞   ⎟   ⎟
# ⎜    ⎜⎜⎛          0.5⎞   ⎟   ⎟   ⎟
# ⎜    ⎜⎜⎜  ⎛ 0.5  ⎞   ⎟   ⎟   ⎟   ⎟
# ⎝Ω + ⎝⎝⎝1⋅⎝1   ⋅x⎠   ⎠   ⎠   ⎠   ⎠⋅1⋅H₀
#
#
# =========== Epoch 00077 ===========
# -> Time 29.21 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                            0.5⎞
#    ⎜        ⎛               0.5⎞   ⎟
#    ⎜        ⎜⎛          0.5⎞   ⎟   ⎟
#    ⎜        ⎜⎜    ⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω + Ω + ⎝⎝1⋅1⋅⎝x   ⎠   ⎠   ⎠   ⎠ + H₀
#
#
# =========== Epoch 00078 ===========
# -> Time 29.51 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.993515
# -> Raw expression :
#    ⎛                                     0.5⎞
#    ⎜    ⎛                  0.5          ⎞   ⎟
#    ⎜    ⎜⎛             0.5⎞             ⎟   ⎟
#    ⎜    ⎜⎜⎛        0.5⎞   ⎟             ⎟   ⎟
#    ⎜    ⎜⎜⎜⎛ 0.5  ⎞   ⎟   ⎟             ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝x   ⋅1⎠   ⎠   ⎠   ⋅1 + 1 + 1⎠   ⎠
#
#
# =========== Epoch 00079 ===========
# -> Time 31.04 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
# ⎛                         0.5    ⎞
# ⎜    ⎛                0.5⎞       ⎟
# ⎜    ⎜⎛           0.5⎞   ⎟       ⎟
# ⎜    ⎜⎜ 0.5 ⎛ 0.5⎞   ⎟   ⎟       ⎟
# ⎝Ω + ⎝⎝1   ⋅⎝x   ⎠   ⎠   ⎠    + 1⎠⋅1⋅H₀
#
#
# =========== Epoch 00080 ===========
# -> Time 23.54 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                                  0.5⎞
#    ⎜        ⎛                     0.5⎞   ⎟
#    ⎜        ⎜⎛            0.5    ⎞   ⎟   ⎟
#    ⎜        ⎜⎜⎛       0.5⎞       ⎟   ⎟   ⎟
# H₀⋅⎝Ω + Ω + ⎝⎝⎝(x⋅1⋅1)   ⎠   ⋅1⋅1⎠   ⎠   ⎠
#
#
# =========== Epoch 00081 ===========
# -> Time 28.16 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.988003
# -> Raw expression :
#    ⎛                              0.5⎞
#    ⎜    ⎛                     0.5⎞   ⎟
#    ⎜    ⎜⎛            0.5    ⎞   ⎟   ⎟
#    ⎜    ⎜⎜    ⎛ 0.5  ⎞       ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝Ω + ⎝x   ⋅1⎠    + 1⎠   ⎠   ⎠ + H₀
#
#
# =========== Epoch 00082 ===========
# -> Time 27.66 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.993321
# -> Raw expression :
#    ⎛                                0.5        ⎞
#    ⎜    ⎛                0.5       ⎞           ⎟
#    ⎜    ⎜⎛           0.5⎞          ⎟           ⎟
#    ⎜    ⎜⎜⎛      0.5⎞   ⎟          ⎟           ⎟
#    ⎜    ⎜⎜⎜⎛ 0.5⎞   ⎟   ⎟       0.5⎟           ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝x   ⎠   ⎠   ⎠    + 1   ⎠   ⋅1⋅1 + 1⎠
#
#
# =========== Epoch 00083 ===========
# -> Time 27.13 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.986567
# -> Raw expression :
#                               0.5
# ⎛                       0.5  ⎞
# ⎜⎛          0.5        ⎞     ⎟
# ⎜⎜    ⎛ 0.5⎞           ⎟     ⎟
# ⎝⎝Ω + ⎝x   ⎠    + 1 + 1⎠   ⋅1⎠   ⋅1⋅H₀
#
#
# =========== Epoch 00084 ===========
# -> Time 30.83 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#                  ⎛                      0.5    ⎞
#                  ⎜      ⎛           0.5⎞       ⎟
#                  ⎜      ⎜⎛      0.5⎞   ⎟       ⎟
#                  ⎜      ⎜⎜⎛ 0.5⎞   ⎟   ⎟       ⎟
# H₀ + (1⋅H₀ + H₀)⋅⎝Ω⋅1 + ⎝⎝⎝x   ⎠   ⎠   ⎠    + 1⎠
#
#
# =========== Epoch 00085 ===========
# -> Time 34.39 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                              0.5  ⎞
#    ⎜    ⎛                   0.5  ⎞     ⎟
#    ⎜    ⎜⎛            0.5  ⎞     ⎟     ⎟
#    ⎜    ⎜⎜⎛       0.5⎞     ⎟     ⎟     ⎟
# H₀⋅⎝Ω + ⎝⎝⎝(x + x)   ⎠   ⋅1⎠   ⋅1⎠   ⋅1⎠
#
#
# =========== Epoch 00086 ===========
# -> Time 28.11 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
# ⎛                                      0.5    ⎞
# ⎜    ⎛                           0.5  ⎞       ⎟
# ⎜    ⎜⎛                    0.5  ⎞     ⎟       ⎟
# ⎜    ⎜⎜⎛               0.5⎞     ⎟     ⎟       ⎟
# ⎝Ω + ⎝⎝⎝(x + x + x + x)   ⎠   ⋅1⎠   ⋅1⎠    + 1⎠⋅1⋅H₀
#
#
# =========== Epoch 00087 ===========
# -> Time 28.99 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
# ⎛                            0.5⎞
# ⎜            ⎛           0.5⎞   ⎟
# ⎜            ⎜⎛      0.5⎞   ⎟   ⎟
# ⎜            ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# ⎝Ω⋅1⋅Ω + Ω + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠⋅1⋅H₀
#
#
# =========== Epoch 00088 ===========
# -> Time 32.05 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.993321
# -> Raw expression :
#    ⎛                               0.5    ⎞
#    ⎜    ⎛                0.5      ⎞       ⎟
#    ⎜    ⎜⎛           0.5⎞         ⎟       ⎟
#    ⎜    ⎜⎜⎛      0.5⎞   ⎟         ⎟       ⎟
#    ⎜    ⎜⎜⎜⎛ 0.5⎞   ⎟   ⎟         ⎟       ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝x   ⎠   ⎠   ⎠   ⋅1 + 1⎠   ⋅1⋅1⎠
#
#
# =========== Epoch 00089 ===========
# -> Time 26.03 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.992645
# -> Raw expression :
#    ⎛                                0.5⎞
#    ⎜                ⎛           0.5⎞   ⎟
#    ⎜                ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜                ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝(Ω⋅x + Ω)⋅1⋅1 + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00090 ===========
# -> Time 34.34 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989383
# -> Raw expression :
#    ⎛                                         0.5⎞
#    ⎜    ⎛                                0.5⎞   ⎟
#    ⎜    ⎜⎛                           0.5⎞   ⎟   ⎟
#    ⎜    ⎜⎜⎛⎛              0.5⎞      ⎞   ⎟   ⎟   ⎟
#    ⎜    ⎜⎜⎜⎜        ⎛ 0.5⎞   ⎟      ⎟   ⎟   ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝Ω + Ω + ⎝x   ⎠   ⎠⋅1 + 1⎠   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00091 ===========
# -> Time 26.85 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.986567
# -> Raw expression :
#                                  0.5
# ⎛                            0.5⎞
# ⎜⎛                     0.5  ⎞   ⎟
# ⎜⎜        ⎛ 0.5    0.5⎞     ⎟   ⎟
# ⎝⎝Ω + Ω + ⎝x    + x   ⎠   ⋅1⎠   ⎠   ⋅1⋅H₀
#
#
# =========== Epoch 00092 ===========
# -> Time 25.23 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.987305
# -> Raw expression :
#           ⎛                                0.5⎞
#           ⎜    ⎛                       0.5⎞   ⎟
#           ⎜    ⎜⎛⎛              0.5⎞  ⎞   ⎟   ⎟
#           ⎜    ⎜⎜⎜    ⎛     0.5⎞   ⎟  ⎟   ⎟   ⎟
# (H₀ + H₀)⋅⎝Ω + ⎝⎝⎝Ω + ⎝(Ω⋅x)   ⎠   ⎠⋅1⎠   ⎠   ⎠
#
#
# =========== Epoch 00093 ===========
# -> Time 28.72 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.988697
# -> Raw expression :
#                           0.5
# ⎛               0.5      ⎞
# ⎜    ⎛      0.5⎞         ⎟
# ⎜    ⎜⎛ 0.5⎞   ⎟         ⎟
# ⎜Ω + ⎝⎝x   ⎠   ⎠    + 1⋅1⎟
# ⎜────────────────────────⎟   ⋅1⋅H₀
# ⎝           1            ⎠
#
#
# =========== Epoch 00094 ===========
# -> Time 31.97 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                                0.5    ⎞
#    ⎜    ⎛                 0.5      ⎞       ⎟
#    ⎜    ⎜⎛            0.5⎞         ⎟       ⎟
#    ⎜    ⎜⎜⎛       0.5⎞   ⎟         ⎟       ⎟
# H₀⋅⎝Ω + ⎝⎝⎝(x + x)   ⎠   ⎠   ⋅1⋅1⋅1⎠    + 1⎠
#
#
# =========== Epoch 00095 ===========
# -> Time 27.22 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
# ⎛                    0.5        ⎞
# ⎜    ⎛           0.5⎞           ⎟
# ⎜    ⎜⎛      0.5⎞   ⎟           ⎟
# ⎜    ⎜⎜⎛ 0.5⎞   ⎟   ⎟           ⎟
# ⎝Ω + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⋅1⋅1 + 1⎠⋅1⋅H₀ + H₀
#
#
# =========== Epoch 00096 ===========
# -> Time 26.98 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                                           0.5⎞
#    ⎜        ⎛                              0.5⎞   ⎟
#    ⎜        ⎜⎛                       0.5  ⎞   ⎟   ⎟
#    ⎜        ⎜⎜⎛                  0.5⎞     ⎟   ⎟   ⎟
#    ⎜        ⎜⎜⎜⎛  ⎛ 0.5        ⎞⎞   ⎟     ⎟   ⎟   ⎟
# H₀⋅⎝Ω + Ω + ⎝⎝⎝⎝x⋅⎝Ω    + Ω + 1⎠⎠   ⎠   ⋅1⎠   ⎠   ⎠
#
#
# =========== Epoch 00097 ===========
# -> Time 22.67 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.992653
# -> Raw expression :
#                                           0.5
#    ⎛                                  0.5⎞
#    ⎜    ⎛⎛           0.5        ⎞    ⎞   ⎟
#    ⎜    ⎜⎜⎛      0.5⎞           ⎟    ⎟   ⎟
#    ⎜    ⎜⎜⎜⎛ 0.5⎞   ⎟           ⎟    ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝x   ⎠   ⎠    + 1 + 1⎠⋅1⋅1⎠   ⎠
#
#
# =========== Epoch 00098 ===========
# -> Time 21.39 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                      0.5      ⎞
#    ⎜    ⎛             0.5⎞         ⎟
#    ⎜    ⎜⎛      0.5  ⎞   ⎟         ⎟
#    ⎜    ⎜⎜⎛ 0.5⎞     ⎟   ⎟         ⎟
# H₀⋅⎝Ω + ⎝⎝⎝x   ⎠   ⋅1⎠   ⎠   ⋅1⋅1⋅1⎠
#
#
# =========== Epoch 00099 ===========
# -> Time 21.14 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
# ⎛                             0.5⎞
# ⎜    ⎛                    0.5⎞   ⎟
# ⎜    ⎜⎛               0.5⎞   ⎟   ⎟
# ⎜    ⎜⎜⎛ 0.5    0.5  ⎞   ⎟   ⎟   ⎟
# ⎝Ω + ⎝⎝⎝x   ⋅1⋅1   ⋅1⎠   ⎠   ⎠   ⎠⋅1⋅H₀
#
#
# =========== Epoch 00100 ===========
# -> Time 19.99 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.993515
# -> Raw expression :
#    ⎛                                     0.5⎞
#    ⎜    ⎛                  0.5          ⎞   ⎟
#    ⎜    ⎜⎛           0.5  ⎞             ⎟   ⎟
#    ⎜    ⎜⎜⎛      0.5⎞     ⎟             ⎟   ⎟
#    ⎜    ⎜⎜⎜⎛ 0.5⎞   ⎟     ⎟             ⎟   ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝x   ⎠   ⎠   ⋅1⎠   ⋅1 + 1 + 1⎠   ⎠ + H₀
#
#
# =========== Epoch 00101 ===========
# -> Time 24.43 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛    ⎛                0.5    ⎞      ⎞
#    ⎜    ⎜⎛           0.5⎞       ⎟      ⎟
#    ⎜    ⎜⎜⎛      0.5⎞   ⎟       ⎟      ⎟
#    ⎜    ⎜⎜⎜⎛ 0.5⎞   ⎟   ⎟       ⎟      ⎟
# H₀⋅⎝Ω + ⎝⎝⎝⎝x   ⎠   ⎠   ⎠    + 1⎠⋅1 + 1⎠
#
#
# =========== Epoch 00102 ===========
# -> Time 23.73 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                                  0.5⎞
#    ⎜                  ⎛           0.5⎞   ⎟
#    ⎜                  ⎜⎛      0.5⎞   ⎟   ⎟
#    ⎜                  ⎜⎜⎛ 0.5⎞   ⎟   ⎟   ⎟
# H₀⋅⎝Ω⋅(1 + 1⋅1 + 1) + ⎝⎝⎝x   ⎠   ⎠   ⎠   ⎠
#
#
# =========== Epoch 00103 ===========
# -> Time 21.04 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.994775
# -> Raw expression :
#                                       0.5
#    ⎛                              0.5⎞
#    ⎜⎛      0.5                   ⎞   ⎟
#    ⎜⎜⎛ 0.5⎞    ⎛       0.5    ⎞  ⎟   ⎟
# H₀⋅⎝⎝⎝x   ⎠   ⋅⎝Ω⋅(x⋅1)    + 1⎠⋅1⎠   ⎠
#
#
# =========== Epoch 00104 ===========
# -> Time 25.12 s
#
# Overall best  at R=0.994798
# -> Raw expression :
#                         0.5
# ⎛                 0.5  ⎞
# ⎜⎛            0.5⎞     ⎟
# ⎜⎜⎛       0.5⎞   ⎟     ⎟
# ⎝⎝⎝Ω⋅x + x   ⎠   ⎠   ⋅1⎠   ⋅1⋅1⋅H₀
#
# Best of epoch at R=0.989688
# -> Raw expression :
#    ⎛                                         0.5⎞
#    ⎜        ⎛                          0.5  ⎞   ⎟
#    ⎜        ⎜⎛                     0.5⎞     ⎟   ⎟
#    ⎜        ⎜⎜⎛                0.5⎞   ⎟     ⎟   ⎟
#    ⎜        ⎜⎜⎜⎛           0.5⎞   ⎟   ⎟     ⎟   ⎟
# H₀⋅⎝Ω + Ω + ⎝⎝⎝⎝(x⋅x⋅1⋅1⋅1)   ⎠   ⎠   ⎠   ⋅1⎠   ⎠

# %% [markdown]
# ## Results

# %% [markdown]
# ### Run plot

# %%
run_visualiser.make_visualisation()

# %% [markdown]
# ### Pareto Front

# %%
def plot_pareto_front(run_logger,
                      do_simplify                   = True,
                      show_superparent_at_beginning = True,
                      eq_text_size                  = 12,
                      delta_xlim                    = [0, 5 ],
                      delta_ylim                    = [0, 15],
                      frac_delta_equ                = [0.03, 0.03],
                      figsize                       = (20, 10),
                     ):

    pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

    pareto_front_rmse = np.log(pareto_front_rmse)
    # Fig params
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    # enables new_dummy_symbol = "\square"
    plt.rc('text.latex', preamble=r'\usepackage{amssymb} \usepackage{xcolor}')
    plt.rc('font', size=32)

    # Fig
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'r-')
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'ro')

    # Limits
    xmin = pareto_front_complexities.min() + delta_xlim[0]
    xmax = pareto_front_complexities.max() + delta_xlim[1]
    ymin = pareto_front_rmse.min() + delta_ylim[0]
    ymax = pareto_front_rmse.max() + delta_ylim[1]
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    # Axes labels
    ax.set_xlabel("Expression complexity")
    ax.set_ylabel("log(RMSE)")


    for i_prog in range (len(pareto_front_programs)):
        prog = pareto_front_programs[i_prog]

        text_pos  = [pareto_front_complexities[i_prog] + frac_delta_equ[0]*(xmax-xmin), 
                     pareto_front_rmse[i_prog]         + frac_delta_equ[1]*(ymax-ymin)]
        # Getting latex expr
        latex_str = prog.get_infix_latex(do_simplify = do_simplify)
        # Adding "superparent =" before program to make it pretty
        if show_superparent_at_beginning:
            latex_str = prog.library.superparent.name + ' =' + latex_str


        ax.text(text_pos[0], text_pos[1], f'${latex_str}$', size = eq_text_size)

# %%
plot_pareto_front(run_logger)

# %%
pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)

# %% [markdown]
# ### Symbolic equivalence

# %%
best_prog_sympy   = candidates[-1] .get_infix_sympy(do_simplify=True)
target_prog_sympy = target_program .get_infix_sympy(do_simplify=True)

# %%
target_prog_sympy

# %%
best_prog_sympy

# %%
target_prog_sympy == best_prog_sympy

# %%
hall_of_fame = run_logger.hall_of_fame

# %%
for i in range(len(hall_of_fame)):
    print(hall_of_fame[i].get_infix_sympy(do_simplify=False))

# %%
eq = hall_of_fame[i].get_infix_sympy(do_simplify=True)

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)
    print("g", prog.free_const_values[0])
    print("m", prog.free_const_values[1])
