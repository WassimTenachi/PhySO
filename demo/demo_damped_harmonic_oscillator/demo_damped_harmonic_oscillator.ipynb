# %% [markdown]
# # $\Phi$-SO demo

# %% [markdown]
# ## Packages import

# %%
# External packages
import torch
import numpy as np

# Pyplot
import matplotlib.pyplot as plt

# Internal code import
import physo
from physo.learn import monitoring
from physo.task  import benchmark

# %%
# Device
DEVICE = 'cpu'
if torch.cuda.is_available():
    DEVICE = 'cuda'
print(DEVICE)
# Out:
# cpu

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# ## Test case

# %% [markdown]
# #### Data points

# %%
data_size = int(1e3)

# %%
# Data points
t  = np.random.uniform(np.pi, 10*np.pi, data_size)
X_array = np.stack((t,), axis=0)
f      = 0.784
alpha0 = 1/9.89
phi    = 0.997
y_array = np.exp(-t*alpha0)*np.cos(f*t + phi)

# %%
n_dim = X_array.shape[0]
fig, ax = plt.subplots(n_dim, 1, figsize=(10,5))
for i in range (n_dim):
    curr_ax = ax if n_dim==1 else ax[i]
    curr_ax.plot(X_array[i], y_array, 'k.',)
    curr_ax.set_xlabel("X[%i]"%(i))
    curr_ax.set_ylabel("y")
plt.show()

# %% [markdown]
# #### Sending data to device

# %%
# ------ Vectors ------
# Stack of all input variables
X = torch.tensor(X_array).to(DEVICE)
# Output of symbolic function to guess
y = torch.tensor(y_array).to(DEVICE)

# ------ Constants ------
const1 = torch.tensor(np.array( 1.   )).to(DEVICE)

# %% [markdown]
# ## Run config

# %% [markdown]
# ### Library config

# %%
# [length, mass, time]
args_make_tokens = {
                # operations
                "op_names"             : ["mul", "add", "sub", "div", "inv", "n2", "sqrt", "neg", "exp", "log", "sin", "cos"],
                "use_protected_ops"    : True,
                # input variables
                "input_var_ids"        : {"t" : 0         ,},
                "input_var_units"      : {"t" : [0, 0, 1] ,},
                "input_var_complexity" : {"t" : 1.        ,},
                # constants
                "constants"            : {"1" : const1    , },
                "constants_units"      : {"1" : [0, 0, 0] , },
                "constants_complexity" : {"1" : 1.        , },
                # free constants
                "free_constants"            : {"f"               , "alpha0"               , "phi"               , },
                "free_constants_init_val"   : {"f" : 1.          , "alpha0" : 1/10.       , "phi" : 1.          , },
                "free_constants_units"      : {"f" : [0, 0, -1]  , "alpha0" : [0, 0, -1]  , "phi" : [0, 0, 0]   , },
                "free_constants_complexity" : {"f" : 1.          , "alpha0" : 1.          , "phi" : 1.          , },
                    }

library_config = {"args_make_tokens"  : args_make_tokens,
                  "superparent_units" : [0, 0, 0],
                  "superparent_name"  : "F",
                }

# %% [markdown]
# ### Learning config

# %%
reward_config = {
                 "reward_function"     : physo.physym.reward.SquashedNRMSE, 
                 "zero_out_unphysical" : True,
                 "zero_out_duplicates" : False,
                 "keep_lowest_complexity_duplicate" : False,
                 "parallel_mode" : True,
                 "n_cpus"        : None,
                }

# %%
BATCH_SIZE = int(1e3)
MAX_LENGTH = 35
GET_OPTIMIZER = lambda model : torch.optim.Adam(
                                    model.parameters(),                
                                    lr=0.0025, #0.001, #0.0050, #0.0005, #1,  #lr=0.0025
                                                )

# %%
learning_config = {
    # Batch related
    'batch_size'       : BATCH_SIZE,
    'max_time_step'    : MAX_LENGTH,
    'n_epochs'         : int(1e9),
    # Loss related
    'gamma_decay'      : 0.7,
    'entropy_weight'   : 0.005,
    # Reward related
    'risk_factor'      : 0.05,
    'rewards_computer' : physo.physym.reward.make_RewardsComputer (**reward_config),
    # Optimizer
    'get_optimizer'    : GET_OPTIMIZER,
    'observe_units'    : True,
}

# %% [markdown]
# ### Free constant optimizer config

# %%
free_const_opti_args = {
            'loss'   : "MSE",
            'method' : 'LBFGS',
            'method_args': {
                        'n_steps' : 15,
                        'tol'     : 1e-6,
                        'lbfgs_func_args' : {
                            'max_iter'       : 4,
                            'line_search_fn' : "strong_wolfe",
                                             },
                            },
        }

# %% [markdown]
# ### Priors config

# %%
priors_config  = [
                #("UniformArityPrior", None),
                # LENGTH RELATED
                ("HardLengthPrior"  , {"min_length": 4, "max_length": MAX_LENGTH, }),
                ("SoftLengthPrior"  , {"length_loc": 8, "scale": 5, }),
                # RELATIONSHIPS RELATED
                ("NoUselessInversePrior"  , None),
                ("PhysicalUnitsPrior", {"prob_eps": np.finfo(np.float32).eps}), # PHYSICALITY
                ("NestedFunctions", {"functions":["exp",], "max_nesting" : 1}),
                ("NestedFunctions", {"functions":["log",], "max_nesting" : 1}),
                ("NestedTrigonometryPrior", {"max_nesting" : 1}),           
                #("OccurrencesPrior", {"targets" : ["1",], "max" : [3,] }),
                 ]

# %% [markdown]
# ### Cell config

# %%
cell_config = {
    "hidden_size" : 128,
    "n_layers"    : 1,
    "is_lobotomized" : False,
}

# %% [markdown]
# ### Logger

# %%
save_path_training_curves = 'demo_curves.png'
save_path_log             = 'demo.log'

run_logger     = monitoring.RunLogger(save_path = save_path_log, 
                                      do_save = True)

run_visualiser = monitoring.RunVisualiser (epoch_refresh_rate = 10,
                                           save_path = save_path_training_curves,
                                           do_show   = False,
                                           do_prints = True,
                                           do_save   = True, )

# %% [markdown]
# ### Run config

# %%
run_config = {
    "learning_config"      : learning_config,
    "reward_config"        : reward_config,
    "free_const_opti_args" : free_const_opti_args,
    "library_config"       : library_config,
    "priors_config"        : priors_config,
    "cell_config"          : cell_config,
    "run_logger"           : run_logger,
    "run_visualiser"       : run_visualiser,
}

# %% [markdown]
# ## Dummy epoch for prior tuning

# %%
benchmark.dummy_epoch(X, y, run_config)

# %% [markdown]
# ## Run

# %%
rewards, candidates = physo.fit (X, y, run_config,
                                stop_reward = 0.9999, 
                                stop_after_n_epochs = 5)
# Out:
# =========== Epoch 00000 ===========
# -> Time 7.29 s
#
# Overall best  at R=0.514255
# -> Raw expression :
#         ⎛            0.5⎞
#         ⎜⎛       φ  ⎞   ⎟
#         ⎜⎜α₀ + ─────⎟   ⎟
#         ⎜⎜     t + t⎟   ⎟
#  φ + cos⎜⎜──────────⎟   ⎟
#         ⎝⎝    f     ⎠   ⎠
# ℯ
#
# Best of epoch at R=0.514255
# -> Raw expression :
#         ⎛            0.5⎞
#         ⎜⎛       φ  ⎞   ⎟
#         ⎜⎜α₀ + ─────⎟   ⎟
#         ⎜⎜     t + t⎟   ⎟
#  φ + cos⎜⎜──────────⎟   ⎟
#         ⎝⎝    f     ⎠   ⎠
# ℯ
#
#
# =========== Epoch 00001 ===========
# -> Time 5.14 s
#
# Overall best  at R=0.525934
# -> Raw expression :
#     ⎛                       2⎞
#     ⎜⎛        ⎛   ⎛     1⎞⎞⎞ ⎟
#     ⎜⎜-φ + log⎜-t⋅⎜-f + ─⎟⎟⎟ ⎟
#     ⎝⎝        ⎝   ⎝     t⎠⎠⎠ ⎠
# α₀⋅ℯ
# ──────────────────────────────
#               f
#
# Best of epoch at R=0.525934
# -> Raw expression :
#     ⎛                       2⎞
#     ⎜⎛        ⎛   ⎛     1⎞⎞⎞ ⎟
#     ⎜⎜-φ + log⎜-t⋅⎜-f + ─⎟⎟⎟ ⎟
#     ⎝⎝        ⎝   ⎝     t⎠⎠⎠ ⎠
# α₀⋅ℯ
# ──────────────────────────────
#               f
#
#
# =========== Epoch 00002 ===========
# -> Time 4.61 s
#
# Overall best  at R=0.574776
# -> Raw expression :
#                     1
# -φ + ───────────────────────────────
#                                  0.5
#      ⎛                       0.5⎞
#      ⎜⎛ -cos(t⋅(-f + f + f))⎞   ⎟
#      ⎝⎝ℯ                    ⎠   ⎠
#
# Best of epoch at R=0.574776
# -> Raw expression :
#                     1
# -φ + ───────────────────────────────
#                                  0.5
#      ⎛                       0.5⎞
#      ⎜⎛ -cos(t⋅(-f + f + f))⎞   ⎟
#      ⎝⎝ℯ                    ⎠   ⎠
#
#
# =========== Epoch 00003 ===========
# -> Time 4.96 s
#
# Overall best  at R=0.574776
# -> Raw expression :
#                     1
# -φ + ───────────────────────────────
#                                  0.5
#      ⎛                       0.5⎞
#      ⎜⎛ -cos(t⋅(-f + f + f))⎞   ⎟
#      ⎝⎝ℯ                    ⎠   ⎠
#
# Best of epoch at R=0.522014
# -> Raw expression :
#    ⎛      -1        ⎞
#    ⎜-────────────── ⎟
#    ⎜     2          ⎟
#    ⎜ f⋅-t      1    ⎟
#    ⎜ ───── + ────── ⎟
#    ⎜   1     ⎛ α₀ ⎞ ⎟
#    ⎜         ⎜────⎟ ⎟
#    ⎜         ⎜ 0.5⎟ ⎟
#    ⎜         ⎝φ   ⎠ ⎟
# sin⎜────────────────⎟
#    ⎝       f        ⎠
#
#
# =========== Epoch 00004 ===========
# -> Time 4.96 s
#
# Overall best  at R=0.574776
# -> Raw expression :
#                     1
# -φ + ───────────────────────────────
#                                  0.5
#      ⎛                       0.5⎞
#      ⎜⎛ -cos(t⋅(-f + f + f))⎞   ⎟
#      ⎝⎝ℯ                    ⎠   ⎠
#
# Best of epoch at R=0.529673
# -> Raw expression :
#                              2
# ⎛    ⎛          f          ⎞⎞
# ⎜-sin⎜─────────────────────⎟⎟
# ⎜    ⎜⎛          1     ⎞  φ⎟⎟
# ⎜    ⎜⎜α₀ + ───────────⎟⋅ℯ ⎟⎟
# ⎝    ⎝⎝     t - (t + t)⎠   ⎠⎠
#
#
# =========== Epoch 00005 ===========
# -> Time 4.73 s
#
# Overall best  at R=0.574776
# -> Raw expression :
#                     1
# -φ + ───────────────────────────────
#                                  0.5
#      ⎛                       0.5⎞
#      ⎜⎛ -cos(t⋅(-f + f + f))⎞   ⎟
#      ⎝⎝ℯ                    ⎠   ⎠
#
# Best of epoch at R=0.532501
# -> Raw expression :
#     ⎛ φ⋅(φ + -α₀⋅t - φ) + φ⎞
# -sin⎝ℯ                     ⎠
#
#
# =========== Epoch 00006 ===========
# -> Time 5.00 s
#
# Overall best  at R=0.574776
# -> Raw expression :
#                     1
# -φ + ───────────────────────────────
#                                  0.5
#      ⎛                       0.5⎞
#      ⎜⎛ -cos(t⋅(-f + f + f))⎞   ⎟
#      ⎝⎝ℯ                    ⎠   ⎠
#
# Best of epoch at R=0.531873
# -> Raw expression :
#             1
#   φ + ──────────────
#       ⎛  2         ⎞
#       ⎜-1 ⋅(1 + 1) ⎟
#       ⎜────────────⎟
#       ⎝    α₀⋅t    ⎠
# -ℯ
#
#
# =========== Epoch 00007 ===========
# -> Time 4.78 s
#
# Overall best  at R=0.588001
# -> Raw expression :
#    ⎛  ⎛           1   ⎞⎞
# cos⎜t⋅⎜α₀ - f - ──────⎟⎟
#    ⎜  ⎜         ⎛-1  ⎞⎟⎟
#    ⎜  ⎜         ⎜────⎟⎟⎟
#    ⎝  ⎝         ⎝-2⋅f⎠⎠⎠
# ────────────────────────
#            φ
#
# Best of epoch at R=0.588001
# -> Raw expression :
#    ⎛  ⎛           1   ⎞⎞
# cos⎜t⋅⎜α₀ - f - ──────⎟⎟
#    ⎜  ⎜         ⎛-1  ⎞⎟⎟
#    ⎜  ⎜         ⎜────⎟⎟⎟
#    ⎝  ⎝         ⎝-2⋅f⎠⎠⎠
# ────────────────────────
#            φ
#
#
# =========== Epoch 00008 ===========
# -> Time 4.76 s
#
# Overall best  at R=0.603614
# -> Raw expression :
#      ⎛                     0.5⎞
#      ⎜⎛      2           1⎞   ⎟
# f⋅cos⎜⎜α₀⋅f⋅t  - 1 + 1 + ─⎟   ⎟
#      ⎝⎝                  φ⎠   ⎠
# ───────────────────────────────
#                α₀
#
# Best of epoch at R=0.603614
# -> Raw expression :
#      ⎛                     0.5⎞
#      ⎜⎛      2           1⎞   ⎟
# f⋅cos⎜⎜α₀⋅f⋅t  - 1 + 1 + ─⎟   ⎟
#      ⎝⎝                  φ⎠   ⎠
# ───────────────────────────────
#                α₀
#
#
# =========== Epoch 00009 ===========
# -> Time 4.99 s
#
# Overall best  at R=0.603614
# -> Raw expression :
#      ⎛                     0.5⎞
#      ⎜⎛      2           1⎞   ⎟
# f⋅cos⎜⎜α₀⋅f⋅t  - 1 + 1 + ─⎟   ⎟
#      ⎝⎝                  φ⎠   ⎠
# ───────────────────────────────
#                α₀
#
# Best of epoch at R=0.588001
# -> Raw expression :
#      ⎛         1          ⎞
# φ⋅cos⎜t⋅1⋅────────────⋅f⋅1⎟
#      ⎜         0.5        ⎟
#      ⎜      - φ    + φ    ⎟
#      ⎝    -ℯ              ⎠
#
#
# =========== Epoch 00010 ===========
# -> Time 8.80 s
#
# Overall best  at R=0.611510
# -> Raw expression :
#      ⎛    0.5                 ⎞
#      ⎜⎛f ⎞       1⋅log(α₀⋅1⋅t)⎟
# φ⋅sin⎜⎜──⎟    + ℯ             ⎟
#      ⎝⎝α₀⎠                    ⎠
#
# Best of epoch at R=0.611510
# -> Raw expression :
#      ⎛    0.5                 ⎞
#      ⎜⎛f ⎞       1⋅log(α₀⋅1⋅t)⎟
# φ⋅sin⎜⎜──⎟    + ℯ             ⎟
#      ⎝⎝α₀⎠                    ⎠
#
#
# =========== Epoch 00011 ===========
# -> Time 4.75 s
#
# Overall best  at R=0.611510
# -> Raw expression :
#      ⎛    0.5                 ⎞
#      ⎜⎛f ⎞       1⋅log(α₀⋅1⋅t)⎟
# φ⋅sin⎜⎜──⎟    + ℯ             ⎟
#      ⎝⎝α₀⎠                    ⎠
#
# Best of epoch at R=0.604355
# -> Raw expression :
#      ⎛ ⎛α₀⋅f⋅t   1    ⎞⎞
# φ⋅sin⎜-⎜────── + ─ + 1⎟⎟
#      ⎝ ⎝  α₀     1    ⎠⎠
#
#
# =========== Epoch 00012 ===========
# -> Time 4.55 s
#
# Overall best  at R=0.611510
# -> Raw expression :
#      ⎛    0.5                 ⎞
#      ⎜⎛f ⎞       1⋅log(α₀⋅1⋅t)⎟
# φ⋅sin⎜⎜──⎟    + ℯ             ⎟
#      ⎝⎝α₀⎠                    ⎠
#
# Best of epoch at R=0.586189
# -> Raw expression :
#       -(α₀ + f⋅-sin(f⋅t))
#       ────────────────────
#                α₀
# -φ - ℯ
#
#
# =========== Epoch 00013 ===========
# -> Time 4.61 s
#
# Overall best  at R=0.611510
# -> Raw expression :
#      ⎛    0.5                 ⎞
#      ⎜⎛f ⎞       1⋅log(α₀⋅1⋅t)⎟
# φ⋅sin⎜⎜──⎟    + ℯ             ⎟
#      ⎝⎝α₀⎠                    ⎠
#
# Best of epoch at R=0.567058
# -> Raw expression :
#       -φ - sin(φ⋅(f⋅t + f⋅(t + t))) - 1
# -φ + ℯ
#
#
# =========== Epoch 00014 ===========
# -> Time 4.60 s
#
# Overall best  at R=0.611510
# -> Raw expression :
#      ⎛    0.5                 ⎞
#      ⎜⎛f ⎞       1⋅log(α₀⋅1⋅t)⎟
# φ⋅sin⎜⎜──⎟    + ℯ             ⎟
#      ⎝⎝α₀⎠                    ⎠
#
# Best of epoch at R=0.535072
# -> Raw expression :
#   ⎛     ⎛   ⎛    1     ⎞⎞     ⎞
#   ⎜  cos⎜log⎜──────────⎟⎟     ⎟
#   ⎜     ⎜   ⎜ -α₀⋅t + φ⎟⎟     ⎟
#   ⎜     ⎝   ⎝ℯ         ⎠⎠   1 ⎟
# f⋅⎜- ──────────────────── + ──⎟
#   ⎝           α₀            α₀⎠
#
#
# =========== Epoch 00015 ===========
# -> Time 5.05 s
#
# Overall best  at R=0.611510
# -> Raw expression :
#      ⎛    0.5                 ⎞
#      ⎜⎛f ⎞       1⋅log(α₀⋅1⋅t)⎟
# φ⋅sin⎜⎜──⎟    + ℯ             ⎟
#      ⎝⎝α₀⎠                    ⎠
#
# Best of epoch at R=0.536440
# -> Raw expression :
#      0.5
#     1
# ───────────
# ⎛   α₀⋅t  ⎞
# ⎜─────────⎟
# ⎜   ⎛α₀⋅t⎞⎟
# ⎜cos⎜────⎟⎟
# ⎜   ⎜  1 ⎟⎟
# ⎝   ⎝ ℯ  ⎠⎠
#
#
# =========== Epoch 00016 ===========
# -> Time 4.62 s
#
# Overall best  at R=0.611510
# -> Raw expression :
#      ⎛    0.5                 ⎞
#      ⎜⎛f ⎞       1⋅log(α₀⋅1⋅t)⎟
# φ⋅sin⎜⎜──⎟    + ℯ             ⎟
#      ⎝⎝α₀⎠                    ⎠
#
# Best of epoch at R=0.541882
# -> Raw expression :
#    ⎛ ⎛       0.5⎞          ⎞
#    ⎜ ⎜⎛  1  ⎞   ⎟          ⎟
#    ⎜ ⎜⎜─────⎟   ⎟          ⎟
#    ⎜ ⎜⎜⎛f⋅t⎞⎟   ⎟          ⎟
#    ⎜ ⎜⎜⎜───⎟⎟   ⎟          ⎟
#    ⎜ ⎝⎝⎝ φ ⎠⎠   ⎠          ⎟
# sin⎝ℯ            ⋅1⋅f⋅t + φ⎠
# ────────────────────────────
#              φ
#
#
# =========== Epoch 00017 ===========
# -> Time 4.71 s
#
# Overall best  at R=0.681982
# -> Raw expression :
#             ⎛ α₀⋅t - φ⎞
# cos(f⋅t)⋅cos⎝ℯ        ⎠
#
# Best of epoch at R=0.681982
# -> Raw expression :
#             ⎛ α₀⋅t - φ⎞
# cos(f⋅t)⋅cos⎝ℯ        ⎠
#
#
# =========== Epoch 00018 ===========
# -> Time 4.45 s
#
# Overall best  at R=0.681982
# -> Raw expression :
#             ⎛ α₀⋅t - φ⎞
# cos(f⋅t)⋅cos⎝ℯ        ⎠
#
# Best of epoch at R=0.535746
# -> Raw expression :
#          ⎛      -t ⎞
#          ⎜ α₀⋅t⋅───⎟
#          ⎜      ⎛1⎞⎟
#          ⎜      ⎜─⎟⎟
#          ⎜      ⎝f⎠⎟
# - f⋅t⋅sin⎝ℯ        ⎠ - φ
#
#
# =========== Epoch 00019 ===========
# -> Time 5.05 s
#
# Overall best  at R=0.681982
# -> Raw expression :
#             ⎛ α₀⋅t - φ⎞
# cos(f⋅t)⋅cos⎝ℯ        ⎠
#
# Best of epoch at R=0.588001
# -> Raw expression :
#      ⎛      ⎛     α₀⋅t - φ + φ + φ⎞⎞
# φ⋅cos⎝-α₀⋅t⋅⎝φ + ℯ                ⎠⎠
#
#
# =========== Epoch 00020 ===========
# -> Time 7.83 s
#
# Overall best  at R=0.681982
# -> Raw expression :
#             ⎛ α₀⋅t - φ⎞
# cos(f⋅t)⋅cos⎝ℯ        ⎠
#
# Best of epoch at R=0.536272
# -> Raw expression :
#    ⎛   ⎛      α₀⋅φ⋅t   ⎞⎞
# sin⎝log⎝α₀⋅t⋅ℯ      ⋅-1⎠⎠
#
#
# =========== Epoch 00021 ===========
# -> Time 4.68 s
#
# Overall best  at R=0.681982
# -> Raw expression :
#             ⎛ α₀⋅t - φ⎞
# cos(f⋅t)⋅cos⎝ℯ        ⎠
#
# Best of epoch at R=0.537913
# -> Raw expression :
#      sin(-f⋅-t + φ + φ + 1)
# - φ⋅ℯ                       + φ
#
#
# =========== Epoch 00022 ===========
# -> Time 4.51 s
#
# Overall best  at R=0.681982
# -> Raw expression :
#             ⎛ α₀⋅t - φ⎞
# cos(f⋅t)⋅cos⎝ℯ        ⎠
#
# Best of epoch at R=0.603419
# -> Raw expression :
#   φ    ⎛             φ⎞
# -ℯ ⋅cos⎝-α₀⋅t - φ + ℯ ⎠
#
#
# =========== Epoch 00023 ===========
# -> Time 4.82 s
#
# Overall best  at R=0.742076
# -> Raw expression :
#           -f⋅t
# φ + -φ - ℯ    ⋅sin(-α₀⋅t)
#
# Best of epoch at R=0.742076
# -> Raw expression :
#           -f⋅t
# φ + -φ - ℯ    ⋅sin(-α₀⋅t)
#
#
# =========== Epoch 00024 ===========
# -> Time 4.61 s
#
# Overall best  at R=0.742076
# -> Raw expression :
#           -f⋅t
# φ + -φ - ℯ    ⋅sin(-α₀⋅t)
#
# Best of epoch at R=0.585410
# -> Raw expression :
#    ⎛           1            ⎞
# log⎜────────────────────────⎟
#    ⎜ (φ - sin(-α₀⋅t))⋅sin(φ)⎟
#    ⎝ℯ                       ⎠
#
#
# =========== Epoch 00025 ===========
# -> Time 4.61 s
#
# Overall best  at R=0.742076
# -> Raw expression :
#  -f⋅t
# ℯ    ⋅sin(-α₀⋅t)
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  -f⋅t
# ℯ    ⋅sin(-α₀⋅t)
#
#
# =========== Epoch 00026 ===========
# -> Time 4.57 s
#
# Overall best  at R=0.742076
# -> Raw expression :
#  -f⋅t
# ℯ    ⋅sin(-α₀⋅t)
#
# Best of epoch at R=0.611510
# -> Raw expression :
#    ⎛       ⎛  ⎛     1 ⎞⎞⎞
#    ⎜  φ⋅sin⎜f⋅⎜-t + ──⎟⎟⎟
#    ⎜       ⎝  ⎝     α₀⎠⎠⎟
# log⎝-ℯ                  ⎠⋅1
#
#
# =========== Epoch 00027 ===========
# -> Time 4.93 s
#
# Overall best  at R=0.742076
# -> Raw expression :
#  -f⋅t
# ℯ    ⋅sin(-α₀⋅t)
#
# Best of epoch at R=0.738230
# -> Raw expression :
#               ⎛  α₀⋅t⎞
# -sin(-f⋅t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00028 ===========
# -> Time 4.47 s
#
# Overall best  at R=0.742076
# -> Raw expression :
#  -f⋅t
# ℯ    ⋅sin(-α₀⋅t)
#
# Best of epoch at R=0.581378
# -> Raw expression :
#    cos(φ + -f⋅t - φ - log(-φ))
# φ⋅ℯ                            - φ
#
#
# =========== Epoch 00029 ===========
# -> Time 4.45 s
#
# Overall best  at R=0.743026
# -> Raw expression :
#                ⎛ -f⋅t - φ⎞
# -sin(-α₀⋅t)⋅sin⎝ℯ        ⎠
#
# Best of epoch at R=0.743026
# -> Raw expression :
#                ⎛ -f⋅t - φ⎞
# -sin(-α₀⋅t)⋅sin⎝ℯ        ⎠
#
#
# =========== Epoch 00030 ===========
# -> Time 8.23 s
#
# Overall best  at R=0.743026
# -> Raw expression :
#                ⎛ -f⋅t - φ⎞
# -sin(-α₀⋅t)⋅sin⎝ℯ        ⎠
#
# Best of epoch at R=0.678308
# -> Raw expression :
#        -f⋅t
# -f⋅t⋅-ℯ    ⋅cos(α₀⋅t)
#
#
# =========== Epoch 00031 ===========
# -> Time 4.57 s
#
# Overall best  at R=0.743026
# -> Raw expression :
#                ⎛ -f⋅t - φ⎞
# -sin(-α₀⋅t)⋅sin⎝ℯ        ⎠
#
# Best of epoch at R=0.612310
# -> Raw expression :
#      ⎛ - -f⋅t⋅(-α₀⋅(t + t) + φ)⎞
# φ⋅sin⎝ℯ                        ⎠
#
#
# =========== Epoch 00032 ===========
# -> Time 4.47 s
#
# Overall best  at R=0.743026
# -> Raw expression :
#                ⎛ -f⋅t - φ⎞
# -sin(-α₀⋅t)⋅sin⎝ℯ        ⎠
#
# Best of epoch at R=0.576944
# -> Raw expression :
#    -f⋅t
# φ⋅ℯ    ⋅-cos(α₀⋅t)
#
#
# =========== Epoch 00033 ===========
# -> Time 4.58 s
#
# Overall best  at R=0.743026
# -> Raw expression :
#                ⎛ -f⋅t - φ⎞
# -sin(-α₀⋅t)⋅sin⎝ℯ        ⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#                ⎛ -f⋅t⎞
# sin(-α₀⋅t)⋅-sin⎝ℯ    ⎠
#
#
# =========== Epoch 00034 ===========
# -> Time 4.47 s
#
# Overall best  at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
# Best of epoch at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
#
# =========== Epoch 00035 ===========
# -> Time 4.71 s
#
# Overall best  at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  -f⋅t
# ℯ    ⋅sin(φ)⋅sin(-α₀⋅t)
#
#
# =========== Epoch 00036 ===========
# -> Time 4.76 s
#
# Overall best  at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
# Best of epoch at R=0.741054
# -> Raw expression :
#                     ⎛ -α₀⋅t⎞
# φ + sin(- -f⋅-t)⋅sin⎝ℯ     ⎠
#
#
# =========== Epoch 00037 ===========
# -> Time 4.65 s
#
# Overall best  at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#              ⎛ - -α₀⋅t⎞
# sin(-f⋅t)⋅sin⎝ℯ       ⎠
#
#
# =========== Epoch 00038 ===========
# -> Time 4.58 s
#
# Overall best  at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#             ⎛  -f⋅φ⋅t⎞
# sin(f⋅t)⋅sin⎝-ℯ      ⎠
#
#
# =========== Epoch 00039 ===========
# -> Time 4.68 s
#
# Overall best  at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
# Best of epoch at R=0.685905
# -> Raw expression :
# α₀⋅t⋅sin(-α₀⋅t)
# ───────────────
#      α₀⋅-φ⋅t
#     ℯ
#
#
# =========== Epoch 00040 ===========
# -> Time 8.76 s
#
# Overall best  at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
# Best of epoch at R=0.743026
# -> Raw expression :
#               ⎛    -f⋅t⎞
# -sin(α₀⋅t)⋅sin⎝-φ⋅ℯ    ⎠
#
#
# =========== Epoch 00041 ===========
# -> Time 4.61 s
#
# Overall best  at R=0.748128
# -> Raw expression :
#    ⎛   φ    α₀⋅t          ⎞
# log⎝- ℯ  - ℯ    ⋅sin(-f⋅t)⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   α₀⋅t
# -ℯ    ⋅-sin(-f⋅t)
#
#
# =========== Epoch 00042 ===========
# -> Time 4.63 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
#
# =========== Epoch 00043 ===========
# -> Time 4.44 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.712103
# -> Raw expression :
#                 ⎛     α₀⋅t⎞
# sin(- -f⋅-t)⋅sin⎝f⋅t⋅ℯ    ⎠
#
#
# =========== Epoch 00044 ===========
# -> Time 4.59 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  f⋅-t
# ℯ    ⋅sin(-α₀⋅t)
#
#
# =========== Epoch 00045 ===========
# -> Time 4.36 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                    ⎛  α₀⋅t⎞
# φ⋅-sin(- -f⋅-t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00046 ===========
# -> Time 4.64 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  α₀⋅t
# ℯ    ⋅sin(- -f⋅-t)
#
#
# =========== Epoch 00047 ===========
# -> Time 4.45 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.593234
# -> Raw expression :
#        -sin(α₀⋅t - f⋅t)
# α₀⋅t - ─────────────────
#                -φ
#               ℯ
#
#
# =========== Epoch 00048 ===========
# -> Time 4.49 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.730629
# -> Raw expression :
# sin(-f⋅-t)
# ──────────
#   -α₀⋅t
#
#
# =========== Epoch 00049 ===========
# -> Time 4.55 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#                  ⎛ -f⋅t⎞
# -sin(- -α₀⋅t)⋅sin⎝ℯ    ⎠
#
#
# =========== Epoch 00050 ===========
# -> Time 8.01 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  -f⋅t
# ℯ    ⋅sin(α₀⋅-t)
#
#
# =========== Epoch 00051 ===========
# -> Time 4.56 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(-α₀⋅-t)
# ─────────────
#    f⋅t⋅sin(φ)
#  -ℯ
#
#
# =========== Epoch 00052 ===========
# -> Time 4.73 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.745239
# -> Raw expression :
#      -f⋅t
# φ + ℯ    ⋅sin(α₀⋅t) - sin(φ)
#
#
# =========== Epoch 00053 ===========
# -> Time 5.15 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.741054
# -> Raw expression :
#                        ⎛ f⋅-t⎞
# sin(φ) + sin(-α₀⋅t)⋅sin⎝ℯ    ⎠
#
#
# =========== Epoch 00054 ===========
# -> Time 4.91 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   α₀⋅t
# -ℯ    ⋅sin(- -f⋅t)
#
#
# =========== Epoch 00055 ===========
# -> Time 4.78 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#    ⎛       -f ⎞
#    ⎜       ───⎟
#    ⎜        f ⎟
# sin⎝α₀⋅-t⋅ℯ   ⎠
# ───────────────
#        f⋅t
#       ℯ
#
#
# =========== Epoch 00056 ===========
# -> Time 4.87 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                   ⎛  -f⋅t⎞
# φ⋅t⋅sin(-α₀⋅t)⋅sin⎝-ℯ    ⎠
# ──────────────────────────
#             t
#
#
# =========== Epoch 00057 ===========
# -> Time 5.12 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#    ⎛      ⎛  -α₀⋅t⎞⎞    ⎛ α₀⋅t⎞
# sin⎝φ⋅-log⎝-ℯ     ⎠⎠⋅sin⎝ℯ    ⎠
#
#
# =========== Epoch 00058 ===========
# -> Time 4.85 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   -α₀⋅-t
# -ℯ      ⋅sin(f⋅t)
#
#
# =========== Epoch 00059 ===========
# -> Time 4.72 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#     ⎛        f⎞
#     ⎜        ─⎟
#     ⎜        f⎟
# -sin⎝-α₀⋅t⋅-ℯ ⎠
# ────────────────
#        f⋅t
#       ℯ
#
#
# =========== Epoch 00060 ===========
# -> Time 7.85 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#                ⎛  α₀⋅t⎞
# - -sin(f⋅t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00061 ===========
# -> Time 4.76 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.743026
# -> Raw expression :
#               ⎛    -f⋅t⎞
# sin(-α₀⋅t)⋅sin⎝-φ⋅ℯ    ⎠⋅1
#
#
# =========== Epoch 00062 ===========
# -> Time 4.66 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.730629
# -> Raw expression :
# ⎛-sin(-α₀⋅-t) ⎞
# ⎜─────────────⎟
# ⎝      t      ⎠
# ───────────────
#         ⎛ -φ⎞
#   α₀⋅sin⎝ℯ  ⎠
#
#
# =========== Epoch 00063 ===========
# -> Time 4.49 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   -f⋅t    ⎛α₀⋅t⋅t⎞
# -ℯ    ⋅sin⎜──────⎟
#           ⎝  t   ⎠
#
#
# =========== Epoch 00064 ===========
# -> Time 4.41 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  ⎛               ⎛   ⎛t ⎞⎞⎞   α₀⋅t
# -⎜-sin(f⋅t) + sin⎜log⎜──⎟⎟⎟⋅-ℯ
#  ⎝               ⎝   ⎝-t⎠⎠⎠
#
#
# =========== Epoch 00065 ===========
# -> Time 4.51 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                 ⎛ -f⋅t⎞
# sin(- -α₀⋅t)⋅sin⎝ℯ    ⎠
# ───────────────────────
#            -φ
#
#
# =========== Epoch 00066 ===========
# -> Time 4.20 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(- -f⋅-t)
# ──────────────
#      -α₀⋅t
#    -ℯ
#
#
# =========== Epoch 00067 ===========
# -> Time 4.38 s
#
# Overall best  at R=0.749529
# -> Raw expression :
#                       ⎛ α₀⋅φ⋅t⎞
# f⋅t⋅sin(-f⋅t - φ)⋅-sin⎝ℯ      ⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#                ⎛ -α₀⋅t⎞
# -sin(-f⋅-t)⋅sin⎝ℯ     ⎠
#
#
# =========== Epoch 00068 ===========
# -> Time 4.33 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
#
# =========== Epoch 00069 ===========
# -> Time 4.30 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                ⎛  f⋅-t⎞
# φ⋅sin(α₀⋅t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00070 ===========
# -> Time 7.83 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   -α₀⋅t
# -ℯ     ⋅sin(-f⋅-t)
#
#
# =========== Epoch 00071 ===========
# -> Time 4.12 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.784058
# -> Raw expression :
# ⎛               ⎛ 1  ⎞⎞  α₀⋅t
# ⎜sin(-f⋅t) + sin⎜────⎟⎟⋅ℯ
# ⎝               ⎝-f⋅t⎠⎠
#
#
# =========== Epoch 00072 ===========
# -> Time 4.38 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#                 ⎛  -f⋅t⎞
# -sin(-α₀⋅-t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00073 ===========
# -> Time 4.20 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  α₀⋅t    ⎛       -t ⎞
# ℯ    ⋅sin⎜-f⋅-α₀⋅───⎟
#          ⎝        α₀⎠
#
#
# =========== Epoch 00074 ===========
# -> Time 3.94 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   α₀⋅t
# -ℯ    ⋅sin(α₀⋅t)
# ─────────────────
#         f⋅t
#        ℯ
#
#
# =========== Epoch 00075 ===========
# -> Time 4.04 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   -f⋅t
# -ℯ    ⋅sin(- -α₀⋅t)
#
#
# =========== Epoch 00076 ===========
# -> Time 4.19 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   α₀⋅t    ⎛- -f⋅f⋅t ⎞
# -ℯ    ⋅sin⎜─────────⎟
#           ⎝    f    ⎠
#
#
# =========== Epoch 00077 ===========
# -> Time 4.05 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  f⋅-t
# ℯ    ⋅-sin(α₀⋅-t)
#
#
# =========== Epoch 00078 ===========
# -> Time 4.17 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.730629
# -> Raw expression :
# ⎛-α₀⋅sin(-f⋅t) ⎞
# ⎜──────────────⎟
# ⎝      α₀      ⎠
# ────────────────
#      -α₀⋅t
#
#
# =========== Epoch 00079 ===========
# -> Time 4.50 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  -α₀⋅t
# ℯ     ⋅-sin(φ)⋅-sin(f⋅-t)
#
#
# =========== Epoch 00080 ===========
# -> Time 7.19 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.740908
# -> Raw expression :
#   -sin(-f⋅t)
# ───────────────
#       sin(α₀⋅t)
# -f⋅t⋅ℯ
#
#
# =========== Epoch 00081 ===========
# -> Time 4.35 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.745239
# -> Raw expression :
#           -f⋅t
# -φ - φ + ℯ    ⋅-sin(- -α₀⋅-t)
#
#
# =========== Epoch 00082 ===========
# -> Time 3.86 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#  φ                ⎛  -f⋅t⎞
# ℯ ⋅-sin(-α₀⋅t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00083 ===========
# -> Time 3.71 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.740908
# -> Raw expression :
# -sin(-f⋅t)    -sin(α₀⋅t)
# ───────────⋅-ℯ
#     f⋅t
#
#
# =========== Epoch 00084 ===========
# -> Time 3.90 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.730629
# -> Raw expression :
# α₀⋅-f⋅sin(-f⋅-t)
# ────────────────
#    α₀⋅t⋅α₀⋅f
#
#
# =========== Epoch 00085 ===========
# -> Time 4.11 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                    ⎛  -α₀⋅t⎞
# -φ⋅sin(- -f⋅t)⋅-sin⎝-ℯ     ⎠
#
#
# =========== Epoch 00086 ===========
# -> Time 4.12 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#       ⎛-α₀⋅-f⋅t ⎞
# - -sin⎜─────────⎟
#       ⎝    f    ⎠
# ──────────────────
#         f⋅t
#       -ℯ
#
#
# =========== Epoch 00087 ===========
# -> Time 4.30 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#                   ⎛  -f⋅t⎞
# - -sin(-α₀⋅-t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00088 ===========
# -> Time 4.26 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.768682
# -> Raw expression :
#              - -α₀⋅t
# sin(f⋅t) - -ℯ
# ────────────────────
#         α₀⋅t
#
#
# =========== Epoch 00089 ===========
# -> Time 4.00 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.738230
# -> Raw expression :
#                ⎛ -α₀⋅t⎞
# -sin(-f⋅t)⋅-sin⎝ℯ     ⎠
#
#
# =========== Epoch 00090 ===========
# -> Time 7.30 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#        ⎛ -α₀⋅t⎞
# -α₀⋅sin⎝ℯ     ⎠⋅sin(f⋅t)
# ────────────────────────
#           α₀⋅φ
#
#
# =========== Epoch 00091 ===========
# -> Time 4.38 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(-f⋅-t)
# ────────────
#     α₀⋅t
#    ℯ
#
#
# =========== Epoch 00092 ===========
# -> Time 4.53 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#      ⎛-   -f⋅t   ⎞
# φ⋅sin⎝ 1⋅ℯ    ⋅-1⎠⋅sin(-α₀⋅t)
#
#
# =========== Epoch 00093 ===========
# -> Time 4.24 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -t⋅-sin(f⋅t)
# ────────────
#      -α₀⋅t
#  t⋅-ℯ
#
#
# =========== Epoch 00094 ===========
# -> Time 4.44 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#     α₀⋅t
# -φ⋅ℯ    ⋅sin(-f⋅t)
# ──────────────────
#        f⋅-t
#       ℯ
#
#
# =========== Epoch 00095 ===========
# -> Time 3.93 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# ⎛        ⎛       -φ⎞ ⎞
# ⎜- -t⋅sin⎝-α₀⋅t⋅ℯ  ⎠ ⎟
# ⎜────────────────────⎟
# ⎝         t          ⎠
# ──────────────────────
#           f⋅t
#          ℯ
#
#
# =========== Epoch 00096 ===========
# -> Time 3.84 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   -f⋅t
# -ℯ    ⋅-sin(α₀⋅t)
#
#
# =========== Epoch 00097 ===========
# -> Time 3.93 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(- -f⋅t)
# ─────────────
#      -α₀⋅t
#     ℯ
#
#
# =========== Epoch 00098 ===========
# -> Time 3.71 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#  sin(-φ)
# ℯ       ⋅sin(-α₀⋅t)
# ───────────────────
#          f⋅t
#         ℯ
#
#
# =========== Epoch 00099 ===========
# -> Time 3.85 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# - -sin(-f⋅t)
# ─────────────
#      -α₀⋅t
#     ℯ
#
#
# =========== Epoch 00100 ===========
# -> Time 7.16 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#     ⎛-f⋅-α₀⋅t⎞
# -sin⎜────────⎟
#     ⎝  -α₀   ⎠
# ───────────────
#        α₀⋅t
#      -ℯ
#
#
# =========== Epoch 00101 ===========
# -> Time 4.17 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(- -α₀⋅t)
# ──────────────
#       f⋅t
#      ℯ
#
#
# =========== Epoch 00102 ===========
# -> Time 4.16 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744408
# -> Raw expression :
#  ⎛   ⎛ -α₀⋅t⎞    -α₀⋅t⎞
# -⎝sin⎝ℯ     ⎠ - ℯ     ⎠⋅sin(-f⋅t)
# ──────────────────────────────────
#                 φ
#
#
# =========== Epoch 00103 ===========
# -> Time 4.12 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.741054
# -> Raw expression :
#                    ⎛ -α₀⋅t - f⋅t⎞
# φ + -sin(-f⋅-t)⋅sin⎝ℯ           ⎠
#
#
# =========== Epoch 00104 ===========
# -> Time 4.09 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#   sin(φ)    ⎛  -f⋅t⎞
# -ℯ      ⋅sin⎝-ℯ    ⎠⋅-sin(α₀⋅-t)
#
#
# =========== Epoch 00105 ===========
# -> Time 4.13 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
# - -sin(-f⋅-t)
# ──────────────
#     φ  α₀⋅t
#   -ℯ ⋅ℯ
#
#
# =========== Epoch 00106 ===========
# -> Time 4.07 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(- -f⋅t)
# ─────────────
#      α₀⋅t
#     ℯ
#
#
# =========== Epoch 00107 ===========
# -> Time 4.20 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.740908
# -> Raw expression :
#  -sin(α₀⋅t)
# ℯ          ⋅-sin(-f⋅-t)
# ───────────────────────
#           f⋅t
#
#
# =========== Epoch 00108 ===========
# -> Time 4.18 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# f⋅sin(-f⋅t)
# ───────────
#      α₀⋅t
#   f⋅ℯ
#
#
# =========== Epoch 00109 ===========
# -> Time 4.37 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#      -α₀⋅t
# -φ⋅-ℯ     ⋅sin(f⋅-t)
#
#
# =========== Epoch 00110 ===========
# -> Time 7.64 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743026
# -> Raw expression :
#               ⎛       -α₀⋅t⎞
# -sin(-f⋅t)⋅sin⎝- -φ⋅-ℯ     ⎠
#
#
# =========== Epoch 00111 ===========
# -> Time 4.69 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#  f⋅-t
# ℯ    ⋅sin(-α₀⋅t)
#
#
# =========== Epoch 00112 ===========
# -> Time 4.41 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#   φ                 ⎛  α₀⋅t⎞
# -ℯ ⋅-sin(- -f⋅t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00113 ===========
# -> Time 4.09 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#   -φ              ⎛  α₀⋅t⎞
# -ℯ  ⋅sin(-f⋅t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00114 ===========
# -> Time 4.07 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#   -α₀⋅t
# -ℯ     ⋅-sin(-f⋅t)
# ───────────────────
#          ⎛ φ⎞
#       sin⎝ℯ ⎠
#
#
# =========== Epoch 00115 ===========
# -> Time 4.02 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(-f⋅-t)
# ────────────
#     α₀⋅t
#    ℯ
#
#
# =========== Epoch 00116 ===========
# -> Time 4.23 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   -f⋅t               ⎛  -φ⎞
# -ℯ    ⋅sin(α₀⋅-t)⋅sin⎝-ℯ  ⎠
#
#
# =========== Epoch 00117 ===========
# -> Time 4.25 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#  -α₀⋅-t
# ℯ      ⋅sin(-f⋅t)
# ─────────────────
#       sin(φ)
#      ℯ
#
#
# =========== Epoch 00118 ===========
# -> Time 4.06 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(- -f⋅t)
# ─────────────
#      α₀⋅t
#     ℯ
#
#
# =========== Epoch 00119 ===========
# -> Time 4.23 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#    -α₀⋅t
# t⋅ℯ     ⋅sin(f⋅-t)
# ──────────────────
#         t
#
#
# =========== Epoch 00120 ===========
# -> Time 7.55 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.804437
# -> Raw expression :
#     ⎛       -α₀⋅t⎞
# -sin⎝f⋅t - ℯ     ⎠
# ───────────────────
#         α₀⋅t
#
#
# =========== Epoch 00121 ===========
# -> Time 3.88 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#   -sin(-f⋅t)
# ───────────────
#     ⎛ -φ⎞  α₀⋅t
# -sin⎝ℯ  ⎠⋅ℯ
#
#
# =========== Epoch 00122 ===========
# -> Time 3.88 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                      ⎛ -f⋅t⎞
# -φ⋅-sin(- -α₀⋅-t)⋅sin⎝ℯ    ⎠
#
#
# =========== Epoch 00123 ===========
# -> Time 4.17 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743512
# -> Raw expression :
#               ⎛   -f⋅t⎞
# -sin(α₀⋅t)⋅sin⎝φ⋅ℯ    ⎠
# ────────────────────────
#          sin(φ)
#
#
# =========== Epoch 00124 ===========
# -> Time 4.05 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#  α₀⋅t    ⎛-f⋅f⋅t ⎞
# ℯ    ⋅sin⎜───────⎟
#          ⎝   f   ⎠
# ──────────────────
#       sin(φ)
#
#
# =========== Epoch 00125 ===========
# -> Time 3.88 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#               ⎛  α₀⋅t⎞
# -sin(f⋅-t)⋅sin⎝-ℯ    ⎠
# ──────────────────────
#         sin(φ)
#
#
# =========== Epoch 00126 ===========
# -> Time 4.11 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#        -f⋅t
# f⋅φ⋅t⋅ℯ    ⋅sin(α₀⋅t)
# ─────────────────────
#          f⋅t
#
#
# =========== Epoch 00127 ===========
# -> Time 3.83 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                 ⎛  α₀⋅t⎞
# -φ⋅sin(-f⋅t)⋅sin⎝-ℯ    ⎠
#
#
# =========== Epoch 00128 ===========
# -> Time 3.83 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#  -f⋅t  sin(φ)
# ℯ    ⋅ℯ      ⋅sin(-α₀⋅t)
#
#
# =========== Epoch 00129 ===========
# -> Time 3.76 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                    ⎛  -α₀⋅t⎞
# -φ⋅sin(- -f⋅-t)⋅sin⎝-ℯ     ⎠
#
#
# =========== Epoch 00130 ===========
# -> Time 7.25 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.745239
# -> Raw expression :
#   -α₀⋅-t
# -ℯ      ⋅-sin(-f⋅t) + sin(-φ)
#
#
# =========== Epoch 00131 ===========
# -> Time 4.05 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743026
# -> Raw expression :
#               ⎛    α₀⋅-t⎞
# -sin(f⋅t)⋅-sin⎝-φ⋅ℯ     ⎠
#
#
# =========== Epoch 00132 ===========
# -> Time 3.93 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#               ⎛ -α₀⋅t⎞
# -sin(-f⋅t)⋅sin⎝ℯ     ⎠
# ──────────────────────
#        sin(-φ)
#
#
# =========== Epoch 00133 ===========
# -> Time 3.99 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
# -sin(φ)⋅sin(-f⋅-t)
# ───────────────────
#         α₀⋅t
#        ℯ
#
#
# =========== Epoch 00134 ===========
# -> Time 4.03 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#       f⋅-t
# - -φ⋅ℯ    ⋅-sin(α₀⋅-t)
#
#
# =========== Epoch 00135 ===========
# -> Time 4.21 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
# -sin(- -f⋅t)
# ─────────────
#  α₀⋅t  cos(φ)
# ℯ    ⋅ℯ
#
#
# =========== Epoch 00136 ===========
# -> Time 4.36 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                    ⎛ -f⋅t⎞
# -φ⋅-sin(-α₀⋅-t)⋅sin⎝ℯ    ⎠
#
#
# =========== Epoch 00137 ===========
# -> Time 3.98 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                ⎛ α₀⋅t⎞
# -sin(-f⋅-t)⋅sin⎝ℯ    ⎠
# ───────────────────────
#             φ
#            ℯ
#
#
# =========== Epoch 00138 ===========
# -> Time 4.11 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   -f⋅t
# -ℯ    ⋅sin(- -α₀⋅t)
#
#
# =========== Epoch 00139 ===========
# -> Time 4.01 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#                   -f⋅t
# - -α₀⋅sin(-α₀⋅t)⋅ℯ
# ───────────────────────
#            α₀
#
#
# =========== Epoch 00140 ===========
# -> Time 7.34 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#   α₀⋅t
# -ℯ    ⋅-sin(f⋅t)
# ─────────────────
#          -φ
#        -ℯ
#
#
# =========== Epoch 00141 ===========
# -> Time 4.15 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#   -α₀⋅-t
# -ℯ      ⋅sin(- -f⋅t)
# ─────────────────────
#           φ
#
#
# =========== Epoch 00142 ===========
# -> Time 3.89 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#     α₀⋅t            φ
# - -ℯ    ⋅-sin(f⋅t)⋅ℯ
#
#
# =========== Epoch 00143 ===========
# -> Time 4.04 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#    sin(-f⋅t)
# ───────────────
#   α₀⋅-t
# -ℯ     ⋅-sin(φ)
#
#
# =========== Epoch 00144 ===========
# -> Time 3.65 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#       α₀⋅φ⋅t
# - -φ⋅ℯ      ⋅sin(-f⋅t)
#
#
# =========== Epoch 00145 ===========
# -> Time 3.63 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#  -sin(-f⋅-t)
# ──────────────
#  α₀⋅t  -sin(φ)
# ℯ    ⋅ℯ
#
#
# =========== Epoch 00146 ===========
# -> Time 3.55 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#     α₀⋅t
# - -ℯ    ⋅sin(-f⋅t)
#
#
# =========== Epoch 00147 ===========
# -> Time 3.56 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
# sin(- -f⋅t)
# ───────────
#    φ  -α₀⋅t
#  -ℯ ⋅ℯ
#
#
# =========== Epoch 00148 ===========
# -> Time 3.66 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#      α₀⋅-t
# -φ⋅-ℯ     ⋅sin(f⋅-t)
#
#
# =========== Epoch 00149 ===========
# -> Time 3.77 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#  -φ   -f⋅t
# ℯ  ⋅-ℯ    ⋅sin(-α₀⋅t)
#
#
# =========== Epoch 00150 ===========
# -> Time 6.87 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#  φ              ⎛ -α₀⋅t⎞
# ℯ ⋅sin(f⋅-t)⋅sin⎝ℯ     ⎠
#
#
# =========== Epoch 00151 ===========
# -> Time 3.84 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                 ⎛ -α₀⋅t⎞
# sin(- -f⋅-t)⋅sin⎝ℯ     ⎠
# ────────────────────────
#            φ
#
#
# =========== Epoch 00152 ===========
# -> Time 3.84 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#      α₀⋅t
# -φ⋅-ℯ    ⋅sin(-f⋅t)
#
#
# =========== Epoch 00153 ===========
# -> Time 3.71 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#    α₀⋅t
# φ⋅ℯ    ⋅sin(-f⋅t)
#
#
# =========== Epoch 00154 ===========
# -> Time 3.94 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#    -α₀⋅t
# t⋅ℯ     ⋅sin(-f⋅t)
# ──────────────────
#         t
#
#
# =========== Epoch 00155 ===========
# -> Time 3.83 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                    ⎛ α₀⋅t⎞
# -φ⋅φ⋅-sin(f⋅t)⋅-sin⎝ℯ    ⎠
#
#
# =========== Epoch 00156 ===========
# -> Time 3.74 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#  -f⋅t  sin(φ)
# ℯ    ⋅ℯ      ⋅sin(-α₀⋅-t)
#
#
# =========== Epoch 00157 ===========
# -> Time 3.99 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.742076
# -> Raw expression :
#   α₀⋅t
# -ℯ    ⋅sin(-f⋅-t)
#
#
# =========== Epoch 00158 ===========
# -> Time 3.99 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
# - -φ⋅sin(-α₀⋅t)
# ────────────────
#        f⋅t
#       ℯ
#
#
# =========== Epoch 00159 ===========
# -> Time 3.96 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.744448
# -> Raw expression :
#    -f⋅t
# φ⋅ℯ    ⋅-sin(α₀⋅t)
#
#
# =========== Epoch 00160 ===========
# -> Time 7.30 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.743616
# -> Raw expression :
#                 ⎛ α₀⋅t⎞
# sin(- -f⋅-t)⋅sin⎝ℯ    ⎠
# ───────────────────────
#            φ
#
#
# ...
# -> Time 3.42 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#   -α₀⋅sin(f⋅t + φ)
# t⋅─────────────────
#           f
# ───────────────────
#        f⋅t⋅t
#
#
# =========== Epoch 00327 ===========
# -> Time 3.24 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#  -sin(f⋅-t - φ⋅φ)
# -─────────────────
#          α₀
# ───────────────────
#          t
#
#
# =========== Epoch 00328 ===========
# -> Time 3.37 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#   -sin(f⋅t - φ⋅φ)
# φ⋅────────────────
#         α₀⋅t
#
#
# =========== Epoch 00329 ===========
# -> Time 3.48 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#       -α₀⋅sin(f⋅t - 2⋅φ)
#   -α₀⋅───────────────────
#            α₀⋅α₀⋅α₀⋅f
# f⋅────────────────────────
#              t
#
#
# =========== Epoch 00330 ===========
# -> Time 6.40 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# ⎛-φ⋅t⋅sin(-f⋅t + φ + φ) ⎞
# ⎜───────────────────────⎟
# ⎝          φ⋅t          ⎠
# ─────────────────────────
#            α₀⋅t
#
#
# =========== Epoch 00331 ===========
# -> Time 3.40 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# -t⋅sin(-α₀⋅t + φ)
# ──────────────────
#     f⋅φ⋅-φ⋅t⋅t
#
#
# =========== Epoch 00332 ===========
# -> Time 3.37 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#          - -sin(f⋅t - 2⋅φ)
# -α₀⋅α₀⋅φ⋅──────────────────
#               f⋅f⋅φ⋅t
# ────────────────────────────
#              α₀
#
#
# =========== Epoch 00333 ===========
# -> Time 3.33 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# ⎛-α₀⋅α₀⋅-α₀⋅φ⋅sin(-f⋅t + φ + φ) ⎞
# ⎜───────────────────────────────⎟
# ⎝           α₀⋅α₀⋅f⋅t           ⎠
# ─────────────────────────────────
#                f⋅φ
#
#
# =========== Epoch 00334 ===========
# -> Time 3.20 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# -sin(α₀⋅t - φ)
# ───────────────
#     f⋅φ⋅φ⋅t
#
#
# =========== Epoch 00335 ===========
# -> Time 3.40 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(-α₀⋅t + φ)
# ──────────────
#    f⋅φ⋅φ⋅t
#
#
# =========== Epoch 00336 ===========
# -> Time 3.86 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.852537
# -> Raw expression :
#     ⎛    sin(-f⋅t + φ + φ + φ)⎞
# f⋅φ⋅⎜φ + ─────────────────────⎟
#     ⎝              φ          ⎠
# ───────────────────────────────
#            α₀⋅f⋅φ⋅φ⋅t
#
#
# =========== Epoch 00337 ===========
# -> Time 3.60 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# f⋅sin(-f⋅t + φ + φ + φ)
# ───────────────────────
#         α₀⋅f⋅φ⋅t
#
#
# =========== Epoch 00338 ===========
# -> Time 3.69 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# -α₀⋅α₀⋅sin(-f⋅t + φ + φ + φ)
# ─────────────────────────────
#            α₀⋅f⋅f⋅t
#
#
# =========== Epoch 00339 ===========
# -> Time 3.86 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(f⋅-φ⋅-t + φ)
# ────────────────
#     α₀⋅φ⋅φ⋅t
#
#
# =========== Epoch 00340 ===========
# -> Time 7.06 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# f⋅sin(α₀⋅t + φ + φ)
# ───────────────────
#      α₀⋅α₀⋅φ⋅t
#
#
# =========== Epoch 00341 ===========
# -> Time 4.21 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# -α₀⋅sin(-f⋅t + φ + φ + φ)
# ──────────────────────────
#           f⋅f⋅t
#
#
# =========== Epoch 00342 ===========
# -> Time 3.92 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# -α₀⋅sin(φ + φ + f⋅t - φ)
# ─────────────────────────
#           f⋅f⋅t
#
#
# =========== Epoch 00343 ===========
# -> Time 3.94 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# t⋅sin(f⋅t + φ + φ + φ)
# ──────────────────────
#       α₀⋅φ⋅φ⋅t⋅t
#
#
# =========== Epoch 00344 ===========
# -> Time 3.90 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#   -f⋅sin(f⋅t + φ + φ + φ)
# φ⋅────────────────────────
#          α₀⋅α₀⋅φ⋅t
#
#
# =========== Epoch 00345 ===========
# -> Time 4.13 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.859861
# -> Raw expression :
#    ⎛  ⎛    ⎛   1      1 1⎞ 1 1 1  ⎞        ⎞
# sin⎜f⋅⎜t + ⎜1⋅─── + 1⋅─⋅─⎟⋅─⋅─⋅─⋅1⎟ + φ + φ⎟
#    ⎜  ⎜    ⎜  ⎛f⎞     f f⎟ t f t  ⎟        ⎟
#    ⎜  ⎜    ⎜  ⎜─⎟        ⎟        ⎟        ⎟
#    ⎝  ⎝    ⎝  ⎝t⎠        ⎠        ⎠        ⎠
# ────────────────────────────────────────────
#                     α₀⋅t
#
#
# =========== Epoch 00346 ===========
# -> Time 4.06 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# f⋅sin(-f⋅t + φ + φ + φ)
# ───────────────────────
#         α₀⋅α₀⋅t
#
#
# =========== Epoch 00347 ===========
# -> Time 4.01 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#       ⎛               φ⎞
#   -sin⎝f⋅t + φ + φ + ℯ ⎠
# φ⋅───────────────────────
#             α₀⋅t
# ─────────────────────────
#             φ
#
#
# =========== Epoch 00348 ===========
# -> Time 4.17 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(-f⋅-φ⋅t + φ)
# ────────────────
#     α₀⋅φ⋅φ⋅t
#
#
# =========== Epoch 00349 ===========
# -> Time 4.04 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# -sin(-α₀⋅t + φ + φ)
# ────────────────────
#      f⋅t⋅sin(φ)
#
#
# =========== Epoch 00350 ===========
# -> Time 6.96 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# φ⋅sin(-f⋅(t + t) + φ + φ + φ + φ)
# ─────────────────────────────────
#               α₀⋅φ⋅t
#
#
# =========== Epoch 00351 ===========
# -> Time 4.08 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.854655
# -> Raw expression :
#      ⎛                      0.5⎞ 1 1  1
# 1⋅sin⎝φ + φ + (α₀⋅f⋅t⋅t + φ)   ⎠⋅─⋅──⋅─
#                                  φ α₀ t
#
#
# =========== Epoch 00352 ===========
# -> Time 4.23 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#      ⎛               φ⎞ 1  1
# 1⋅sin⎝f⋅t + φ + φ + ℯ ⎠⋅──⋅─
#                         α₀ t
#
#
# =========== Epoch 00353 ===========
# -> Time 4.23 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# t⋅sin(-f⋅t + φ + φ + φ + φ)
# ───────────────────────────
#          α₀⋅φ⋅φ⋅t⋅t
#
#
# =========== Epoch 00354 ===========
# -> Time 4.30 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.856524
# -> Raw expression :
#    ⎛      ⎛        α₀⋅t⎞⎞
# sin⎝φ + t⋅⎝α₀ - f⋅ℯ    ⎠⎠
# ─────────────────────────
#           f⋅φ⋅t
#
#
# =========== Epoch 00355 ===========
# -> Time 4.36 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(φ + φ + -α₀⋅t - φ)
# ──────────────────────
#        f⋅φ⋅φ⋅t
#
#
# =========== Epoch 00356 ===========
# -> Time 4.23 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#    -sin(f⋅t + φ + φ + φ + φ)
# -f⋅──────────────────────────
#                α₀
# ──────────────────────────────
#              α₀⋅t
#
#
# =========== Epoch 00357 ===========
# -> Time 4.40 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(-f⋅t + φ + φ + φ + φ)
# ─────────────────────────
#          α₀⋅φ⋅φ⋅t
#
#
# =========== Epoch 00358 ===========
# -> Time 4.37 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#   -f⋅sin(-f⋅t + φ + φ)
# φ⋅─────────────────────
#          α₀⋅f⋅φ⋅t
#
#
# =========== Epoch 00359 ===========
# -> Time 4.20 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# -f⋅sin(f⋅t + φ + φ + φ + φ)
# ────────────────────────────
#           α₀⋅f⋅φ⋅t
#
#
# =========== Epoch 00360 ===========
# -> Time 7.06 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#                         1  1 1
# 1⋅sin(-f⋅t + φ + φ + φ)⋅──⋅─⋅─
#                         α₀ t φ
#
#
# =========== Epoch 00361 ===========
# -> Time 3.82 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(φ + φ + f⋅φ⋅t - φ)
# ──────────────────────
#         α₀⋅φ⋅t
#
#
# =========== Epoch 00362 ===========
# -> Time 4.27 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#                              1 1 1 1
# 1⋅sin(-α₀⋅t + φ + φ + φ + φ)⋅─⋅─⋅─⋅─
#                              φ φ f t
#
#
# =========== Epoch 00363 ===========
# -> Time 4.04 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# f⋅sin(-f⋅t + φ + φ + φ)
# ───────────────────────
#         α₀⋅f⋅φ⋅t
#
#
# =========== Epoch 00364 ===========
# -> Time 4.14 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# f⋅sin(f⋅-t + φ + φ + φ)
# ───────────────────────
#         α₀⋅α₀⋅t
#
#
# =========== Epoch 00365 ===========
# -> Time 4.09 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.851009
# -> Raw expression :
#    ⎛           -α₀⋅t⎞
# sin⎝f⋅t + φ + ℯ     ⎠
# ─────────────────────
#         α₀⋅φ⋅t
#
#
# =========== Epoch 00366 ===========
# -> Time 4.04 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
#                                 1 1  1
# 1⋅cos(-f⋅t + φ + φ + φ + φ + φ)⋅─⋅──⋅─
#                                 t α₀ φ
#
#
# =========== Epoch 00367 ===========
# -> Time 3.85 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# α₀⋅sin(-f⋅t - φ - φ + φ)
# ────────────────────────
#          f⋅f⋅t
#
#
# =========== Epoch 00368 ===========
# -> Time 3.93 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# φ⋅sin(α₀⋅t - f⋅t + φ)
# ─────────────────────
#         α₀⋅φ⋅t
#
#
# =========== Epoch 00369 ===========
# -> Time 3.93 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# -α₀⋅sin(-f⋅-t + φ)
# ───────────────────
#        f⋅f⋅t
#
#
# =========== Epoch 00370 ===========
# -> Time 7.34 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# f⋅sin(-f⋅t + φ + φ + φ)
# ───────────────────────
#         α₀⋅f⋅φ⋅t
#
#
# =========== Epoch 00371 ===========
# -> Time 3.96 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# α₀⋅sin(-f⋅t + φ + φ)
# ────────────────────
#        f⋅f⋅t
#
#
# =========== Epoch 00372 ===========
# -> Time 3.85 s
#
# Overall best  at R=0.880999
# -> Raw expression :
#  α₀⋅t    ⎛        -log(f⋅t)⎞
# ℯ    ⋅sin⎝f⋅-t + ℯ         ⎠
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(-f⋅t + φ + φ + φ + φ)
# ─────────────────────────
#          α₀⋅φ⋅φ⋅t
#
#
# =========== Epoch 00373 ===========
# -> Time 3.95 s
#
# Overall best  at R=0.999938
# -> Raw expression :
# -sin(-f⋅-t + φ)
# ────────────────
#       α₀⋅t
#      ℯ
#
# Best of epoch at R=0.999938
# -> Raw expression :
# -sin(-f⋅-t + φ)
# ────────────────
#       α₀⋅t
#      ℯ
#
#
# =========== Epoch 00374 ===========
# -> Time 4.07 s
#
# Overall best  at R=0.999938
# -> Raw expression :
# -sin(-f⋅-t + φ)
# ────────────────
#       α₀⋅t
#      ℯ
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(α₀⋅φ⋅φ⋅t - φ)
# ─────────────────
#        f⋅t
#
#
# =========== Epoch 00375 ===========
# -> Time 3.93 s
#
# Overall best  at R=0.999938
# -> Raw expression :
# -sin(-f⋅-t + φ)
# ────────────────
#       α₀⋅t
#      ℯ
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(α₀⋅φ⋅t + α₀⋅t + φ + φ)
# ──────────────────────────
#            f⋅t
#
#
# =========== Epoch 00376 ===========
# -> Time 4.17 s
#
# Overall best  at R=0.999938
# -> Raw expression :
# -sin(-f⋅-t + φ)
# ────────────────
#       α₀⋅t
#      ℯ
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(-α₀⋅t + φ)
# ──────────────
#    f⋅φ⋅φ⋅t
#
#
# =========== Epoch 00377 ===========
# -> Time 3.99 s
#
# Overall best  at R=0.999938
# -> Raw expression :
# -sin(-f⋅-t + φ)
# ────────────────
#       α₀⋅t
#      ℯ
#
# Best of epoch at R=0.849302
# -> Raw expression :
# α₀⋅sin(-α₀⋅t + φ + φ)
# ─────────────────────
#         t⋅f⋅f
#
#
# =========== Epoch 00378 ===========
# -> Time 4.20 s
#
# Overall best  at R=0.999938
# -> Raw expression :
# -sin(-f⋅-t + φ)
# ────────────────
#       α₀⋅t
#      ℯ
#
# Best of epoch at R=0.849302
# -> Raw expression :
# sin(α₀⋅φ⋅t + α₀⋅t + φ + φ)
# ──────────────────────────
#            f⋅t

# %% [markdown]
# ## Results

# %% [markdown]
# ### Run plot

# %%
run_visualiser.make_visualisation()
run_visualiser.save_visualisation()
run_visualiser.save_data()

# %% [markdown]
# ### Pareto Front

# %%
def plot_pareto_front(run_logger,
                      do_simplify                   = True,
                      show_superparent_at_beginning = True,
                      eq_text_size                  = 12,
                      delta_xlim                    = [0, 5 ],
                      delta_ylim                    = [0, 15],
                      frac_delta_equ                = [0.03, 0.03],
                      figsize                       = (20, 10),
                     ):

    pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

    pareto_front_rmse = pareto_front_rmse
    # Fig params
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    # enables new_dummy_symbol = "\square"
    plt.rc('text.latex', preamble=r'\usepackage{amssymb} \usepackage{xcolor}')
    plt.rc('font', size=32)

    # Fig
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'r-')
    ax.plot(pareto_front_complexities, pareto_front_rmse, 'ro')

    # Limits
    xmin = pareto_front_complexities.min() + delta_xlim[0]
    xmax = pareto_front_complexities.max() + delta_xlim[1]
    ymin = pareto_front_rmse.min() + delta_ylim[0]
    ymax = pareto_front_rmse.max() + delta_ylim[1]
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

    # Axes labels
    ax.set_xlabel("Expression complexity")
    ax.set_ylabel("RMSE")


    for i_prog in range (len(pareto_front_programs)):
        prog = pareto_front_programs[i_prog]

        text_pos  = [pareto_front_complexities[i_prog] + frac_delta_equ[0]*(xmax-xmin), 
                     pareto_front_rmse[i_prog]         + frac_delta_equ[1]*(ymax-ymin)]
        # Getting latex expr
        latex_str = prog.get_infix_latex(do_simplify = do_simplify)
        # Adding "superparent =" before program to make it pretty
        if show_superparent_at_beginning:
            latex_str = prog.library.superparent.name + ' =' + latex_str


        ax.text(text_pos[0], text_pos[1], f'${latex_str}$', size = eq_text_size)

# %%
plot_pareto_front(run_logger)

# %% [markdown]
# ### Complexity - accuracy optimums

# %%
pareto_front_complexities, pareto_front_programs, pareto_front_r, pareto_front_rmse = run_logger.get_pareto_front()

# %%
for prog in pareto_front_programs:
    prog.show_infix(do_simplify=True)
    free_consts = prog.free_const_values.detach().cpu().numpy()
    for i in range (len(free_consts)):
        print("%s = %f"%(prog.library.free_const_names[i], free_consts[i]))
# Out:
# alpha0 = 0.100000
# f = 0.000000
# phi = 1.000000
# alpha0 = -0.548808
# f = 1.000000
# phi = 1.000000
# alpha0 = 0.100000
# f = 0.851373
# phi = 0.195415
# alpha0 = 0.100000
# f = 0.743263
# phi = -0.208318
# alpha0 = 0.329132
# f = 0.731936
# phi = 1.000000
# alpha0 = 0.777265
# f = 0.334329
# phi = 2.655510
# alpha0 = 0.777266
# f = 0.334335
# phi = 3.627685
# alpha0 = 0.334333
# f = 0.777265
# phi = 2.407717
# alpha0 = 0.101111
# f = 0.783989
# phi = 5.709456
